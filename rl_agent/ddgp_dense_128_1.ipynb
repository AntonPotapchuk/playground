# %%
import numpy as np
import os
import tensorflow as tf
import warnings

from keras.models import Model
from keras.layers import Dense, Flatten, Convolution2D, Input, Concatenate, Activation
from keras.optimizers import Adam
from pommerman.configs import ffa_v0_env
from pommerman.envs.v0 import Pomme
from pommerman.agents import SimpleAgent, BaseAgent
from pommerman.constants import BOARD_SIZE
from rl.agents import DDPGAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory
from rl.core import Env, Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint, Callback
from rl.random import OrnsteinUhlenbeckProcess

# %%
number_of_training_steps = 500000
log_interval = 1000
file_log_path = './dqn/rl_logs/ddgp_dense_128_1/log.txt'
tensorboard_path = './dqn/logs/ddgp_dense_128_1/'
model_path = './dqn/model/ddgp_dense_128_1/model{step}.h4'

# %%
if not os.path.isdir(os.path.dirname(file_log_path)):
    os.makedirs(os.path.dirname(file_log_path))
if not os.path.isdir(os.path.dirname(model_path)):
    os.makedirs(os.path.dirname(model_path))

# %%
class TensorforceAgent(BaseAgent):
    def act(self, obs, action_space):
        pass


class TensorboardLogger(Callback):
    """Logging in tensorboard without tensorflow ops."""
    def __init__(self, log_dir):
        # Some algorithms compute multiple episodes at once since they are multi-threaded.
        # We therefore use a dictionary that is indexed by the episode to separate episodes
        # from each other.
        self.observations = {}
        self.rewards = {}
        self.actions = {}
        self.metrics = {}
        self.step = 0
        """Creates a summary writer logging to log_dir."""
        self.writer = tf.summary.FileWriter(log_dir)

    def log_scalar(self, tag, value, step):
        """Log a scalar variable.
        Parameter
        ----------
        tag : basestring
            Name of the scalar
        value
        step : int
            training iteration
        """
        summary = tf.Summary(value=[tf.Summary.Value(tag=tag, simple_value=value)])
        self.writer.add_summary(summary, step)

    def on_train_begin(self, logs):
        self.metrics_names = self.model.metrics_names

    def on_episode_begin(self, episode, logs):
        self.observations[episode] = []
        self.rewards[episode] = []
        self.actions[episode] = []
        self.metrics[episode] = []

    def on_episode_end(self, episode, logs):
        episode_steps = len(self.observations[episode])
        variables = {
            'step': self.step,
            'nb_steps': self.params['nb_steps'],
            'episode_steps': episode_steps,
            'episode_reward': np.sum(self.rewards[episode]),
            'reward_mean': np.mean(self.rewards[episode]),
            'reward_min': np.min(self.rewards[episode]),
            'reward_max': np.max(self.rewards[episode]),
            'action_mean': np.mean(np.argmax(self.actions[episode], axis=1)),
            'action_min': np.min(np.argmax(self.actions[episode], axis=1)),
            'action_max': np.max(np.argmax(self.actions[episode], axis=1)),
            'obs_mean': np.mean(self.observations[episode]),
            'obs_min': np.min(self.observations[episode]),
            'obs_max': np.max(self.observations[episode]),
        }

        # Format all metrics.
        metrics = np.array(self.metrics[episode])
        with warnings.catch_warnings():
            warnings.filterwarnings('error')
            for idx, name in enumerate(self.metrics_names):
                try:
                    value = np.nanmean(metrics[:, idx])
                except Warning:
                    value = -1
                variables[name] = value
        for key, value in variables.items():
            self.log_scalar(key, value, episode + 1)

        # Free up resources.
        del self.observations[episode]
        del self.rewards[episode]
        del self.actions[episode]
        del self.metrics[episode]

    def on_step_end(self, step, logs):
        episode = logs['episode']
        self.observations[episode].append(logs['observation'])
        self.rewards[episode].append(logs['reward'])
        self.actions[episode].append(logs['action'])
        self.metrics[episode].append(logs['metrics'])
        self.step += 1

# %%
# Instantiate the environment
config = ffa_v0_env()
env = Pomme(**config["env_kwargs"])
np.random.seed(0)
env.seed(0)

env.set_init_game_state(None)
nb_actions = env.action_space.n


def create_actor(actions, input_shape=(2369,)):
    inp = Input(input_shape)
    x = Dense(128)(inp)
    x = Activation('relu')(x) 
    out = Dense(actions)(x)
    out = Activation('softmax')(out)
    model = Model(inputs=inp, outputs=out)
    return model


def create_critic(actions, input_shape=(2369,)):
    action_input = Input(shape=(actions,), name='action_input')
    observation_input = Input(shape=input_shape, name='observation_input')
    x = Concatenate()([action_input, observation_input])
    x = Dense(128)(x)
    x = Activation('relu')(x) 
    x = Dense(1)(x)
    return action_input, Model(inputs=[action_input, observation_input], outputs=x)


actor = create_actor(nb_actions)
action_input, critic = create_critic(nb_actions)
print(actor.summary())
print(critic.summary())
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2369)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               303360
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 774
# _________________________________________________________________
# activation_5 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 304,134
# Trainable params: 304,134
# Non-trainable params: 0
# _________________________________________________________________
# None
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# action_input (InputLayer)       (None, 6)            0
# __________________________________________________________________________________________________
# observation_input (InputLayer)  (None, 2369)         0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2375)         0           action_input[0][0]
#                                                                  observation_input[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          304128      concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            129         activation_6[0][0]
# ==================================================================================================
# Total params: 304,257
# Trainable params: 304,257
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
class EnvWrapper(Env):
    """The abstract environment class that is used by all agents. This class has the exact
        same API that OpenAI Gym uses so that integrating with it is trivial. In contrast to the
        OpenAI Gym implementation, this class only defines the abstract methods without any actual
        implementation.
        To implement your own environment, you need to define the following methods:
        - `step`
        - `reset`
        - `render`
        - `close`
        Refer to the [Gym documentation](https://gym.openai.com/docs/#environments).
        """
    reward_range = (-1, 1)
    action_space = None
    observation_space = None

    def __init__(self, gym, board_size):
        self.gym = gym
        self.action_space = gym.action_space
        self.observation_space = gym.observation_space
        self.reward_range = gym.reward_range
        self.board_size = board_size

    def step(self, action):
        """Run one timestep of the environment's dynamics.
        Accepts an action and returns a tuple (observation, reward, done, info).
        # Arguments
            action (object): An action provided by the environment.
        # Returns
            observation (object): Agent's observation of the current environment.
            reward (float) : Amount of reward returned after previous action.
            done (boolean): Whether the episode has ended, in which case further step() calls will return undefined results.
            info (dict): Contains auxiliary diagnostic information (helpful for debugging, and sometimes learning).
        """
        action = np.argmax(action)
        obs = self.gym.get_observations()
        all_actions = self.gym.act(obs)
        all_actions.insert(self.gym.training_agent, action)
        state, reward, terminal, info = self.gym.step(all_actions)
        agent_state = self.featurize(state[self.gym.training_agent])
        agent_reward = reward[self.gym.training_agent]
        return agent_state, agent_reward, terminal, info

    def reset(self):
        """
        Resets the state of the environment and returns an initial observation.
        # Returns
            observation (object): The initial observation of the space. Initial reward is assumed to be 0.
        """
        # Add 3 random agents
        train_agent_pos = np.random.randint(0, 4)
        agents = []
        for agent_id in range(4):
            if agent_id == train_agent_pos:
                agents.append(TensorforceAgent(config["agent"](agent_id, config["game_type"])))
            else:
                agents.append(SimpleAgent(config["agent"](agent_id, config["game_type"])))
        self.gym.set_agents(agents)
        self.gym.set_training_agent(agents[train_agent_pos].agent_id)
        
        obs = self.gym.reset()
        agent_obs = self.featurize(obs[self.gym.training_agent])
        return agent_obs

    def render(self, mode='human', close=False):
        """Renders the environment.
        The set of supported modes varies per environment. (And some
        environments do not support rendering at all.)
        # Arguments
            mode (str): The mode to render with.
            close (bool): Close all open renderings.
        """
        self.gym.render(mode=mode, close=close)

    def close(self):
        """Override in your subclass to perform any necessary cleanup.
        Environments will automatically close() themselves when
        garbage collected or when the program exits.
        """
        self.gym.close()

    def seed(self, seed=None):
        """Sets the seed for this env's random number generator(s).
        # Returns
            Returns the list of seeds used in this env's random number generators
        """
        raise self.gym.seed(seed)

    def configure(self, *args, **kwargs):
        """Provides runtime configuration to the environment.
        This configuration should consist of data that tells your
        environment how to run (such as an address of a remote server,
        or path to your ImageNet data). It should not affect the
        semantics of the environment.
        """
        raise NotImplementedError()

    def featurize(self, obs):
        shape = (self.board_size, self.board_size, 1)

        def get_matrix(dict, key):
            res = dict[key]
            return res.reshape(shape).astype(np.float32)

        def get_map(board, item):
            map = np.zeros(shape)
            map[board == item] = 1
            return map

        board = get_matrix(obs, 'board')

        # TODO: probably not needed Passage = 0
        rigid_map = get_map(board, 1)               # Rigid = 1
        wood_map = get_map(board, 2)                # Wood = 2
        bomb_map = get_map(board, 3)                # Bomb = 3
        flames_map = get_map(board, 4)              # Flames = 4
        fog_map = get_map(board, 5)                 # TODO: not used for first two stages Fog = 5
        extra_bomb_map = get_map(board, 6)          # ExtraBomb = 6
        incr_range_map = get_map(board, 7)          # IncrRange = 7
        kick_map = get_map(board, 8)                # Kick = 8
        skull_map = get_map(board, 9)               # Skull = 9

        position = obs["position"]
        my_position = np.zeros(shape)
        my_position[position[0], position[1], 0] = 1

        team_mates = get_map(board, obs["teammate"].value) # TODO during documentation it should be an array

        enemies = np.zeros(shape)
        for enemy in obs["enemies"]:
            enemies[board == enemy.value] = 1

        bomb_blast_strength = get_matrix(obs, 'bomb_blast_strength')
        bomb_life = get_matrix(obs, 'bomb_life')

        ammo = obs["ammo"]
        blast_strength = obs["blast_strength"]
        can_kick = int(obs["can_kick"])

        obs = np.concatenate([my_position, enemies, team_mates, rigid_map,
                              wood_map, bomb_map, flames_map,
                              fog_map, extra_bomb_map, incr_range_map,
                              kick_map, skull_map, bomb_blast_strength,
                              bomb_life], axis=2).flatten()
        obs = np.append(obs, [ammo, blast_strength, can_kick])
        return obs

    def __del__(self):
        self.close()

    def __str__(self):
        return '<{} instance>'.format(type(self).__name__)


class CustomProcessor(Processor):
    def process_state_batch(self, batch):
        """Processes an entire batch of states and returns it.
        # Arguments
            batch (list): List of states
        # Returns
            Processed list of states
        """
        batch = np.squeeze(batch, axis=1)
        return batch

    def process_info(self, info):
        """Processes the info as obtained from the environment for use in an agent and
        returns it.
        """
        info['result'] = info['result'].value
        return info

# %%
env_wrapper = EnvWrapper(env, BOARD_SIZE)
processor = CustomProcessor()


memory = SequentialMemory(limit=100000, window_length=1)
random_process = OrnsteinUhlenbeckProcess(size=nb_actions, theta=.15, mu=0., sigma=.3)
agent = DDPGAgent(nb_actions=nb_actions, actor=actor, critic=critic, critic_action_input=action_input,
                  memory=memory, nb_steps_warmup_critic=512, nb_steps_warmup_actor=512,
                  random_process=random_process, gamma=.99, target_model_update=1e-3,
                  batch_size=512, processor=processor)
agent.compile(Adam(lr=0.0001, clipnorm=1.), metrics=['mae'])


file_logger = FileLogger(file_log_path, interval=log_interval)
checkpoint = ModelIntervalCheckpoint(model_path, interval=log_interval)
tensorboard = TensorboardLogger(tensorboard_path)
callbacks=[file_logger, checkpoint, tensorboard]
if os.path.isfile(model_path):
    agent.load_weights(model_path)

# %%
history = agent.fit(env_wrapper, nb_steps=number_of_training_steps, visualize=False, verbose=2,
        nb_max_episode_steps=env._max_steps, callbacks=callbacks)
# Out:
# Training for 500000 steps ...
#      25/500000: episode: 1, duration: 0.775s, episode steps: 25, steps per second: 32, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.189 [0.023, 0.510], mean observation: 0.072 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      60/500000: episode: 2, duration: 0.415s, episode steps: 35, steps per second: 84, episode reward: -1.000, mean reward: -0.029 [-1.000, 0.000], mean action: 0.092 [-0.621, 0.481], mean observation: 0.069 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#     100/500000: episode: 3, duration: 0.452s, episode steps: 40, steps per second: 89, episode reward: -1.000, mean reward: -0.025 [-1.000, 0.000], mean action: 0.134 [-0.205, 0.901], mean observation: 0.070 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#    1081/500000: episode: 4, duration: 30.205s, episode steps: 981, steps per second: 32, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.055 [-1.276, 1.509], mean observation: 0.039 [0.000, 24.000], loss: 0.004073, mean_absolute_error: 0.034987, mean_q: 0.166302
#    1132/500000: episode: 5, duration: 2.785s, episode steps: 51, steps per second: 18, episode reward: -1.000, mean reward: -0.020 [-1.000, 0.000], mean action: 0.232 [-0.228, 1.073], mean observation: 0.071 [0.000, 24.000], loss: 0.002386, mean_absolute_error: 0.025104, mean_q: 0.155317
#    1170/500000: episode: 6, duration: 2.071s, episode steps: 38, steps per second: 18, episode reward: -1.000, mean reward: -0.026 [-1.000, 0.000], mean action: 0.204 [-0.231, 1.155], mean observation: 0.069 [0.000, 24.000], loss: 0.002533, mean_absolute_error: 0.025694, mean_q: 0.147778
#    1195/500000: episode: 7, duration: 1.359s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.167 [-0.090, 0.807], mean observation: 0.072 [0.000, 24.000], loss: 0.003197, mean_absolute_error: 0.030048, mean_q: 0.118975
#    1685/500000: episode: 8, duration: 26.316s, episode steps: 490, steps per second: 19, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: -0.031 [-1.112, 1.327], mean observation: 0.048 [0.000, 24.000], loss: 0.002175, mean_absolute_error: 0.028172, mean_q: 0.117883
#    2116/500000: episode: 9, duration: 21.886s, episode steps: 431, steps per second: 20, episode reward: 1.000, mean reward: 0.002 [0.000, 1.000], mean action: 0.200 [-0.814, 1.508], mean observation: 0.050 [0.000, 24.000], loss: 0.001986, mean_absolute_error: 0.028430, mean_q: 0.147739
, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.128 [-0.305, 1.032], mean observation: 0.072 [0.000, 24.000], loss: 0.001355, mean_absolute_error: 0.026758, mean_q: 0.002894
#    4627/500000: episode: 75, duration: 1.389s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.166 [-0.107, 1.027], mean observation: 0.058 [0.000, 24.000], loss: 0.001477, mean_absolute_error: 0.026654, mean_q: 0.008496
#    4652/500000: episode: 76, duration: 1.374s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.071 [-0.427, 0.987], mean observation: 0.072 [0.000, 24.000], loss: 0.001283, mean_absolute_error: 0.025778, mean_q: 0.005245
#    4677/500000: episode: 77, duration: 1.356s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.184 [-0.161, 1.089], mean observation: 0.072 [0.000, 24.000], loss: 0.001336, mean_absolute_error: 0.026448, mean_q: -0.002922
#    4702/500000: episode: 78, duration: 1.479s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.158 [-0.170, 0.978], mean observation: 0.072 [0.000, 24.000], loss: 0.001222, mean_absolute_error: 0.025303, mean_q: 0.005758
#    4727/500000: episode: 79, duration: 1.410s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.122 [-0.225, 1.075], mean observation: 0.072 [0.000, 24.000], loss: 0.001189, mean_absolute_error: 0.025925, mean_q: 0.000230
#    4752/500000: episode: 80, duration: 1.323s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.171 [-0.287, 1.063], mean observation: 0.072 [0.000, 24.000], loss: 0.001201, mean_absolute_error: 0.027027, mean_q: 0.003323
#    4777/500000: episode: 81, duration: 1.378s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.204 [-0.149, 1.150], mean observation: 0.071 [0.000, 24.000], loss: 0.001126, mean_absolute_error: 0.026202, mean_q: -0.001565
#    4802/500000: episode: 82, duration: 1.431s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.133 [-0.188, 1.046], mean observation: 0.070 [0.000, 24.000], loss: 0.000992, mean_absolute_error: 0.024226, mean_q: -0.000909
#    4827/500000: episode: 83, duration: 1.313s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.116 [-0.340, 1.013], mean observation: 0.071 [0.000, 24.000], loss: 0.001061, mean_absolute_error: 0.024226, mean_q: -0.004676
#    4852/500000: episode: 84, duration: 1.354s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.121 [-0.268, 1.035], mean observation: 0.072 [0.000, 24.000], loss: 0.001212, mean_absolute_error: 0.026104, mean_q: -0.011854
#    4877/500000: episode: 85, duration: 1.387s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.187 [-0.149, 1.055], mean observation: 0.072 [0.000, 24.000], loss: 0.001101, mean_absolute_error: 0.025604, mean_q: -0.007020
#    4902/500000: episode: 86, duration: 1.391s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.136 [-0.219, 1.036], mean observation: 0.072 [0.000, 24.000], loss: 0.001133, mean_absolute_error: 0.026101, mean_q: -0.003510
#    4927/500000: episode: 87, duration: 1.363s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.179 [-0.282, 1.069], mean observation: 0.072 [0.000, 24.000], loss: 0.001095, mean_absolute_error: 0.025461, mean_q: -0.003208
#    4952/500000: episode: 88, duration: 1.466s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.156 [-0.237, 1.091], mean observation: 0.072 [0.000, 24.000], loss: 0.001208, mean_absolute_error: 0.026391, mean_q: -0.007915
#    4977/500000: episode: 89, duration: 1.372s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.229 [-0.114, 1.267], mean observation: 0.072 [0.000, 24.000], loss: 0.001336, mean_absolute_error: 0.026435, mean_q: -0.011337
#    5002/500000: episode: 90, duration: 1.444s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.187 [-0.141, 1.006], mean observation: 0.070 [0.000, 24.000], loss: 0.001092, mean_absolute_error: 0.025061, mean_q: -0.007136
#    5027/500000: episode: 91, duration: 1.455s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.207 [-0.120, 1.273], mean observation: 0.071 [0.000, 24.000], loss: 0.001164, mean_absolute_error: 0.025415, mean_q: -0.009310
#    5052/500000: episode: 92, duration: 1.248s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.115 [-0.265, 0.983], mean observation: 0.071 [0.000, 24.000], loss: 0.001269, mean_absolute_error: 0.027107, mean_q: -0.003918
#    5077/500000: episode: 93, duration: 1.394s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.209 [-0.196, 1.184], mean observation: 0.072 [0.000, 24.000], loss: 0.001314, mean_absolute_error: 0.026964, mean_q: -0.010249
#    5102/500000: episode: 94, duration: 1.451s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.193 [-0.252, 1.335], mean observation: 0.058 [0.000, 24.000], loss: 0.001175, mean_absolute_error: 0.026540, mean_q: -0.017828
#    5127/500000: episode: 95, duration: 1.383s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.100 [-0.207, 1.016], mean observation: 0.065 [0.000, 24.000], loss: 0.001101, mean_absolute_error: 0.024891, mean_q: -0.012254
#    5152/500000: episode: 96, duration: 1.348s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.103 [-0.362, 1.032], mean observation: 0.071 [0.000, 24.000], loss: 0.001166, mean_absolute_error: 0.025190, mean_q: -0.019775
#    5177/500000: episode: 97, duration: 1.422s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.131 [-0.244, 1.010], mean observation: 0.072 [0.000, 24.000], loss: 0.001160, mean_absolute_error: 0.025581, mean_q: -0.020680
#    5202/500000: episode: 98, duration: 1.490s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.228 [-0.148, 1.205], mean observation: 0.065 [0.000, 24.000], loss: 0.001018, mean_absolute_error: 0.025050, mean_q: -0.027162
#    5227/500000: episode: 99, duration: 1.449s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.090 [-0.453, 0.944], mean observation: 0.071 [0.000, 24.000], loss: 0.000990, mean_absolute_error: 0.024159, mean_q: -0.026757
#    5252/500000: episode: 100, duration: 1.389s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.195 [-0.301, 1.143], mean observation: 0.072 [0.000, 24.000], loss: 0.000987, mean_absolute_error: 0.024312, mean_q: -0.023168
#    5277/500000: episode: 101, duration: 1.389s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.155 [-0.259, 1.070], mean observation: 0.072 [0.000, 24.000], loss: 0.000950, mean_absolute_error: 0.024654, mean_q: -0.020017
#    5302/500000: episode: 102, duration: 1.426s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.150 [-0.190, 1.156], mean observation: 0.072 [0.000, 24.000], loss: 0.001038, mean_absolute_error: 0.025178, mean_q: -0.014029
#    5327/500000: episode: 103, duration: 1.309s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.176 [-0.155, 1.111], mean observation: 0.071 [0.000, 24.000], loss: 0.001053, mean_absolute_error: 0.025740, mean_q: -0.027039
#    5352/500000: episode: 104, duration: 1.329s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.204 [-0.272, 1.180], mean observation: 0.072 [0.000, 24.000], loss: 0.001055, mean_absolute_error: 0.024801, mean_q: -0.018013
#    5377/500000: episode: 105, duration: 1.402s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.177 [-0.197, 1.042], mean observation: 0.071 [0.000, 24.000], loss: 0.001090, mean_absolute_error: 0.025473, mean_q: -0.021900
#    5402/500000: episode: 106, duration: 1.401s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.206 [-0.123, 1.205], mean observation: 0.072 [0.000, 24.000], loss: 0.001520, mean_absolute_error: 0.027838, mean_q: -0.023661
#    5427/500000: episode: 107, duration: 1.449s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.153 [-0.161, 1.112], mean observation: 0.072 [0.000, 24.000], loss: 0.001043, mean_absolute_error: 0.025832, mean_q: -0.028717
#    5452/500000: episode: 108, duration: 1.365s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0
, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.119 [-0.349, 1.059], mean observation: 0.071 [0.000, 24.000], loss: 0.001310, mean_absolute_error: 0.025261, mean_q: -0.029429
#    6327/500000: episode: 143, duration: 1.420s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.126 [-0.236, 1.058], mean observation: 0.071 [0.000, 24.000], loss: 0.001216, mean_absolute_error: 0.027997, mean_q: -0.030944
#    6352/500000: episode: 144, duration: 1.427s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.206 [-0.120, 1.237], mean observation: 0.072 [0.000, 24.000], loss: 0.000979, mean_absolute_error: 0.024305, mean_q: -0.038140
#    6377/500000: episode: 145, duration: 1.333s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.137 [-0.137, 1.034], mean observation: 0.072 [0.000, 24.000], loss: 0.000974, mean_absolute_error: 0.024231, mean_q: -0.033994
#    6402/500000: episode: 146, duration: 1.356s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.191 [-0.144, 1.079], mean observation: 0.071 [0.000, 24.000], loss: 0.000902, mean_absolute_error: 0.023659, mean_q: -0.031841
#    6427/500000: episode: 147, duration: 1.356s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.212 [-0.106, 1.219], mean observation: 0.071 [0.000, 24.000], loss: 0.001194, mean_absolute_error: 0.025433, mean_q: -0.040043
#    6452/500000: episode: 148, duration: 1.362s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.185 [-0.253, 1.066], mean observation: 0.071 [0.000, 24.000], loss: 0.001103, mean_absolute_error: 0.025159, mean_q: -0.041006
#    6477/500000: episode: 149, duration: 1.486s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.149 [-0.279, 1.091], mean observation: 0.072 [0.000, 24.000], loss: 0.001318, mean_absolute_error: 0.027300, mean_q: -0.038876
#    6502/500000: episode: 150, duration: 1.393s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.187 [-0.177, 1.160], mean observation: 0.072 [0.000, 24.000], loss: 0.001151, mean_absolute_error: 0.024585, mean_q: -0.043492
#    6527/500000: episode: 151, duration: 1.382s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.145 [-0.358, 1.020], mean observation: 0.072 [0.000, 24.000], loss: 0.001060, mean_absolute_error: 0.025225, mean_q: -0.045174
#    6552/500000: episode: 152, duration: 1.397s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.167 [-0.148, 1.042], mean observation: 0.072 [0.000, 24.000], loss: 0.001132, mean_absolute_error: 0.025099, mean_q: -0.047145
#    6577/500000: episode: 153, duration: 1.472s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.162 [-0.312, 1.318], mean observation: 0.072 [0.000, 24.000], loss: 0.001015, mean_absolute_error: 0.023876, mean_q: -0.046658
#    6602/500000: episode: 154, duration: 1.436s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.188 [-0.242, 1.046], mean observation: 0.071 [0.000, 24.000], loss: 0.001301, mean_absolute_error: 0.025191, mean_q: -0.042590
#    6627/500000: episode: 155, duration: 1.371s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.185 [-0.255, 1.012], mean observation: 0.072 [0.000, 24.000], loss: 0.001070, mean_absolute_error: 0.025359, mean_q: -0.049886
#    6652/500000: episode: 156, duration: 1.365s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.168 [-0.216, 1.224], mean observation: 0.071 [0.000, 24.000], loss: 0.001094, mean_absolute_error: 0.024677, mean_q: -0.057738
#    6677/500000: episode: 157, duration: 1.350s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.201 [-0.146, 1.320], mean observation: 0.072 [0.000, 24.000], loss: 0.001223, mean_absolute_error: 0.025530, mean_q: -0.048507
#    6702/500000: episode: 158, duration: 1.315s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.144 [-0.201, 0.980], mean observation: 0.072 [0.000, 24.000], loss: 0.001023, mean_absolute_error: 0.023567, mean_q: -0.042560
#    6727/500000: episode: 159, duration: 1.441s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.177 [-0.281, 1.019], mean observation: 0.068 [0.000, 24.000], loss: 0.001087, mean_absolute_error: 0.024241, mean_q: -0.054959
#    6752/500000: episode: 160, duration: 1.424s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.140 [-0.332, 1.044], mean observation: 0.071 [0.000, 24.000], loss: 0.000993, mean_absolute_error: 0.024594, mean_q: -0.036846
#    6777/500000: episode: 161, duration: 1.268s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.228 [-0.064, 1.082], mean observation: 0.072 [0.000, 24.000], loss: 0.000921, mean_absolute_error: 0.024699, mean_q: -0.040260
#    6802/500000: episode: 162, duration: 1.399s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.156 [-0.290, 1.191], mean observation: 0.072 [0.000, 24.000], loss: 0.001062, mean_absolute_error: 0.025927, mean_q: -0.034216
#    6827/500000: episode: 163, duration: 1.334s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.135 [-0.205, 1.024], mean observation: 0.071 [0.000, 24.000], loss: 0.000982, mean_absolute_error: 0.025271, mean_q: -0.043439
#    6852/500000: episode: 164, duration: 1.391s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.190 [-0.102, 1.086], mean observation: 0.072 [0.000, 24.000], loss: 0.001022, mean_absolute_error: 0.025970, mean_q: -0.047738
#    6877/500000: episode: 165, duration: 1.372s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.211 [-0.126, 1.324], mean observation: 0.071 [0.000, 24.000], loss: 0.001074, mean_absolute_error: 0.025186, mean_q: -0.045830
# ...
#   29062/500000: episode: 466, duration: 15.289s, episode steps: 265, steps per second: 17, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.089 [-0.693, 1.647], mean observation: 0.060 [0.000, 24.000], loss: 0.000912, mean_absolute_error: 0.026462, mean_q: -0.152616
#   29088/500000: episode: 467, duration: 1.438s, episode steps: 26, steps per second: 18, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 0.161 [-0.139, 1.127], mean observation: 0.071 [0.000, 24.000], loss: 0.000909, mean_absolute_error: 0.026563, mean_q: -0.156682
#   29191/500000: episode: 468, duration: 5.516s, episode steps: 103, steps per second: 19, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 0.178 [-0.335, 1.196], mean observation: 0.055 [0.000, 24.000], loss: 0.000960, mean_absolute_error: 0.026557, mean_q: -0.149307
#   29277/500000: episode: 469, duration: 4.671s, episode steps: 86, steps per second: 18, episode reward: -1.000, mean reward: -0.012 [-1.000, 0.000], mean action: 0.151 [-0.339, 1.245], mean observation: 0.069 [0.000, 24.000], loss: 0.000887, mean_absolute_error: 0.025957, mean_q: -0.151088
#   29341/500000: episode: 470, duration: 3.423s, episode steps: 64, steps per second: 19, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 0.269 [-0.202, 1.400], mean observation: 0.066 [0.000, 24.000], loss: 0.000891, mean_absolute_error: 0.026239, mean_q: -0.150272
#   29400/500000: episode: 471, duration: 3.429s, episode steps: 59, steps per second: 17, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 0.156 [-0.414, 1.426], mean observation: 0.069 [0.000, 24.000], loss: 0.000896, mean_absolute_error: 0.026761, mean_q: -0.151533
#   30404/500000: episode: 472, duration: 44.632s, episode steps: 1004, steps per second: 22, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.049 [-0.880, 1.472], mean observation: 0.040 [0.000, 24.000], loss: 0.000802, mean_absolute_error: 0.025357, mean_q: -0.153117
#   30431/500000: episode: 473, duration: 1.417s, episode steps: 27, steps per second: 19, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 0.175 [-0.272, 1.079], mean observation: 0.071 [0.000, 24.000], loss: 0.000780, mean_absolute_error: 0.026485, mean_q: -0.154278
#   30486/500000: episode: 474, duration: 2.946s, episode steps: 55, steps per second: 19, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 0.287 [-0.038, 1.155], mean observation: 0.065 [0.000, 24.000], loss: 0.000715, mean_absolute_error: 0.024323, mean_q: -0.150734
#   30514/500000: episode: 475, duration: 1.515s, episode steps: 28, steps per second: 18, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 0.112 [-0.405, 1.063], mean observation: 0.071 [0.000, 24.000], loss: 0.000722, mean_absolute_error: 0.025163, mean_q: -0.155458
#   30563/500000: episode: 476, duration: 2.698s, episode steps: 49, steps per second: 18, episode reward: -1.000, mean reward: -0.020 [-1.000, 0.000], mean action: 0.143 [-0.271, 1.178], mean observation: 0.067 [0.000, 24.000], loss: 0.000701, mean_absolute_error: 0.024292, mean_q: -0.161980
#   30764/500000: episode: 477, duration: 10.930s, episode steps: 201, steps per second: 18, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.076 [-0.488, 1.096], mean observation: 0.057 [0.000, 24.000], loss: 0.000753, mean_absolute_error: 0.024444, mean_q: -0.151618
#   30790/500000: episode: 478, duration: 1.525s, episode steps: 26, steps per second: 17, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 0.179 [-0.146, 1.210], mean observation: 0.071 [0.000, 24.000], loss: 0.000743, mean_absolute_error: 0.024817, mean_q: -0.160978
#   30817/500000: episode: 479, duration: 1.528s, episode steps: 27, steps per second: 18, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 0.170 [-0.191, 1.060], mean observation: 0.071 [0.000, 24.000], loss: 0.000772, mean_absolute_error: 0.024819, mean_q: -0.154185
#   30844/500000: episode: 480, duration: 1.469s, episode steps: 27, steps per second: 18, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 0.192 [-0.141, 1.165], mean observation: 0.063 [0.000, 24.000], loss: 0.000671, mean_absolute_error: 0.023880, mean_q: -0.158504
#   31184/500000: episode: 481, duration: 30.030s, episode steps: 340, steps per second: 11, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.252 [-0.931, 2.004], mean observation: 0.052 [0.000, 24.000], loss: 0.000770, mean_absolute_error: 0.025268, mean_q: -0.156148
#   31316/500000: episode: 482, duration: 7.243s, episode steps: 132, steps per second: 18, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 0.271 [-0.521, 1.435], mean observation: 0.067 [0.000, 24.000], loss: 0.000763, mean_absolute_error: 0.024875, mean_q: -0.149173
#   31341/500000: episode: 483, duration: 1.389s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.228 [-0.090, 1.322], mean observation: 0.072 [0.000, 24.000], loss: 0.001032, mean_absolute_error: 0.028536, mean_q: -0.141088
#   31401/500000: episode: 484, duration: 3.340s, episode steps: 60, steps per second: 18, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 0.079 [-0.371, 1.157], mean observation: 0.071 [0.000, 24.000], loss: 0.000870, mean_absolute_error: 0.026633, mean_q: -0.155199
#   31487/500000: episode: 485, duration: 4.645s, episode steps: 86, steps per second: 19, episode reward: -1.000, mean reward: -0.012 [-1.000, 0.000], mean action: 0.199 [-0.359, 1.273], mean observation: 0.063 [0.000, 24.000], loss: 0.000792, mean_absolute_error: 0.025128, mean_q: -0.153633
#   31537/500000: episode: 486, duration: 2.628s, episode steps: 50, steps per second: 19, episode reward: -1.000, mean reward: -0.020 [-1.000, 0.000], mean action: 0.078 [-0.363, 0.949], mean observation: 0.069 [0.000, 24.000], loss: 0.000807, mean_absolute_error: 0.025493, mean_q: -0.151239
#   31776/500000: episode: 487, duration: 13.164s, episode steps: 239, steps per second: 18, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.099 [-1.015, 1.500], mean observation: 0.059 [0.000, 24.000], loss: 0.000807, mean_absolute_error: 0.025625, mean_q: -0.152818
#   31889/500000: episode: 488, duration: 6.329s, episode steps: 113, steps per second: 18, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 0.126 [-0.699, 1.427], mean observation: 0.065 [0.000, 24.000], loss: 0.000874, mean_absolute_error: 0.026502, mean_q: -0.152982
#   31915/500000: episode: 489, duration: 1.461s, episode steps: 26, steps per second: 18, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 0.153 [-0.117, 1.021], mean observation: 0.071 [0.000, 24.000], loss: 0.000890, mean_absolute_error: 0.026364, mean_q: -0.150575
#   32292/500000: episode: 490, duration: 20.583s, episode steps: 377, steps per second: 18, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.059 [-0.884, 1.382], mean observation: 0.056 [0.000, 24.000], loss: 0.000882, mean_absolute_error: 0.026202, mean_q: -0.149184
#   32318/500000: episode: 491, duration: 1.490s, episode steps: 26, steps per second: 17, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 0.235 [-0.082, 1.087], mean observation: 0.071 [0.000, 24.000], loss: 0.000929, mean_absolute_error: 0.026443, mean_q: -0.142405
#   32401/500000: episode: 492, duration: 4.523s, episode steps: 83, steps per second: 18, episode reward: -1.000, mean reward: -0.012 [-1.000, 0.000], mean action: 0.175 [-0.267, 1.549], mean observation: 0.070 [0.000, 24.000], loss: 0.000934, mean_absolute_error: 0.027128, mean_q: -0.144192
#   32427/500000: episode: 493, duration: 1.438s, episode steps: 26, steps per second: 18, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 0.146 [-0.147, 1.034], mean observation: 0.059 [0.000, 24.000], loss: 0.000935, mean_absolute_error: 0.026258, mean_q: -0.147370
#   32879/500000: episode: 494, duration: 23.653s, episode steps: 452, steps per second: 19, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.069 [-1.080, 1.732], mean observation: 0.049 [0.000, 24.000], loss: 0.000889, mean_absolute_error: 0.026151, mean_q: -0.148363
#   32905/500000: episode: 495, duration: 1.472s, episode steps: 26, steps per second: 18, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 0.163 [-0.180, 1.012], mean observation: 0.071 [0.000, 24.000], loss: 0.000828, mean_absolute_error: 0.025729, mean_q: -0.139322
#   32935/500000: episode: 496, duration: 1.603s, episode steps: 30, steps per second: 19, episode reward: -1.000, mean reward: -0.033 [-1.000, 0.000], mean action: 0.174 [-0.342, 1.116], mean observation: 0.069 [0.000, 24.000], loss: 0.000943, mean_absolute_error: 0.026304, mean_q: -0.141462
#   34243/500000: episode: 497, duration: 65.734s, episode steps: 1308, steps per second: 20, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.117 [-1.080, 2.287], mean observation: 0.036 [0.000, 24.000], loss: 0.000842, mean_absolute_error: 0.025944, mean_q: -0.142484
#   34271/500000: episode: 498, duration: 1.569s, episode steps: 28, steps per second: 18, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 0.154 [-0.157, 1.017], mean observation: 0.071 [0.000, 24.000], loss: 0.000760, mean_absolute_error: 0.025222, mean_q: -0.135097
#   36263/500000: episode: 499, duration: 96.187s, episode steps: 1992, steps per second: 21, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.200 [-1.404, 1.817], mean observation: 0.037 [0.000, 24.000], loss: 0.000710, mean_absolute_error: 0.024574, mean_q: -0.139282
#   36291/500000: episode: 500, duration: 1.554s, episode steps: 28, steps per second: 18, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 0.134 [-0.418, 1.056], mean observation: 0.070 [0.000, 24.000], loss: 0.000605, mean_absolute_error: 0.022599, mean_q: -0.131074
#   36421/500000: episode: 501, duration: 7.497s, episode steps: 130, steps per second: 17, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 0.158 [-0.593, 1.386], mean observation: 0.065 [0.000, 24.000], loss: 0.000615, mean_absolute_error: 0.022744, mean_q: -0.139510
#   36765/500000: episode: 502, duration: 17.873s, episode steps: 344, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.029 [-1.067, 1.333], mean observation: 0.048 [0.000, 24.000], loss: 0.000662, mean_absolute_error: 0.023656, mean_q: -0.140634
#   37342/500000: episode: 503, duration: 30.185s, episode steps: 577, steps per second: 19, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.452 [-0.659, 2.054], mean observation: 0.047 [0.000, 24.000], loss: 0.000714, mean_absolute_error: 0.024322, mean_q: -0.141161
#   37455/500000: episode: 504, duration: 5.966s, episode steps: 113, steps per second: 19, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 0.167 [-0.444, 1.307], mean observation: 0.067 [0.000, 24.000], loss: 0.000735, mean_absolute_error: 0.024143, mean_q: -0.147808
#   37586/500000: episode: 505, duration: 7.008s, episode steps: 131, steps per second: 19, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 0.220 [-0.406, 1.505], mean observation: 0.056 [0.000, 24.000], loss: 0.000747, mean_absolute_error: 0.024711, mean_q: -0.141003
#   37866/500000: episode: 506, duration: 14.463s, episode steps: 280, steps per second: 19, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.205 [-0.707, 1.529], mean observation: 0.057 [0.000, 24.000], loss: 0.000765, mean_absolute_error: 0.024857, mean_q: -0.144907
#   37921/500000: episode: 507, duration: 2.877s, episode steps: 55, steps per second: 19, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 0.187 [-0.126, 1.144], mean observation: 0.067 [0.000, 24.000], loss: 0.000827, mean_absolute_error: 0.024170, mean_q: -0.148779
#   38308/500000: episode: 508, duration: 19.226s, episode steps: 387, steps per second: 20, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.043 [-0.836, 1.585], mean observation: 0.050 [0.000, 24.000], loss: 0.000764, mean_absolute_error: 0.024705, mean_q: -0.144173
#   38336/500000: episode: 509, duration: 1.505s, episode steps: 28, steps per second: 19, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 0.168 [-0.149, 1.048], mean observation: 0.070 [0.000, 24.000], loss: 0.000756, mean_absolute_error: 0.024188, mean_q: -0.153980
#   38365/500000: episode: 510, duration: 1.614s, episode steps: 29, steps per second: 18, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 0.154 [-0.257, 1.153], mean observation: 0.068 [0.000, 24.000], loss: 0.000716, mean_absolute_error: 0.024111, mean_q: -0.142069
#   38506/500000: episode: 511, duration: 7.560s, episode steps: 141, steps per second: 19, episode reward: -1.000, mean reward: -0.007 [-1.000, 0.000], mean action: 0.208 [-0.673, 1.207], mean observation: 0.058 [0.000, 24.000], loss: 0.000773, mean_absolute_error: 0.024661, mean_q: -0.141585
#   38665/500000: episode: 512, duration: 8.593s, episode steps: 159, steps per second: 19, episode reward: -1.000, mean reward: -0.006 [-1.000, 0.000], mean action: 0.164 [-0.448, 1.293], mean observation: 0.063 [0.000, 24.000], loss: 0.000819, mean_absolute_error: 0.025552, mean_q: -0.144569
#   38963/500000: episode: 513, duration: 15.620s, episode steps: 298, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.168 [-0.453, 1.367], mean observation: 0.055 [0.000, 24.000], loss: 0.000788, mean_absolute_error: 0.025281, mean_q: -0.140075
#   39288/500000: episode: 514, duration: 16.730s, episode steps: 325, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.254 [-0.736, 2.026], mean observation: 0.053 [0.000, 24.000], loss: 0.000785, mean_absolute_error: 0.025236, mean_q: -0.141046
#   39410/500000: episode: 515, duration: 6.584s, episode steps: 122, steps per second: 19, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 0.082 [-0.441, 1.071], mean observation: 0.055 [0.000, 24.000], loss: 0.000810, mean_absolute_error: 0.025637, mean_q: -0.148778
#   39519/500000: episode: 516, duration: 5.962s, episode steps: 109, steps per second: 18, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 0.230 [-0.687, 1.442], mean observation: 0.065 [0.000, 24.000], loss: 0.000804, mean_absolute_error: 0.025504, mean_q: -0.144417
#   39812/500000: episode: 517, duration: 16.186s, episode steps: 293, steps per second: 18, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.188 [-0.785, 1.533], mean observation: 0.060 [0.000, 24.000], loss: 0.000821, mean_absolute_error: 0.025517, mean_q: -0.145370
#   40006/500000: episode: 518, duration: 10.672s, episode steps: 194, steps per second: 18, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.142 [-0.699, 1.322], mean observation: 0.061 [0.000, 24.000], loss: 0.000877, mean_absolute_error: 0.026307, mean_q: -0.141493
#   40340/500000: episode: 519, duration: 18.019s, episode steps: 334, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.172 [-0.610, 1.705], mean observation: 0.055 [0.000, 24.000], loss: 0.000931, mean_absolute_error: 0.027026, mean_q: -0.144505

# %%
agent.save_weights(model_path, overwrite=True)
