# %%
import os
import shutil
import pommerman
import numpy as np
import tensorflow as tf

from pommerman.agents import BaseAgent, SimpleAgent
from pommerman.configs import ffa_v0_env
from pommerman.constants import BOARD_SIZE
from pommerman.envs.v0 import Pomme
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from keras.utils import to_categorical
# Immitation Learning: learn a mapping from observations to actions.
from pomm_network import PommNetwork
# Out:
# /gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
batch_size = 16384
epochs = 25
initial_rollouts = 120
num_rollouts = 50
iterations = 100
early_stopping = 6

# %%
class Agent:
    def __init__(self, actions, seed=0, save_path="./model/model.cptk", log_path='./logs/', save_best_model=True, learning_rate=1e-3):
        self.save_path = save_path
        self.actions = actions
        self.save_best_model = save_best_model
        self.seed = seed
        self.sess = tf.InteractiveSession()
        self.rewards = []
        self.cur_epoch = 0
        if os.path.isdir(log_path):
            try:
                os.removedirs(log_path)
            except:
                print("Cant delete log folder")

        # TODO hardcoded
        self.conv_ph = tf.placeholder(shape=[None, BOARD_SIZE, BOARD_SIZE, 3], name='conv_ph', dtype=tf.float32)
        self.state_ph = tf.placeholder(shape=[None, 3], name='state_ph', dtype=tf.float32)
        self.logits_ph = tf.placeholder(shape=[None, actions], name='logits_ph', dtype=tf.int32)

        network = PommNetwork.create_network({'board': self.conv_ph, 'state': self.state_ph})
        logits = tf.layers.dense(network, actions)
        self.sampled_action = tf.squeeze(tf.multinomial(logits, 1), axis=[1])
        sy_logprob_n = tf.nn.softmax_cross_entropy_with_logits(labels=self.logits_ph, logits=logits)
        self.loss = tf.reduce_mean(sy_logprob_n)  # Loss function that we'll differentiate to get the policy gradient.
        self.train_step = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(self.loss)
        self.train_writer = tf.summary.FileWriter(log_path + "train", self.sess.graph)
        self.test_writer = tf.summary.FileWriter(log_path + "test")
        self.sess.run(tf.global_variables_initializer())
        self.saver = tf.train.Saver()
        if os.path.isdir(os.path.dirname(self.save_path)):
            try:
                print("Trying to load model")
                self.saver.restore(self.sess, self.save_path)
                print("Model was loaded successful")
            except:
                print("Model load failed")

    def __run_batch(self, X, y, batch_size, training=True):
        accuracies = []
        losses = []
        size = X.shape[-1]
        batches = int(np.ceil(size / batch_size))
        for i in range(batches):
            X_batch, y_batch = None, None
            if i == batches - 1:
                X_batch = X[i * batch_size:]
                y_batch = y[i * batch_size:]
            else:
                X_batch = X[i * batch_size: (i + 1) * batch_size]
                y_batch = y[i * batch_size: (i + 1) * batch_size]
            board = []
            state = []
            for i in range(X_batch.shape[-1]):
                val = self.featurize(X_batch[i])
                board.append(val['board'])
                state.append(val['state'])
            y_batch = np.array(y_batch).reshape(-1)
            feed_dict = {self.conv_ph: board, self.state_ph: state, self.logits_ph: to_categorical(y_batch, self.actions)}
            if training:
                _, loss, actions = self.sess.run([self.train_step, self.loss, self.sampled_action], feed_dict=feed_dict)
            else:
                loss, actions = self.sess.run([self.loss, self.sampled_action], feed_dict=feed_dict)
            accuracies.append(accuracy_score(actions, y_batch))
            losses.append(loss)
        return np.mean(accuracies), np.mean(losses)

    def train(self, obs, labels, batch_size, epochs, early_stopping = 6):
        print("Train the agent with %i training data, batch_size %i, epochs %i" % (obs.shape[0], batch_size, epochs))
        train_obs, val_obs, train_labels, val_labels = train_test_split(obs, labels, test_size=0.2, random_state=self.seed)
        best_loss = np.inf
        not_improved = 0
        for i in range(epochs):
            train_acc, train_loss = self.__run_batch(train_obs, train_labels, batch_size)
            val_acc, val_loss = self.__run_batch(val_obs, val_labels, batch_size, training=False)
            print("Epoch %d: train_acc %f, train_loss %f, test_acc %f, test_loss: %f" % (i + 1, train_acc, train_loss, val_acc, val_loss))

            summary = tf.summary.Summary()
            summary.value.add(tag="Train acc", simple_value=train_acc)
            summary.value.add(tag="Train loss", simple_value=train_loss)
            self.train_writer.add_summary(summary, self.cur_epoch)
            summary.value.add(tag="Val acc", simple_value=val_acc)
            summary.value.add(tag="Val loss", simple_value=val_loss)
            self.test_writer.add_summary(summary, self.cur_epoch)
            self.cur_epoch += 1
            if not_improved > early_stopping:
                print("Early stopping")
                break
            try:
                if self.save_best_model:
                    if val_loss < best_loss:
                        not_improved = 0
                        print("Saving model")
                        self.saver.save(self.sess, self.save_path)
                        print("Model was saved successfully")
                        best_loss = val_loss
                    else:
                        not_improved += 1
                else:
                    print("Saving model")
                    self.saver.save(self.sess, self.save_path)
                    print("Model was saved successfully")
            except:
                print("Failed save model")

    @staticmethod
    def featurize(obs):
        def get_matrix(dict, key):
            res = dict[key]
            return res.reshape(res.shape[0], res.shape[1], 1).astype(np.float32)

        board = get_matrix(obs, 'board')
        teammate_position = None
        teammate = obs["teammate"]
        if teammate is not None:
            teammate = teammate.value
            if teammate > 10 and teammate < 15:
                teammate_position = np.argwhere(board == teammate)[0]
        else:
            teammate = None
        # My self - 11
        # Team mate - 12
        # Enemy - 13

        # Everyone enemy
        board[(board > 10) & (board < 15)] = 13
        # I'm not enemy
        my_position = obs['position']
        board[my_position[0], my_position[1], 0] = 11
        # Set teammate
        if teammate_position is not None:
            board[teammate_position[0], teammate_position[1], teammate_position[2]] = 12

        bomb_blast_strength = get_matrix(obs, 'bomb_blast_strength')
        bomb_life = get_matrix(obs, 'bomb_life')
        conv_inp = np.concatenate([board, bomb_blast_strength, bomb_life], axis=2)
        state = np.array([obs["ammo"], obs["blast_strength"], obs["can_kick"]]).astype(np.float32)
        return dict(board=conv_inp, state=state)

    def clear_training_history(self):
        self.history = []

    def act(self, obs):
        obs = self.featurize(obs)
        board = np.expand_dims(obs['board'], axis=0)
        state = np.expand_dims(obs['state'], axis=0)
        res = self.sess.run(self.sampled_action, feed_dict={self.conv_ph: board, self.state_ph: state})
        return res

    def record_reward(self, reward):
        self.rewards.append(np.mean(reward))

    def close(self):
        self.sess.close()

# %%
# Simple wrapper around policy function to have an act function
class Expert:
    def __init__(self, config):
        self.__agent = SimpleAgent(config)

    def act(self, obs):
        return self.__agent.act(obs, None)

    def record_reward(self, reward):
        pass


class TensorforceAgent(BaseAgent):
    def act(self, obs, action_space):
        pass


# Environment wrapper
class Stimulator:
    def __init__(self, env, config):
        self.env = env
        self.init(config)

    def init(self, config):
        self.env.seed(0)
        # Add 3 random agents
        agents = []
        for agent_id in range(3):
            agents.append(SimpleAgent(config["agent"](agent_id, config["game_type"])))

        # Add TensorforceAgent
        agent_id += 1
        agents.append(TensorforceAgent(config["agent"](agent_id, config["game_type"])))
        self.env.set_agents(agents)
        self.env.set_training_agent(agents[-1].agent_id)
        self.env.set_init_game_state(None)

    def stimulate(self, agent, num_rollouts, render):
        returns = []
        observations = []
        actions = []
        for i in range(num_rollouts):
            obs = self.env.reset()[self.env.training_agent]
            done = False
            totalr = 0.
            steps = 0
            while not done:
                if render:
                    self.env.render()

                action = agent.act(obs)
                obs = self.env.get_observations()
                all_actions = self.env.act(obs)
                all_actions.insert(self.env.training_agent, action)
                state, reward, done, _ = self.env.step(all_actions)

                obs = state[self.env.training_agent]
                r = reward[self.env.training_agent]
                totalr += r
                steps += 1

                observations.append(obs)
                actions.append(action)

            print('rollout %i/%i return=%f' % (i + 1, num_rollouts, totalr))
            returns.append(totalr)
        print('Return summary: mean=%f, std=%f' % (np.mean(returns), np.std(returns)))
        agent.record_reward(returns)
        return (np.array(observations), np.array(actions))

    def label_obs(self, expert, obs):
        actions = []
        for o in obs:
            actions.append(expert.act(o))
        return np.array(actions)

# %%
# Instantiate the environment
config = ffa_v0_env()
env = Pomme(**config["env_kwargs"])
states = {
    "board": dict(shape=(BOARD_SIZE, BOARD_SIZE, 3,), type='float'),
    "state": dict(shape=(3,), type='float')
}
agent_dagger = Agent(env.action_space.n)
# Load Expert
expert = Expert(config["agent"](0, config["game_type"]))

# Generate training data
stimulator = Stimulator(env, config)
training_data = stimulator.stimulate(expert, num_rollouts=initial_rollouts, render=False)
# Train DAgger Agent
obs = training_data[0]
labls = training_data[1]
for i in range(2, iterations):
    print("Train with DAgger, iter %i" % i)
    (stimulated_env, _) = stimulator.stimulate(agent_dagger, num_rollouts=num_rollouts, render=False)
    labels = stimulator.label_obs(expert, stimulated_env)
    obs = np.append(obs, stimulated_env, axis=0)
    labls = np.append(labls, labels, axis=0)
    agent_dagger.train(obs, labls, batch_size=batch_size, epochs=epochs, early_stopping=early_stopping)
agent_dagger.close()
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Cant delete log folder
# Trying to load model
# INFO:tensorflow:Restoring parameters from ./model/model.cptk
# Model was loaded successful
# rollout 1/120 return=-1.000000
# rollout 2/120 return=-1.000000
# rollout 3/120 return=-1.000000
# rollout 4/120 return=-1.000000
# rollout 5/120 return=-1.000000
# rollout 6/120 return=-1.000000
# rollout 7/120 return=-1.000000
# rollout 8/120 return=-1.000000
# rollout 9/120 return=1.000000
# rollout 10/120 return=-1.000000
# rollout 11/120 return=1.000000
# rollout 12/120 return=-1.000000
# rollout 13/120 return=-1.000000
# rollout 14/120 return=-1.000000
# rollout 15/120 return=-1.000000
# rollout 16/120 return=-1.000000
# rollout 17/120 return=-1.000000
# rollout 18/120 return=-1.000000
# rollout 19/120 return=-1.000000
# rollout 20/120 return=1.000000
# rollout 21/120 return=-1.000000
# rollout 22/120 return=-1.000000
# rollout 23/120 return=-1.000000
# rollout 24/120 return=-1.000000
# rollout 25/120 return=-1.000000
# rollout 26/120 return=-1.000000
# rollout 27/120 return=-1.000000
# rollout 28/120 return=-1.000000
# rollout 29/120 return=-1.000000
# rollout 30/120 return=-1.000000
# rollout 31/120 return=-1.000000
# rollout 32/120 return=-1.000000
# rollout 33/120 return=-1.000000
# rollout 34/120 return=1.000000
# rollout 35/120 return=-1.000000
# rollout 36/120 return=-1.000000
# rollout 37/120 return=-1.000000
# rollout 38/120 return=-1.000000
# rollout 39/120 return=-1.000000
# rollout 40/120 return=-1.000000
# rollout 41/120 return=-1.000000
# rollout 56/120 return=-1.000000
# rollout 57/120 return=-1.000000
# rollout 58/120 return=-1.000000
# rollout 59/120 return=-1.000000
# rollout 60/120 return=-1.000000
# rollout 61/120 return=-1.000000
# rollout 62/120 return=-1.000000
# rollout 63/120 return=-1.000000
# rollout 64/120 return=-1.000000
# rollout 65/120 return=-1.000000
# rollout 66/120 return=-1.000000
# rollout 67/120 return=-1.000000
# rollout 68/120 return=-1.000000
# rollout 69/120 return=1.000000
# rollout 70/120 return=1.000000
# rollout 71/120 return=-1.000000
# rollout 72/120 return=-1.000000
# rollout 73/120 return=-1.000000
# rollout 74/120 return=-1.000000
# rollout 75/120 return=1.000000
# rollout 76/120 return=-1.000000
# rollout 77/120 return=1.000000
# rollout 78/120 return=-1.000000
# rollout 79/120 return=-1.000000
# rollout 80/120 return=-1.000000
# rollout 81/120 return=-1.000000
# rollout 82/120 return=-1.000000
# rollout 83/120 return=-1.000000
# rollout 84/120 return=-1.000000
# rollout 85/120 return=-1.000000
# rollout 86/120 return=1.000000
# rollout 87/120 return=-1.000000
# rollout 88/120 return=-1.000000
# rollout 89/120 return=1.000000
# rollout 90/120 return=-1.000000
# rollout 91/120 return=-1.000000
# rollout 92/120 return=1.000000
# rollout 93/120 return=-1.000000
# rollout 94/120 return=-1.000000
# rollout 95/120 return=-1.000000
# rollout 96/120 return=-1.000000
# rollout 97/120 return=1.000000
# rollout 98/120 return=-1.000000
# rollout 99/120 return=-1.000000
# rollout 100/120 return=-1.000000
# rollout 101/120 return=-1.000000
# rollout 102/120 return=1.000000
# rollout 103/120 return=-1.000000
# rollout 104/120 return=1.000000
# rollout 105/120 return=-1.000000
# rollout 106/120 return=-1.000000
# rollout 107/120 return=-1.000000
# rollout 108/120 return=-1.000000
# rollout 109/120 return=-1.000000
# rollout 110/120 return=-1.000000
# rollout 111/120 return=-1.000000
# rollout 112/120 return=-1.000000
# rollout 113/120 return=-1.000000
# rollout 114/120 return=-1.000000
# rollout 115/120 return=-1.000000
# rollout 116/120 return=1.000000
# rollout 117/120 return=-1.000000
# rollout 118/120 return=-1.000000
# rollout 119/120 return=-1.000000
# rollout 120/120 return=-1.000000
# Return summary: mean=-0.700000, std=0.714143
# Train with DAgger, iter 2
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 80537 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.348897, train_loss 2.254147, test_acc 0.356034, test_loss: 1.295211
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.400980, train_loss 1.252744, test_acc 0.423330, test_loss: 1.205858
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.423934, train_loss 1.186474, test_acc 0.427862, test_loss: 1.174327
# Saving model
# Model was saved successfully
# Epoch 4: train_acc 0.437730, train_loss 1.148386, test_acc 0.450646, test_loss: 1.139738
# Saving model
# Model was saved successfully
# Epoch 5: train_acc 0.452720, train_loss 1.110269, test_acc 0.466663, test_loss: 1.110492
# Saving model
# Model was saved successfully
# Epoch 6: train_acc 0.471677, train_loss 1.072733, test_acc 0.470884, test_loss: 1.079999
# Saving model
# Model was saved successfully
# Epoch 7: train_acc 0.483982, train_loss 1.036776, test_acc 0.482804, test_loss: 1.050308
# Saving model
# Model was saved successfully
# Epoch 8: train_acc 0.498595, train_loss 1.001115, test_acc 0.497765, test_loss: 1.023569
# Saving model
# Model was saved successfully
# Epoch 9: train_acc 0.512048, train_loss 0.971879, test_acc 0.519059, test_loss: 1.020469
# Saving model
# Model was saved successfully
# Epoch 10: train_acc 0.527008, train_loss 0.944020, test_acc 0.516389, test_loss: 1.006802
# Saving model
# Model was saved successfully
# Epoch 11: train_acc 0.535831, train_loss 0.922144, test_acc 0.525267, test_loss: 0.979980
# Saving model
# Model was saved successfully
# Epoch 12: train_acc 0.540823, train_loss 0.895102, test_acc 0.535759, test_loss: 0.985897
# Epoch 13: train_acc 0.559719, train_loss 0.874187, test_acc 0.518252, test_loss: 0.996082
# Epoch 14: train_acc 0.550386, train_loss 0.876528, test_acc 0.542401, test_loss: 0.993084
# Epoch 15: train_acc 0.567345, train_loss 0.841176, test_acc 0.554010, test_loss: 0.973738
# Saving model
# Model was saved successfully
# Epoch 16: train_acc 0.578440, train_loss 0.811094, test_acc 0.555500, test_loss: 0.990829
# Epoch 17: train_acc 0.585667, train_loss 0.790888, test_acc 0.562081, test_loss: 0.985900
# Epoch 18: train_acc 0.596750, train_loss 0.774486, test_acc 0.562453, test_loss: 1.018052
# Epoch 19: train_acc 0.599050, train_loss 0.768984, test_acc 0.560032, test_loss: 0.997600
# Epoch 20: train_acc 0.600714, train_loss 0.777902, test_acc 0.565185, test_loss: 0.978454
# Epoch 21: train_acc 0.601764, train_loss 0.769382, test_acc 0.553079, test_loss: 0.977729
# Epoch 22: train_acc 0.604630, train_loss 0.751045, test_acc 0.563509, test_loss: 0.962893
# Saving model
# Model was saved successfully
# Epoch 23: train_acc 0.619530, train_loss 0.712345, test_acc 0.569779, test_loss: 0.974022
# Epoch 24: train_acc 0.626516, train_loss 0.687756, test_acc 0.573131, test_loss: 0.981852
# Epoch 25: train_acc 0.644083, train_loss 0.661887, test_acc 0.583623, test_loss: 1.028240
# Train with DAgger, iter 3
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 85852 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.635982, train_loss 0.737640, test_acc 0.618288, test_loss: 0.790134
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.648414, train_loss 0.656706, test_acc 0.631466, test_loss: 0.790056
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.669675, train_loss 0.613099, test_acc 0.640796, test_loss: 0.817165
# Epoch 4: train_acc 0.686909, train_loss 0.584749, test_acc 0.645376, test_loss: 0.798371
# Epoch 5: train_acc 0.700124, train_loss 0.556006, test_acc 0.644278, test_loss: 0.810484
# Epoch 6: train_acc 0.711276, train_loss 0.535082, test_acc 0.645945, test_loss: 0.818171
# Epoch 7: train_acc 0.715854, train_loss 0.525523, test_acc 0.635652, test_loss: 0.913107
# Epoch 8: train_acc 0.715539, train_loss 0.534112, test_acc 0.639528, test_loss: 0.885901
# Epoch 9: train_acc 0.712667, train_loss 0.541740, test_acc 0.632578, test_loss: 0.884004
# Epoch 10: train_acc 0.710676, train_loss 0.535385, test_acc 0.650942, test_loss: 0.911388
# Early stopping
# Train with DAgger, iter 4
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 91797 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.657430, train_loss 0.829373, test_acc 0.616280, test_loss: 0.804383
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.647231, train_loss 0.673744, test_acc 0.640952, test_loss: 0.764315
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.675467, train_loss 0.611024, test_acc 0.652438, test_loss: 0.750759
# Saving model
# Model was saved successfully
# Epoch 4: train_acc 0.697562, train_loss 0.560017, test_acc 0.669817, test_loss: 0.753812
# Epoch 5: train_acc 0.720441, train_loss 0.520325, test_acc 0.675674, test_loss: 0.778336
# Epoch 6: train_acc 0.732784, train_loss 0.490573, test_acc 0.678517, test_loss: 0.783069
# Epoch 7: train_acc 0.742886, train_loss 0.467065, test_acc 0.678487, test_loss: 0.807988
# Epoch 8: train_acc 0.749224, train_loss 0.455682, test_acc 0.679103, test_loss: 0.857900
# Epoch 9: train_acc 0.750815, train_loss 0.465629, test_acc 0.680456, test_loss: 0.818693
# Epoch 10: train_acc 0.742948, train_loss 0.472471, test_acc 0.670673, test_loss: 0.829344
# Epoch 11: train_acc 0.747430, train_loss 0.462148, test_acc 0.671938, test_loss: 0.799474
# Early stopping
# Train with DAgger, iter 5
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 95032 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.742146, train_loss 0.519598, test_acc 0.690407, test_loss: 0.701678
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.748934, train_loss 0.467552, test_acc 0.693338, test_loss: 0.697227
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.756717, train_loss 0.439114, test_acc 0.700626, test_loss: 0.766976
# Epoch 4: train_acc 0.765519, train_loss 0.427914, test_acc 0.698309, test_loss: 0.717049
# Epoch 5: train_acc 0.778628, train_loss 0.394717, test_acc 0.700643, test_loss: 0.736546
# Epoch 6: train_acc 0.787385, train_loss 0.380663, test_acc 0.703769, test_loss: 0.746721
# Epoch 7: train_acc 0.793320, train_loss 0.363203, test_acc 0.706385, test_loss: 0.785154
# Epoch 8: train_acc 0.803150, train_loss 0.346193, test_acc 0.708948, test_loss: 0.812385
# Epoch 9: train_acc 0.808604, train_loss 0.334432, test_acc 0.698829, test_loss: 0.799403
# Epoch 10: train_acc 0.813485, train_loss 0.323749, test_acc 0.707385, test_loss: 0.823819
# Early stopping
# Train with DAgger, iter 6
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 98494 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.792097, train_loss 0.432531, test_acc 0.737928, test_loss: 0.652036
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.797970, train_loss 0.368242, test_acc 0.735479, test_loss: 0.651212
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.804395, train_loss 0.343468, test_acc 0.739710, test_loss: 0.662367
# Epoch 4: train_acc 0.813178, train_loss 0.325627, test_acc 0.736684, test_loss: 0.682860
# Epoch 5: train_acc 0.819783, train_loss 0.314017, test_acc 0.734192, test_loss: 0.689396
# Epoch 6: train_acc 0.824326, train_loss 0.301929, test_acc 0.735486, test_loss: 0.739524
# Epoch 7: train_acc 0.826629, train_loss 0.297273, test_acc 0.736125, test_loss: 0.748296
# Epoch 8: train_acc 0.831697, train_loss 0.293913, test_acc 0.735192, test_loss: 0.754197
# Epoch 9: train_acc 0.833199, train_loss 0.288274, test_acc 0.729554, test_loss: 0.778836
# Epoch 10: train_acc 0.833015, train_loss 0.290271, test_acc 0.733864, test_loss: 0.803940
# Early stopping
# Train with DAgger, iter 7
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 101771 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.817636, train_loss 0.372052, test_acc 0.758869, test_loss: 0.631269
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.820524, train_loss 0.329702, test_acc 0.764715, test_loss: 0.609645
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.823906, train_loss 0.309045, test_acc 0.765081, test_loss: 0.619856
# Epoch 4: train_acc 0.831388, train_loss 0.299715, test_acc 0.761792, test_loss: 0.640568
# Epoch 5: train_acc 0.835904, train_loss 0.287486, test_acc 0.750599, test_loss: 0.675131
# Epoch 6: train_acc 0.833769, train_loss 0.288765, test_acc 0.752788, test_loss: 0.686453
# Epoch 7: train_acc 0.835100, train_loss 0.293205, test_acc 0.754364, test_loss: 0.717295
# Epoch 8: train_acc 0.834725, train_loss 0.294021, test_acc 0.752918, test_loss: 0.756945
# Epoch 9: train_acc 0.829882, train_loss 0.307642, test_acc 0.749053, test_loss: 0.717486
# Epoch 10: train_acc 0.831283, train_loss 0.306391, test_acc 0.738196, test_loss: 0.735265
# Early stopping
# Train with DAgger, iter 8
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 105521 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.821507, train_loss 0.370402, test_acc 0.766717, test_loss: 0.580444
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.828511, train_loss 0.305015, test_acc 0.765604, test_loss: 0.603171
# Epoch 3: train_acc 0.835020, train_loss 0.293111, test_acc 0.763574, test_loss: 0.618100
# Epoch 4: train_acc 0.845695, train_loss 0.275359, test_acc 0.764536, test_loss: 0.609678
# Epoch 5: train_acc 0.852246, train_loss 0.259792, test_acc 0.762188, test_loss: 0.634877
# Epoch 6: train_acc 0.856214, train_loss 0.253628, test_acc 0.768321, test_loss: 0.638609
# Epoch 7: train_acc 0.859471, train_loss 0.243471, test_acc 0.766477, test_loss: 0.664094
# Epoch 8: train_acc 0.859153, train_loss 0.244163, test_acc 0.761472, test_loss: 0.692105
# Epoch 9: train_acc 0.859044, train_loss 0.251948, test_acc 0.749432, test_loss: 0.771255
# Early stopping
# Train with DAgger, iter 9
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# {(0, 4): None, (0, 5): None, (0, 6): None, (0, 7): None, (0, 8): None, (0, 9): None, (0, 10): None, (0, 11): None, (1, 3): None, (1, 4): None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None, (2, 9): None, (3, 7): None, (3, 9): None, (3, 11): None, (4, 6): None, (4, 7): None, (4, 8): None, (4, 9): None, (4, 11): None, (5, 8): None, (6, 9): None, (6, 11): None, (7, 9): None, (7, 11): None, (8, 11): None, (8, 12): None} None (1, 11)
# {(0, 4): None, (0, 5): None, (0, 6): None, (0, 7): None, (0, 8): None, (0, 9): None, (0, 10): None, (0, 11): None, (1, 3): None, (1, 4): None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None, (2, 9): None, (3, 7): None, (3, 9): None, (3, 11): None, (4, 6): None, (4, 7): None, (4, 8): None, (4, 9): None, (4, 11): None, (5, 8): None, (6, 9): None, (6, 11): None, (7, 9): None, (7, 11): None, (8, 11): None, (8, 12): None} None (1, 11)
# {(0, 4): None, (0, 5): None, (0, 6): None, (0, 7): None, (0, 8): None, (0, 9): None, (0, 10): None, (0, 11): None, (1, 3): None, (1, 4): None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None,
None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None, (2, 9): None, (3, 7): None, (3, 9): None, (3, 11): None, (4, 6): None, (4, 7): None, (4, 8): None, (4, 9): None, (4, 11): None, (5, 8): None, (6, 9): None, (6, 11): None, (7, 9): None, (7, 11): None, (8, 11): None, (8, 12): None} None (1, 11)
# Train the agent with 109733 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.822177, train_loss 0.389930, test_acc 0.774444, test_loss: 0.556122
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.826417, train_loss 0.314726, test_acc 0.772136, test_loss: 0.552621
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.833752, train_loss 0.291308, test_acc 0.781459, test_loss: 0.552148
# Saving model
# Model was saved successfully
# Epoch 4: train_acc 0.849002, train_loss 0.264888, test_acc 0.776272, test_loss: 0.558774
# Epoch 5: train_acc 0.855233, train_loss 0.250406, test_acc 0.781209, test_loss: 0.588486
# Epoch 6: train_acc 0.858694, train_loss 0.245655, test_acc 0.784304, test_loss: 0.591841
# Epoch 7: train_acc 0.863253, train_loss 0.235710, test_acc 0.774827, test_loss: 0.631118
# Epoch 8: train_acc 0.862542, train_loss 0.237524, test_acc 0.776620, test_loss: 0.643035
# Epoch 9: train_acc 0.862136, train_loss 0.240962, test_acc 0.777635, test_loss: 0.645302
# Epoch 10: train_acc 0.860803, train_loss 0.249545, test_acc 0.774885, test_loss: 0.631372
# Epoch 11: train_acc 0.859551, train_loss 0.245251, test_acc 0.774898, test_loss: 0.656113
# Early stopping
# Train with DAgger, iter 10
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 113734 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.848666, train_loss 0.312161, test_acc 0.802771, test_loss: 0.508093
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.853280, train_loss 0.263365, test_acc 0.800371, test_loss: 0.507767
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.859024, train_loss 0.241749, test_acc 0.804075, test_loss: 0.516575
# Epoch 4: train_acc 0.867351, train_loss 0.225790, test_acc 0.804461, test_loss: 0.520667
# Epoch 5: train_acc 0.870916, train_loss 0.215168, test_acc 0.797713, test_loss: 0.541445
# Epoch 6: train_acc 0.875624, train_loss 0.210473, test_acc 0.800942, test_loss: 0.558664
# Epoch 7: train_acc 0.877415, train_loss 0.207097, test_acc 0.805112, test_loss: 0.576097
# Epoch 8: train_acc 0.877264, train_loss 0.205721, test_acc 0.801022, test_loss: 0.603765
# Epoch 9: train_acc 0.879377, train_loss 0.207856, test_acc 0.803801, test_loss: 0.600071
# Epoch 10: train_acc 0.877871, train_loss 0.210649, test_acc 0.797277, test_loss: 0.587172
# Early stopping
# Train with DAgger, iter 11
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 119580 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.840921, train_loss 0.397596, test_acc 0.800072, test_loss: 0.510111
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.841930, train_loss 0.292616, test_acc 0.797293, test_loss: 0.505190
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.848930, train_loss 0.267744, test_acc 0.800786, test_loss: 0.479517
# Saving model
# Model was saved successfully
# Epoch 4: train_acc 0.859818, train_loss 0.239593, test_acc 0.806149, test_loss: 0.504275
# Epoch 5: train_acc 0.868933, train_loss 0.223726, test_acc 0.807046, test_loss: 0.520782
# Epoch 6: train_acc 0.874126, train_loss 0.213874, test_acc 0.806302, test_loss: 0.513653
# Epoch 7: train_acc 0.878028, train_loss 0.206410, test_acc 0.807028, test_loss: 0.527876
# Epoch 8: train_acc 0.879192, train_loss 0.209129, test_acc 0.808117, test_loss: 0.536357
# Epoch 9: train_acc 0.880443, train_loss 0.204935, test_acc 0.805557, test_loss: 0.576877
# Epoch 10: train_acc 0.881037, train_loss 0.208260, test_acc 0.804559, test_loss: 0.565341
# Epoch 11: train_acc 0.880634, train_loss 0.205226, test_acc 0.804371, test_loss: 0.551660
# Early stopping
# Train with DAgger, iter 12
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# {(0, 4): None, (0, 7): None, (0, 10): None, (0, 11): None, (0, 12): None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None, (1, 12): None, (2, 10): None, (2, 11): None, (3, 7): None, (3, 9): None, (3, 10): None, (3, 11): None, (4, 8): None, (4, 10): None, (5, 9): None, (6, 10): None, (6, 11): None, (7, 11): None} None (0, 12)
# {(0, 4): None, (0, 7): None, (0, 10): None, (0, 11): None, (0, 12): None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None,
None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None, (1, 12): None, (2, 10): None, (2, 11): None, (3, 7): None, (3, 9): None, (3, 10): None, (3, 11): None, (4, 8): None, (4, 10): None, (5, 9): None, (6, 10): None, (6, 11): None, (7, 11): None} None (0, 12)
# {(0, 4): None, (0, 7): None, (0, 10): None, (0, 11): None, (0, 12): None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None, (1, 12): None, (2, 10): None, (2, 11): None, (3, 7): None, (3, 9): None, (3, 10): None, (3, 11): None, (4, 8): None, (4, 10): None, (5, 9): None, (6, 10): None, (6, 11): None, (7, 11): None} None (0, 12)
# {(0, 4): None, (0, 7): None, (0, 10): None, (0, 11): None, (0, 12): None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None, (1, 12): None, (2, 10): None, (2, 11): None, (3, 7): None, (3, 9): None, (3, 10): None, (3, 11): None, (4, 8): None, (4, 10): None, (5, 9): None, (6, 10): None, (6, 11): None, (7, 11): None} None (0, 12)
# {(0, 4): None, (0, 7): None, (0, 10): None, (0, 11): None, (0, 12): None, (1, 5): None, (1, 6): None, (1, 7): None, (1, 8): None, (1, 9): None, (1, 10): None, (1, 11): None, (1, 12): None, (2, 10): None, (2, 11): None, (3, 7): None, (3, 9): None, (3, 10): None, (3, 11): None, (4, 8): None, (4, 10): None, (5, 9): None, (6, 10): None, (6, 11): None, (7, 11): None} None (0, 12)
# ...
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 421599 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.961058, train_loss 0.072110, test_acc 0.934295, test_loss: 0.251322
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.963962, train_loss 0.060140, test_acc 0.934317, test_loss: 0.251299
# Saving model
# Model was saved successfully
# Epoch 3: train_acc 0.964713, train_loss 0.058957, test_acc 0.934666, test_loss: 0.248176
# Saving model
# Model was saved successfully
# Epoch 4: train_acc 0.964672, train_loss 0.058277, test_acc 0.932984, test_loss: 0.269424
# Epoch 5: train_acc 0.964485, train_loss 0.059798, test_acc 0.933258, test_loss: 0.272313
# Epoch 6: train_acc 0.963827, train_loss 0.059530, test_acc 0.933212, test_loss: 0.276290
# Epoch 7: train_acc 0.964384, train_loss 0.060020, test_acc 0.931764, test_loss: 0.276264
# Epoch 8: train_acc 0.964652, train_loss 0.058973, test_acc 0.932836, test_loss: 0.271919
# Epoch 9: train_acc 0.964417, train_loss 0.057476, test_acc 0.933216, test_loss: 0.280798
# Epoch 10: train_acc 0.965140, train_loss 0.056658, test_acc 0.932588, test_loss: 0.289857
# Epoch 11: train_acc 0.965289, train_loss 0.056811, test_acc 0.932509, test_loss: 0.284496
# Early stopping
# Train with DAgger, iter 97
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 425180 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.960941, train_loss 0.073698, test_acc 0.931291, test_loss: 0.252828
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.963949, train_loss 0.059308, test_acc 0.933449, test_loss: 0.258159
# Epoch 3: train_acc 0.964818, train_loss 0.056762, test_acc 0.934892, test_loss: 0.261044
# Epoch 4: train_acc 0.965829, train_loss 0.055735, test_acc 0.934797, test_loss: 0.285277
# Epoch 5: train_acc 0.965820, train_loss 0.056150, test_acc 0.933907, test_loss: 0.309413
# Epoch 6: train_acc 0.965860, train_loss 0.056028, test_acc 0.933920, test_loss: 0.307857
# Epoch 7: train_acc 0.965560, train_loss 0.056609, test_acc 0.933971, test_loss: 0.294894
# Epoch 8: train_acc 0.966399, train_loss 0.055852, test_acc 0.933142, test_loss: 0.278148
# Epoch 9: train_acc 0.966313, train_loss 0.054947, test_acc 0.932978, test_loss: 0.271535
# Early stopping
# Train with DAgger, iter 98
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# {(0, 11): None, (0, 12): None, (2, 5): None, (2, 9): None, (2, 10): None, (2, 11): None, (2, 12): None, (3, 4): None, (3, 10): None, (3, 11): None, (3, 12): None, (4, 6): None, (4, 9): None, (4, 11): None, (4, 12): None, (5, 6): None, (5, 11): None, (5, 12): None, (6, 7): None, (6, 10): None, (6, 11): None, (6, 12): None, (7, 10): None, (7, 11): None, (8, 10): None, (8, 11): None, (9, 10): None, (9, 11): None, (10, 11): None} None (3, 12)
# {(0, 11): None, (0, 12): None, (2, 5): None, (2, 9): None, (2, 10): None, (2, 11): None, (2, 12): None, (3, 4): None, (3, 10): None, (3, 11): None, (3, 12): None, (4, 6): None, (4, 9): None, (4, 11): None, (4, 12): None, (5, 6): None, (5, 11): None, (5, 12): None, (6, 7): None, (6, 10): None, (6, 11): None, (6, 12): None, (7, 10): None, (7, 11): None, (8, 10): None, (8, 11): None, (9, 10): None, (9, 11): None, (10, 11): None} None (3, 12)
# {(0, 11): None, (0, 12): None, (2, 5): None, (2, 9): None, (2, 10): None, (2, 11): None, (2, 12): None, (3, 4): None, (3, 10): None, (3, 11): None, (3, 12): None, (4, 6): None, (4, 9): None, (4, 11): None, (4, 12): None, (5, 6): None, (5, 11): None, (5, 12): None, (6, 7): None, (6, 10): None, (6, 11): None, (6, 12): None, (7, 10): None, (7, 11): None, (8, 10): None, (8, 11): None, (9, 10): None, (9, 11): None, (10, 11): None} None (3, 12)
# {(0, 11): None, (0, 12): None, (2, 5): None, (2, 9): None, (2, 10): None, (2, 11): None, (2, 12): None, (3, 4): None, (3, 10): None, (3, 11): None, (3, 12): None, (4, 6): None, (4, 9): None, (4, 11): None, (4, 12): None, (5, 6): None, (5, 11): None, (5, 12): None, (6, 7): None, (6, 10): None, (6, 11): None, (6, 12): None, (7, 10): None, (7, 11): None, (8, 10): None, (8, 11): None, (9, 10): None, (9, 11): None, (10, 11): None} None (3, 12)
# Epoch 7: train_acc 0.966327, train_loss 0.055554, test_acc 0.932793, test_loss: 0.297169
# Epoch 8: train_acc 0.965183, train_loss 0.057797, test_acc 0.933611, test_loss: 0.278429
# Epoch 9: train_acc 0.964511, train_loss 0.058924, test_acc 0.932595, test_loss: 0.279724
# Early stopping
# Train with DAgger, iter 99
# rollout 1/50 return=-1.000000
# rollout 2/50 return=-1.000000
# rollout 3/50 return=-1.000000
# rollout 4/50 return=-1.000000
# rollout 5/50 return=-1.000000
# rollout 6/50 return=-1.000000
# rollout 7/50 return=-1.000000
# rollout 8/50 return=-1.000000
# rollout 9/50 return=-1.000000
# rollout 10/50 return=-1.000000
# rollout 11/50 return=-1.000000
# rollout 12/50 return=-1.000000
# rollout 13/50 return=-1.000000
# rollout 14/50 return=-1.000000
# rollout 15/50 return=-1.000000
# rollout 16/50 return=-1.000000
# rollout 17/50 return=-1.000000
# rollout 18/50 return=-1.000000
# rollout 19/50 return=-1.000000
# rollout 20/50 return=-1.000000
# rollout 21/50 return=-1.000000
# rollout 22/50 return=-1.000000
# rollout 23/50 return=-1.000000
# rollout 24/50 return=-1.000000
# rollout 25/50 return=-1.000000
# rollout 26/50 return=-1.000000
# rollout 27/50 return=-1.000000
# rollout 28/50 return=-1.000000
# rollout 29/50 return=-1.000000
# rollout 30/50 return=-1.000000
# rollout 31/50 return=-1.000000
# rollout 32/50 return=-1.000000
# rollout 33/50 return=-1.000000
# rollout 34/50 return=-1.000000
# rollout 35/50 return=-1.000000
# rollout 36/50 return=-1.000000
# rollout 37/50 return=-1.000000
# rollout 38/50 return=-1.000000
# rollout 39/50 return=-1.000000
# rollout 40/50 return=-1.000000
# rollout 41/50 return=-1.000000
# rollout 42/50 return=-1.000000
# rollout 43/50 return=-1.000000
# rollout 44/50 return=-1.000000
# rollout 45/50 return=-1.000000
# rollout 46/50 return=-1.000000
# rollout 47/50 return=-1.000000
# rollout 48/50 return=-1.000000
# rollout 49/50 return=-1.000000
# rollout 50/50 return=-1.000000
# Return summary: mean=-1.000000, std=0.000000
# Train the agent with 432748 training data, batch_size 16384, epochs 25
# Epoch 1: train_acc 0.961805, train_loss 0.071417, test_acc 0.934445, test_loss: 0.247823
# Saving model
# Model was saved successfully
# Epoch 2: train_acc 0.963228, train_loss 0.061737, test_acc 0.933517, test_loss: 0.256950
# Epoch 3: train_acc 0.963738, train_loss 0.061182, test_acc 0.934667, test_loss: 0.259279
# Epoch 4: train_acc 0.964878, train_loss 0.059202, test_acc 0.935089, test_loss: 0.253871
# Epoch 5: train_acc 0.965104, train_loss 0.058267, test_acc 0.933390, test_loss: 0.261468
# Epoch 6: train_acc 0.965034, train_loss 0.058697, test_acc 0.933556, test_loss: 0.266355
# Epoch 7: train_acc 0.964112, train_loss 0.058715, test_acc 0.932203, test_loss: 0.271126
# Epoch 8: train_acc 0.965172, train_loss 0.057666, test_acc 0.931703, test_loss: 0.284100
# Epoch 9: train_acc 0.964991, train_loss 0.058622, test_acc 0.932754, test_loss: 0.281845
# Early stopping
