# %%
import numpy as np
import os
import shutil

from pommerman.envs.v0 import Pomme
from pommerman.agents import SimpleAgent, BaseAgent
from pommerman.configs import ffa_competition_env
from pommerman.constants import BOARD_SIZE, GameType
from tensorforce.agents import PPOAgent
from tensorforce.execution import Runner
from tensorforce.contrib.openai_gym import OpenAIGym
# Out:
# Import error! You will not be able to render --> Cannot connect to "None"
# /gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
num_episodes = 100
batching_capacity = 100000
save_seconds = 300
main_dir = './ppo/'
log_path = main_dir + 'logs/'
model_path = main_dir + 'model'

if not os.path.isdir(main_dir):
    os.mkdir(main_dir)
if os.path.isdir(log_path):
    shutil.rmtree(log_path, ignore_errors=True)
os.mkdir(log_path)

# Instantiate the environment
config = ffa_competition_env()
env = Pomme(**config["env_kwargs"])
env.seed(0)

# Create a Proximal Policy Optimization agent
network = dict(type='pomm_network.PommNetwork')
states = {
    "board": dict(shape=(2369), type='float')
}
saver = {
    "directory": model_path,
    "seconds": save_seconds,
    "load": os.path.isdir(model_path)
}
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
agent = PPOAgent(
    states=states,
    actions=dict(type='int', num_actions=env.action_space.n),
    network=network,
    batching_capacity=batching_capacity,
    step_optimizer=dict(
        type='adam',
        learning_rate=1e-4
    ),
    saver=saver
)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f086996066db> in <module>()
#       8         learning_rate=1e-4
#       9     ),
# ---> 10     saver=saver
#      11 )
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/agents/ppo_agent.py in __init__(self, states, actions, network, batched_observe, batching_capacity, scope, device, saver, summarizer, execution, variable_noise, states_preprocessing, actions_exploration, reward_preprocessing, update_mode, memory, discount, distributions, entropy_regularization, baseline_mode, baseline, baseline_optimizer, gae_lambda, likelihood_ratio_clipping, step_optimizer, subsampling_fraction, optimization_steps)
#     153             network=network,
#     154             distributions=distributions,
# --> 155             entropy_regularization=entropy_regularization
#     156         )
#     157
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/agents/learning_agent.py in __init__(self, states, actions, network, update_mode, memory, optimizer, batched_observe, batching_capacity, scope, device, saver, summarizer, execution, variable_noise, states_preprocessing, actions_exploration, reward_preprocessing, discount, distributions, entropy_regularization)
#     139             actions=actions,
#     140             batched_observe=batched_observe,
# --> 141             batching_capacity=batching_capacity
#     142         )
#     143
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/agents/agent.py in __init__(self, states, actions, batched_observe, batching_capacity)
#      78         self.episode = None
#      79
# ---> 80         self.model = self.initialize_model()
#      81         self.reset()
#      82
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/agents/ppo_agent.py in initialize_model(self)
#     181             baseline_optimizer=self.baseline_optimizer,
#     182             gae_lambda=self.gae_lambda,
# --> 183             likelihood_ratio_clipping=self.likelihood_ratio_clipping
#     184         )
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_prob_ratio_model.py in __init__(self, states, actions, scope, device, saver, summarizer, execution, batching_capacity, variable_noise, states_preprocessing, actions_exploration, reward_preprocessing, update_mode, memory, optimizer, discount, network, distributions, entropy_regularization, baseline_mode, baseline, baseline_optimizer, gae_lambda, likelihood_ratio_clipping)
#      86             baseline=baseline,
#      87             baseline_optimizer=baseline_optimizer,
# ---> 88             gae_lambda=gae_lambda
#      89         )
#      90
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_model.py in __init__(self, states, actions, scope, device, saver, summarizer, execution, batching_capacity, variable_noise, states_preprocessing, actions_exploration, reward_preprocessing, update_mode, memory, optimizer, discount, network, distributions, entropy_regularization, baseline_mode, baseline, baseline_optimizer, gae_lambda)
#      96             distributions=distributions,
#      97             entropy_regularization=entropy_regularization,
# ---> 98             requires_deterministic=False
#      99         )
#     100
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/distribution_model.py in __init__(self, states, actions, scope, device, saver, summarizer, execution, batching_capacity, variable_noise, states_preprocessing, actions_exploration, reward_preprocessing, update_mode, memory, optimizer, discount, network, distributions, entropy_regularization, requires_deterministic)
#      88             memory=memory,
#      89             optimizer=optimizer,
# ---> 90             discount=discount
#      91         )
#      92
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py in __init__(self, states, actions, scope, device, saver, summarizer, execution, batching_capacity, variable_noise, states_preprocessing, actions_exploration, reward_preprocessing, update_mode, memory, optimizer, discount)
#     112             states_preprocessing=states_preprocessing,
#     113             actions_exploration=actions_exploration,
# --> 114             reward_preprocessing=reward_preprocessing
#     115         )
#     116
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py in __init__(self, states, actions, scope, device, saver, summarizer, execution, batching_capacity, variable_noise, states_preprocessing, actions_exploration, reward_preprocessing, tf_session_dump_dir)
#     219
#     220         # Setup Model (create and build graph (local and global if distributed), server, session, etc..).
# --> 221         self.setup()
#     222
#     223     def setup(self):
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py in setup(self)
#     272                     reward=reward,
#     273                     deterministic=deterministic,
# --> 274                     independent=independent
#     275                 )
#     276
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py in create_operations(self, states, internals, actions, terminal, reward, deterministic, independent)
#     605             reward=reward,
#     606             deterministic=deterministic,
# --> 607             independent=independent
#     608         )
#     609
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py in create_operations(self, states, internals, actions, terminal, reward, deterministic, independent)
#    1145             independent=independent
#    1146         )
# -> 1147         self.create_observe_operations(reward=reward, terminal=terminal)
#    1148         self.create_atomic_observe_operations(
#    1149             states=states,
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py in create_observe_operations(self, terminal, reward)
#    1081                 actions=actions,
#    1082                 terminal=terminal,
# -> 1083                 reward=reward
#    1084             )
#    1085
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in __call__(self, *args, **kwargs)
#     276           custom_getter=self._custom_getter) as vs:
#     277         self._variable_scope = vs
# --> 278         result = self._call_func(args, kwargs, check_for_new_variables=False)
#     279         self._variables_created = True
#     280         return result
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in _call_func(self, args, kwargs, check_for_new_variables)
#     215           ops.get_collection(ops.GraphKeys.TRAINABLE_VARIABLES))
#     216
# --> 217       result = self._func(*args, **kwargs)
#     218       if check_for_new_variables:
#     219         trainable_variables = ops.get_collection(
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py in tf_observe_timestep(self, states, internals, actions, terminal, reward)
#     565                 pred=optimize,
#     566                 true_fn=(lambda: self.fn_optimization(**batch)),
# --> 567                 false_fn=tf.no_op
#     568             )
#     569
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     314                 'in a future version' if date is None else ('after %s' % date),
#     315                 instructions)
# --> 316       return func(*args, **kwargs)
#     317     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     318                                        _add_deprecated_arg_notice_to_docstring(
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in cond(pred, true_fn, false_fn, strict, name, fn1, fn2)
#    1853     context_t = CondContext(pred, pivot_1, branch=1)
#    1854     context_t.Enter()
# -> 1855     orig_res_t, res_t = context_t.BuildCondBranch(true_fn)
#    1856     if orig_res_t is None:
#    1857       raise ValueError("true_fn must have a return value.")
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in BuildCondBranch(self, fn)
#    1723   def BuildCondBranch(self, fn):
#    1724     """Add the subgraph defined by fn() to the graph."""
# -> 1725     original_result = fn()
#    1726     if original_result is None:
#    1727       return None, None
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py in <lambda>()
#     564             return tf.cond(
#     565                 pred=optimize,
# --> 566                 true_fn=(lambda: self.fn_optimization(**batch)),
#     567                 false_fn=tf.no_op
#     568             )
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in __call__(self, *args, **kwargs)
#     276           custom_getter=self._custom_getter) as vs:
#     277         self._variable_scope = vs
# --> 278         result = self._call_func(args, kwargs, check_for_new_variables=False)
#     279         self._variables_created = True
#     280         return result
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in _call_func(self, args, kwargs, check_for_new_variables)
#     215           ops.get_collection(ops.GraphKeys.TRAINABLE_VARIABLES))
#     216
# --> 217       result = self._func(*args, **kwargs)
#     218       if check_for_new_variables:
#     219         trainable_variables = ops.get_collection(
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_model.py in tf_optimization(self, states, internals, actions, terminal, reward, next_states, next_internals)
#     303             reward=estimated_reward,
#     304             next_states=next_states,
# --> 305             next_internals=next_internals
#     306         )
#     307
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py in tf_optimization(self, states, internals, actions, terminal, reward, next_states, next_internals)
#     492             next_internals=next_internals
#     493         )
# --> 494         return self.optimizer.minimize(**arguments)
#     495
#     496     def tf_observe_timestep(self, states, internals, actions, terminal, reward):
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/core/optimizers/optimizer.py in minimize(self, time, variables, **kwargs)
#     141         #                     self.summaries.append(summary)
#     142
# --> 143         deltas = self.step(time=time, variables=variables, **kwargs)
#     144         with tf.control_dependencies(control_inputs=deltas):
#     145             return tf.no_op()
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in __call__(self, *args, **kwargs)
#     276           custom_getter=self._custom_getter) as vs:
#     277         self._variable_scope = vs
# --> 278         result = self._call_func(args, kwargs, check_for_new_variables=False)
#     279         self._variables_created = True
#     280         return result
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in _call_func(self, args, kwargs, check_for_new_variables)
#     215           ops.get_collection(ops.GraphKeys.TRAINABLE_VARIABLES))
#     216
# --> 217       result = self._func(*args, **kwargs)
#     218       if check_for_new_variables:
#     219         trainable_variables = ops.get_collection(
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/core/optimizers/multi_step.py in tf_step(self, time, variables, arguments, fn_reference, **kwargs)
#      62
#      63         # Set reference to compare with at each optimization step, in case of a comparative loss.
# ---> 64         arguments['reference'] = fn_reference(**arguments)
#      65
#      66         # First step
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in __call__(self, *args, **kwargs)
#     276           custom_getter=self._custom_getter) as vs:
#     277         self._variable_scope = vs
# --> 278         result = self._call_func(args, kwargs, check_for_new_variables=False)
#     279         self._variables_created = True
#     280         return result
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in _call_func(self, args, kwargs, check_for_new_variables)
#     215           ops.get_collection(ops.GraphKeys.TRAINABLE_VARIABLES))
#     216
# --> 217       result = self._func(*args, **kwargs)
#     218       if check_for_new_variables:
#     219         trainable_variables = ops.get_collection(
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_prob_ratio_model.py in tf_reference(self, states, internals, actions, terminal, reward, next_states, next_internals, update)
#      90
#      91     def tf_reference(self, states, internals, actions, terminal, reward, next_states, next_internals, update):
# ---> 92         embedding = self.network.apply(x=states, internals=internals, update=update)
#      93
#      94         log_probs = list()
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in __call__(self, *args, **kwargs)
#     259         # been created, and we want to reuse them.
#     260         with variable_scope.variable_scope(self._variable_scope, reuse=True):
# --> 261           return self._call_func(args, kwargs, check_for_new_variables=True)
#     262       else:
#     263         # This is the first visit to __call__, but the scope has already been
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/template.py in _call_func(self, args, kwargs, check_for_new_variables)
#     215           ops.get_collection(ops.GraphKeys.TRAINABLE_VARIABLES))
#     216
# --> 217       result = self._func(*args, **kwargs)
#     218       if check_for_new_variables:
#     219         trainable_variables = ops.get_collection(
#
# ~/playground/rl_agent/pomm_network.py in tf_apply(self, x, internals, update, return_internals)
#       8 class PommNetwork(Network):
#       9     def tf_apply(self, x, internals, update, return_internals=False):
# ---> 10         fc = self.create_network(x)
#      11         # TODO maybe {} is not ok
#      12         if return_internals:
#
# ~/playground/rl_agent/pomm_network.py in create_network(board)
#      17     def create_network(board):
#      18         inp = Input(tensor = board['board'])
# ---> 19         x = Dense(8)(inp)
#      20         x = Activation('relu')(x)
#      21         x = Dense(8)(x)
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     590                                          '`layer.build(batch_input_shape)`')
#     591                 if len(input_shapes) == 1:
# --> 592                     self.build(input_shapes[0])
#     593                 else:
#     594                     self.build(input_shapes)
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/keras/layers/core.py in build(self, input_shape)
#     862                                       name='kernel',
#     863                                       regularizer=self.kernel_regularizer,
# --> 864                                       constraint=self.kernel_constraint)
#     865         if self.use_bias:
#     866             self.bias = self.add_weight(shape=(self.units,),
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/keras/engine/topology.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint)
#     414                             dtype=dtype,
#     415                             name=name,
# --> 416                             constraint=constraint)
#     417         if regularizer is not None:
#     418             self.add_loss(regularizer(weight))
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in variable(value, dtype, name, constraint)
#     394         v._uses_learning_phase = False
#     395         return v
# --> 396     v = tf.Variable(value, dtype=tf.as_dtype(dtype), name=name)
#     397     if isinstance(value, np.ndarray):
#     398         v._keras_shape = value.shape
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint)
#     211           dtype=dtype,
#     212           expected_shape=expected_shape,
# --> 213           constraint=constraint)
#     214
#     215   def __repr__(self):
#
# ~/.conda/envs/pommerman/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in _init_from_args(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, expected_shape, constraint)
#     320                 "construct, such as a loop or conditional. When creating a "
#     321                 "variable inside a loop or conditional, use a lambda as the "
# --> 322                 "initializer." % name)
#     323           # pylint: enable=protected-access
#     324           shape = (self._initial_value.get_shape()
#
# ValueError: Initializer for variable ppo/observe-timestep/cond/optimization/multi-step/step/reference/apply/dense_4/kernel/ is from inside a control-flow construct, such as a loop or conditional. When creating a variable inside a loop or conditional, use a lambda as the initializer.
#
# originally defined at:
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py", line 250, in setup
#     self.setup_components_and_tf_funcs()
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_model.py", line 110, in setup_components_and_tf_funcs
#     custom_getter = super(PGModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/distribution_model.py", line 101, in setup_components_and_tf_funcs
#     kwargs=dict(summary_labels=self.summary_labels)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/core/networks/network.py", line 180, in from_spec
#     kwargs=kwargs
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/util.py", line 192, in get_object
#     return obj(*args, **kwargs)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/core/networks/network.py", line 60, in __init__
#     custom_getter_=custom_getter
#
#
# originally defined at:
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py", line 250, in setup
#     self.setup_components_and_tf_funcs()
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_model.py", line 110, in setup_components_and_tf_funcs
#     custom_getter = super(PGModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/distribution_model.py", line 119, in setup_components_and_tf_funcs
#     custom_getter = super(DistributionModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py", line 160, in setup_components_and_tf_funcs
#     custom_getter_=custom_getter
#
#
# originally defined at:
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py", line 250, in setup
#     self.setup_components_and_tf_funcs()
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_model.py", line 110, in setup_components_and_tf_funcs
#     custom_getter = super(PGModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/distribution_model.py", line 119, in setup_components_and_tf_funcs
#     custom_getter = super(DistributionModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py", line 148, in setup_components_and_tf_funcs
#     kwargs=dict(summary_labels=self.summary_labels)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/core/optimizers/optimizer.py", line 173, in from_spec
#     kwargs=kwargs
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/util.py", line 192, in get_object
#     return obj(*args, **kwargs)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/core/optimizers/multi_step.py", line 46, in __init__
#     super(MultiStep, self).__init__(optimizer=optimizer, scope=scope, summary_labels=summary_labels)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/core/optimizers/meta_optimizer.py", line 39, in __init__
#     super(MetaOptimizer, self).__init__(scope=scope, summary_labels=summary_labels)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/core/optimizers/optimizer.py", line 53, in __init__
#     custom_getter=custom_getter
#
#
# originally defined at:
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py", line 250, in setup
#     self.setup_components_and_tf_funcs()
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_model.py", line 110, in setup_components_and_tf_funcs
#     custom_getter = super(PGModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/distribution_model.py", line 119, in setup_components_and_tf_funcs
#     custom_getter = super(DistributionModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py", line 180, in setup_components_and_tf_funcs
#     custom_getter_=custom_getter
#
#
# originally defined at:
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py", line 250, in setup
#     self.setup_components_and_tf_funcs()
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/pg_model.py", line 110, in setup_components_and_tf_funcs
#     custom_getter = super(PGModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/distribution_model.py", line 119, in setup_components_and_tf_funcs
#     custom_getter = super(DistributionModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/memory_model.py", line 132, in setup_components_and_tf_funcs
#     custom_getter = super(MemoryModel, self).setup_components_and_tf_funcs(custom_getter)
#   File "/gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/tensorforce/models/model.py", line 528, in setup_components_and_tf_funcs
#     custom_getter_=custom_getter

# %%
class TensorforceAgent(BaseAgent):
    def act(self, obs, action_space):
        pass
# Add 3 random agents
agents = []
for agent_id in range(3):
    agents.append(SimpleAgent(config["agent"](agent_id, config["game_type"])))

# Add TensorforceAgent
agent_id += 1
agents.append(TensorforceAgent(config["agent"](agent_id, config["game_type"])))
env.set_agents(agents)
env.set_training_agent(agents[-1].agent_id)
env.set_init_game_state(None)

# %%
class WrappedEnv(OpenAIGym):
    def __init__(self, gym, visualize=False):
        self.gym = gym
        self.visualize = visualize

    def execute(self, actions):
        if self.visualize:
            self.gym.render()

        obs = self.gym.get_observations()
        all_actions = self.gym.act(obs)
        all_actions.insert(self.gym.training_agent, actions)
        state, reward, terminal, _ = self.gym.step(all_actions)
        agent_state = self.featurize(state[self.gym.training_agent])
        agent_reward = reward[self.gym.training_agent]
        # If nobody die, use some "smart" reward
        return agent_state, terminal, agent_reward

    def reset(self):
        obs = self.gym.reset()
        agent_obs = self.featurize(obs[3])
        return agent_obs

    def featurize(self, obs):
        shape = (self.board_size, self.board_size, 1)

        def get_matrix(dict, key):
            res = dict[key]
            return res.reshape(shape).astype(np.float32)

        def get_map(board, item):
            map = np.zeros(shape)
            map[board == item] = 1
            return map

        board = get_matrix(obs, 'board')

        # TODO: probably not needed Passage = 0
        rigid_map = get_map(board, 1)  # Rigid = 1
        wood_map = get_map(board, 2)  # Wood = 2
        bomb_map = get_map(board, 3)  # Bomb = 3
        flames_map = get_map(board, 4)  # Flames = 4
        fog_map = get_map(board, 5)  # TODO: not used for first two stages Fog = 5
        extra_bomb_map = get_map(board, 6)  # ExtraBomb = 6
        incr_range_map = get_map(board, 7)  # IncrRange = 7
        kick_map = get_map(board, 8)  # Kick = 8
        skull_map = get_map(board, 9)  # Skull = 9

        position = obs["position"]
        my_position = np.zeros(shape)
        my_position[position[0], position[1], 0] = 1

        team_mates = get_map(board, obs["teammate"].value)  # TODO during documentation it should be an array

        enemies = np.zeros(shape)
        for enemy in obs["enemies"]:
            enemies[board == enemy.value] = 1

        bomb_blast_strength = get_matrix(obs, 'bomb_blast_strength')
        bomb_life = get_matrix(obs, 'bomb_life')

        ammo = obs["ammo"]
        blast_strength = obs["blast_strength"]
        can_kick = int(obs["can_kick"])

        obs = np.concatenate([my_position, enemies, team_mates, rigid_map,
                              wood_map, bomb_map, flames_map,
                              fog_map, extra_bomb_map, incr_range_map,
                              kick_map, skull_map, bomb_blast_strength,
                              bomb_life], axis=2).flatten()
        obs = np.append(obs, [ammo, blast_strength, can_kick])
        return obs

# %%
def episode_finished(r):
    if r.episode % 10 == 0:
        print("Finished episode {ep} after {ts} timesteps".format(ep=r.episode + 1, ts = r.timestep + 1))
        print("Episode reward: {}".format(r.episode_rewards[-1]))
        print("Average of last 10 rewards: {}".format(np.mean(r.episode_rewards[10:])))
    return True

# %%
# Instantiate and run the environment for 5 episodes.
wrapped_env = WrappedEnv(env, False)
runner = Runner(agent=agent, environment=wrapped_env)
runner.run(num_episodes=num_episodes, episode_finished=episode_finished, max_episode_timesteps=env._max_steps)
print("Stats: ", runner.episode_rewards, runner.episode_timesteps, runner.episode_times)

try:
    runner.close()
except AttributeError as e:
    pass
