# %%
import numpy as np
import os
import tensorflow as tf
import warnings

from keras.models import Model
from keras.layers import Dense, Flatten, Convolution2D, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from pommerman.configs import ffa_v0_env
from pommerman.envs.v0 import Pomme
from pommerman.agents import SimpleAgent, BaseAgent
from pommerman.constants import BOARD_SIZE
from rl.agents.dqn import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory
from rl.core import Env, Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint, Callback
# Out:
# /gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
number_of_training_steps = 5000000
log_interval = 1000
file_log_path = './dqn/rl_logs/dense_8_2/log.txt'
tensorboard_path = './dqn/logs/dense_8_2/'
model_path = './dqn/model/dense_8_2/model{step}.h4'

# %%
if not os.path.isdir(os.path.dirname(file_log_path)):
    os.makedirs(os.path.dirname(file_log_path))
if not os.path.isdir(os.path.dirname(model_path)):
    os.makedirs(os.path.dirname(model_path))

# %%
class TensorforceAgent(BaseAgent):
    def act(self, obs, action_space):
        pass


class TensorboardLogger(Callback):
    """Logging in tensorboard without tensorflow ops."""
    def __init__(self, log_dir):
        # Some algorithms compute multiple episodes at once since they are multi-threaded.
        # We therefore use a dictionary that is indexed by the episode to separate episodes
        # from each other.
        self.observations = {}
        self.rewards = {}
        self.actions = {}
        self.metrics = {}
        self.step = 0
        """Creates a summary writer logging to log_dir."""
        self.writer = tf.summary.FileWriter(log_dir)

    def log_scalar(self, tag, value, step):
        """Log a scalar variable.
        Parameter
        ----------
        tag : basestring
            Name of the scalar
        value
        step : int
            training iteration
        """
        summary = tf.Summary(value=[tf.Summary.Value(tag=tag, simple_value=value)])
        self.writer.add_summary(summary, step)

    def on_train_begin(self, logs):
        self.metrics_names = self.model.metrics_names

    def on_episode_begin(self, episode, logs):
        self.observations[episode] = []
        self.rewards[episode] = []
        self.actions[episode] = []
        self.metrics[episode] = []

    def on_episode_end(self, episode, logs):
        episode_steps = len(self.observations[episode])
        variables = {
            'step': self.step,
            'nb_steps': self.params['nb_steps'],
            'episode_steps': episode_steps,
            'episode_reward': np.sum(self.rewards[episode]),
            'reward_mean': np.mean(self.rewards[episode]),
            'reward_min': np.min(self.rewards[episode]),
            'reward_max': np.max(self.rewards[episode]),
            'action_mean': np.mean(self.actions[episode]),
            'action_min': np.min(self.actions[episode]),
            'action_max': np.max(self.actions[episode]),
            'obs_mean': np.mean(self.observations[episode]),
            'obs_min': np.min(self.observations[episode]),
            'obs_max': np.max(self.observations[episode]),
        }

        # Format all metrics.
        metrics = np.array(self.metrics[episode])
        with warnings.catch_warnings():
            warnings.filterwarnings('error')
            for idx, name in enumerate(self.metrics_names):
                try:
                    value = np.nanmean(metrics[:, idx])
                except Warning:
                    value = -1
                variables[name] = value
        for key, value in variables.items():
            self.log_scalar(key, value, episode + 1)

        # Free up resources.
        del self.observations[episode]
        del self.rewards[episode]
        del self.actions[episode]
        del self.metrics[episode]

    def on_step_end(self, step, logs):
        episode = logs['episode']
        self.observations[episode].append(logs['observation'])
        self.rewards[episode].append(logs['reward'])
        self.actions[episode].append(logs['action'])
        self.metrics[episode].append(logs['metrics'])
        self.step += 1

# %%
# Instantiate the environment
config = ffa_v0_env()
env = Pomme(**config["env_kwargs"])
np.random.seed(0)
env.seed(0)
# Add 3 random agents
agents = []
for agent_id in range(3):
    agents.append(SimpleAgent(config["agent"](agent_id, config["game_type"])))

# Add TensorforceAgent
agent_id += 1
agents.append(TensorforceAgent(config["agent"](agent_id, config["game_type"])))
env.set_agents(agents)
env.set_training_agent(agents[-1].agent_id)
env.set_init_game_state(None)
nb_actions = env.action_space.n


def create_model(actions, input_shape=(2369,)):
    inp = Input(input_shape)        
    x = Dense(8, activation='relu')(inp)
    x = Dense(8, activation='relu')(x)
    out = Dense(actions)(x)
    model = Model(inputs = inp, outputs=out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


# Next, we build a very simple model regardless of the dueling architecture
# if you enable dueling network in DQN , DQN will build a dueling network base on your model automatically
# Also, you can build a dueling network by yourself and turn off the dueling network in DQN.
model = create_model(nb_actions)
print(model.summary())
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2369)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 18960
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 54
# =================================================================
# Total params: 19,086
# Trainable params: 19,086
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
class EnvWrapper(Env):
    """The abstract environment class that is used by all agents. This class has the exact
        same API that OpenAI Gym uses so that integrating with it is trivial. In contrast to the
        OpenAI Gym implementation, this class only defines the abstract methods without any actual
        implementation.
        To implement your own environment, you need to define the following methods:
        - `step`
        - `reset`
        - `render`
        - `close`
        Refer to the [Gym documentation](https://gym.openai.com/docs/#environments).
        """
    reward_range = (-1, 1)
    action_space = None
    observation_space = None

    def __init__(self, gym, board_size):
        self.gym = gym
        self.action_space = gym.action_space
        self.observation_space = gym.observation_space
        self.reward_range = gym.reward_range
        self.board_size = board_size

    def step(self, action):
        """Run one timestep of the environment's dynamics.
        Accepts an action and returns a tuple (observation, reward, done, info).
        # Arguments
            action (object): An action provided by the environment.
        # Returns
            observation (object): Agent's observation of the current environment.
            reward (float) : Amount of reward returned after previous action.
            done (boolean): Whether the episode has ended, in which case further step() calls will return undefined results.
            info (dict): Contains auxiliary diagnostic information (helpful for debugging, and sometimes learning).
        """
        obs = self.gym.get_observations()
        all_actions = self.gym.act(obs)
        all_actions.insert(self.gym.training_agent, action)
        state, reward, terminal, info = self.gym.step(all_actions)
        agent_state = self.featurize(state[self.gym.training_agent])
        agent_reward = reward[self.gym.training_agent]
        return agent_state, agent_reward, terminal, info

    def reset(self):
        """
        Resets the state of the environment and returns an initial observation.
        # Returns
            observation (object): The initial observation of the space. Initial reward is assumed to be 0.
        """
        obs = self.gym.reset()
        agent_obs = self.featurize(obs[self.gym.training_agent])
        return agent_obs

    def render(self, mode='human', close=False):
        """Renders the environment.
        The set of supported modes varies per environment. (And some
        environments do not support rendering at all.)
        # Arguments
            mode (str): The mode to render with.
            close (bool): Close all open renderings.
        """
        self.gym.render(mode=mode, close=close)

    def close(self):
        """Override in your subclass to perform any necessary cleanup.
        Environments will automatically close() themselves when
        garbage collected or when the program exits.
        """
        self.gym.close()

    def seed(self, seed=None):
        """Sets the seed for this env's random number generator(s).
        # Returns
            Returns the list of seeds used in this env's random number generators
        """
        raise self.gym.seed(seed)

    def configure(self, *args, **kwargs):
        """Provides runtime configuration to the environment.
        This configuration should consist of data that tells your
        environment how to run (such as an address of a remote server,
        or path to your ImageNet data). It should not affect the
        semantics of the environment.
        """
        raise NotImplementedError()

    def featurize(self, obs):
        shape = (self.board_size, self.board_size, 1)

        def get_matrix(dict, key):
            res = dict[key]
            return res.reshape(shape).astype(np.float32)

        def get_map(board, item):
            map = np.zeros(shape)
            map[board == item] = 1
            return map

        board = get_matrix(obs, 'board')

        # TODO: probably not needed Passage = 0
        rigid_map = get_map(board, 1)               # Rigid = 1
        wood_map = get_map(board, 2)                # Wood = 2
        bomb_map = get_map(board, 3)                # Bomb = 3
        flames_map = get_map(board, 4)              # Flames = 4
        fog_map = get_map(board, 5)                 # TODO: not used for first two stages Fog = 5
        extra_bomb_map = get_map(board, 6)          # ExtraBomb = 6
        incr_range_map = get_map(board, 7)          # IncrRange = 7
        kick_map = get_map(board, 8)                # Kick = 8
        skull_map = get_map(board, 9)               # Skull = 9

        position = obs["position"]
        my_position = np.zeros(shape)
        my_position[position[0], position[1], 0] = 1

        team_mates = get_map(board, obs["teammate"].value) # TODO during documentation it should be an array

        enemies = np.zeros(shape)
        for enemy in obs["enemies"]:
            enemies[board == enemy.value] = 1

        bomb_blast_strength = get_matrix(obs, 'bomb_blast_strength')
        bomb_life = get_matrix(obs, 'bomb_life')

        ammo = obs["ammo"]
        blast_strength = obs["blast_strength"]
        can_kick = int(obs["can_kick"])

        obs = np.concatenate([my_position, enemies, team_mates, rigid_map,
                              wood_map, bomb_map, flames_map,
                              fog_map, extra_bomb_map, incr_range_map,
                              kick_map, skull_map, bomb_blast_strength,
                              bomb_life], axis=2).flatten()
        obs = np.append(obs, [ammo, blast_strength, can_kick])
        return obs

    def __del__(self):
        self.close()

    def __str__(self):
        return '<{} instance>'.format(type(self).__name__)


class CustomProcessor(Processor):
    def process_state_batch(self, batch):
        """Processes an entire batch of states and returns it.
        # Arguments
            batch (list): List of states
        # Returns
            Processed list of states
        """
        batch = np.squeeze(batch, axis=1)
        return batch

    def process_info(self, info):
        """Processes the info as obtained from the environment for use in an agent and
        returns it.
        """
        info['result'] = info['result'].value
        return info

# %%
env_wrapper = EnvWrapper(env, BOARD_SIZE)
processor = CustomProcessor()

# Finally, we configure and compile our agent. You can use every built-in Keras optimizer and
# even the metrics!
memory = SequentialMemory(limit=50000, window_length=1)
policy = BoltzmannQPolicy()
file_logger = FileLogger(file_log_path, interval=log_interval)
checkpoint = ModelIntervalCheckpoint(model_path, interval=log_interval)
tensorboard = TensorboardLogger(tensorboard_path)
reduce_rl = ReduceLROnPlateau(monitor='loss', factor=0.9, patience=3)
callbacks=[file_logger, checkpoint, tensorboard]
# enable the dueling network
# you can specify the dueling_type to one of {'avg','max','naive'}
dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory, nb_steps_warmup=512,
               enable_dueling_network=True, dueling_type='avg', target_model_update=1e-2, policy=policy,
               processor=processor, batch_size=512)
dqn.compile(Adam(lr=1e-4), metrics=['mae'])
if os.path.isfile(model_path):
    dqn.load_weights(model_path)

# %%
history = dqn.fit(env_wrapper, nb_steps=number_of_training_steps, visualize=False, verbose=2,
        nb_max_episode_steps=env._max_steps,
                  callbacks=callbacks)
# Out:
# Training for 5000000 steps ...
#       33/5000000: episode: 1, duration: 0.518s, episode steps: 33, steps per second: 64, episode reward: -1.000, mean reward: -0.030 [-1.000, 0.000], mean action: 2.273 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      125/5000000: episode: 2, duration: 1.386s, episode steps: 92, steps per second: 66, episode reward: -1.000, mean reward: -0.011 [-1.000, 0.000], mean action: 2.772 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      185/5000000: episode: 3, duration: 0.926s, episode steps: 60, steps per second: 65, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 2.367 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      212/5000000: episode: 4, duration: 0.514s, episode steps: 27, steps per second: 52, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 3.000 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      239/5000000: episode: 5, duration: 0.436s, episode steps: 27, steps per second: 62, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.704 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      280/5000000: episode: 6, duration: 0.664s, episode steps: 41, steps per second: 62, episode reward: -1.000, mean reward: -0.024 [-1.000, 0.000], mean action: 2.659 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      309/5000000: episode: 7, duration: 0.471s, episode steps: 29, steps per second: 62, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.517 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      340/5000000: episode: 8, duration: 0.544s, episode steps: 31, steps per second: 57, episode reward: -1.000, mean reward: -0.032 [-1.000, 0.000], mean action: 2.581 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      375/5000000: episode: 9, duration: 0.554s, episode steps: 35, steps per second: 63, episode reward: -1.000, mean reward: -0.029 [-1.000, 0.000], mean action: 1.971 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      429/5000000: episode: 10, duration: 0.839s, episode steps: 54, steps per second: 64, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 2.611 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      455/5000000: episode: 11, duration: 0.411s, episode steps: 26, steps per second: 63, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.538 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#      523/5000000: episode: 12, duration: 1.709s, episode steps: 68, steps per second: 40, episode reward: -1.000, mean reward: -0.015 [-1.000, 0.000], mean action: 2.485 [0.000, 5.000], mean observation: 0.061 [0.000, 24.000], loss: 0.002704, mean_absolute_error: 0.471644, mean_q: -0.555492
#      583/5000000: episode: 13, duration: 2.890s, episode steps: 60, steps per second: 21, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 2.533 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.002006, mean_absolute_error: 0.466057, mean_q: -0.546330
#      640/5000000: episode: 14, duration: 2.915s, episode steps: 57, steps per second: 20, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 2.509 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.001751, mean_absolute_error: 0.449056, mean_q: -0.519576
#      665/5000000: episode: 15, duration: 1.193s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.280 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.001475, mean_absolute_error: 0.454260, mean_q: -0.525556
#      693/5000000: episode: 16, duration: 1.386s, episode steps: 28, steps per second: 20, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 2.679 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.001345, mean_absolute_error: 0.459423, mean_q: -0.532692
#      728/5000000: episode: 17, duration: 1.809s, episode steps: 35, steps per second: 19, episode reward: -1.000, mean reward: -0.029 [-1.000, 0.000], mean action: 2.257 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.001239, mean_absolute_error: 0.461751, mean_q: -0.535579
#      881/5000000: episode: 18, duration: 7.615s, episode steps: 153, steps per second: 20, episode reward: -1.000, mean reward: -0.007 [-1.000, 0.000], mean action: 2.536 [0.000, 5.000], mean observation: 0.066 [0.000, 24.000], loss: 0.000938, mean_absolute_error: 0.466442, mean_q: -0.542934
#      965/5000000: episode: 19, duration: 4.117s, episode steps: 84, steps per second: 20, episode reward: -1.000, mean reward: -0.012 [-1.000, 0.000], mean action: 2.750 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000710, mean_absolute_error: 0.475632, mean_q: -0.555081
#      993/5000000: episode: 20, duration: 1.495s, episode steps: 28, steps per second: 19, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 2.286 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000742, mean_absolute_error: 0.485309, mean_q: -0.564596
#     1021/5000000: episode: 21, duration: 1.491s, episode steps: 28, steps per second: 19, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 2.107 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000793, mean_absolute_error: 0.479687, mean_q: -0.557969
#     1050/5000000: episode: 22, duration: 1.376s, episode steps: 29, steps per second: 21, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.172 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000718, mean_absolute_error: 0.473092, mean_q: -0.550538
#     1081/5000000: episode: 23, duration: 1.488s, episode steps: 31, steps per second: 21, episode reward: -1.000, mean reward: -0.032 [-1.000, 0.000], mean action: 2.774 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000672, mean_absolute_error: 0.468167, mean_q: -0.545559
#     1164/5000000: episode: 24, duration: 4.087s, episode steps: 83, steps per second: 20, episode reward: -1.000, mean reward: -0.012 [-1.000, 0.000], mean action: 2.554 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000646, mean_absolute_error: 0.460842, mean_q: -0.537125
#     1207/5000000: episode: 25, duration: 2.165s, episode steps: 43, steps per second: 20, episode reward: -1.000, mean reward: -0.023 [-1.000, 0.000], mean action: 2.326 [0.000, 5.000], mean observation: 0.067 [0.000, 24.000], loss: 0.000667, mean_absolute_error: 0.455507, mean_q: -0.530443
#     1277/5000000: episode: 26, duration: 3.280s, episode steps: 70, steps per second: 21, episode reward: -1.000, mean reward: -0.014 [-1.000, 0.000], mean action: 2.529 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.000650, mean_absolute_error: 0.462012, mean_q: -0.539895
#     1316/5000000: episode: 27, duration: 1.880s, episode steps: 39, steps per second: 21, episode reward: -1.000, mean reward: -0.026 [-1.000, 0.000], mean action: 2.179 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000651, mean_absolute_error: 0.471489, mean_q: -0.551225
#     1386/5000000: episode: 28, duration: 3.411s, episode steps: 70, steps per second: 21, episode reward: -1.000, mean reward: -0.014 [-1.000, 0.000], mean action: 2.686 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.000674, mean_absolute_error: 0.468890, mean_q: -0.548148
#     1411/5000000: episode: 29, duration: 1.120s, episode steps: 25, steps per second: 22, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.640 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000838, mean_absolute_error: 0.462701, mean_q: -0.540479
#     1446/5000000: episode: 30, duration: 1.692s, episode steps: 35, steps per second: 21, episode reward: -1.000, mean reward: -0.029 [-1.000, 0.000], mean action: 2.029 [0.000, 5.000], mean observation: 0.066 [0.000, 24.000], loss: 0.000702, mean_absolute_error: 0.460401, mean_q: -0.538457
#     1477/5000000: episode: 31, duration: 1.485s, episode steps: 31, steps per second: 21, episode reward: -1.000, mean reward: -0.032 [-1.000, 0.000], mean action: 2.742 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000697, mean_absolute_error: 0.460561, mean_q: -0.539018
#     1592/5000000: episode: 32, duration: 5.345s, episode steps: 115, steps per second: 22, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 2.374 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000663, mean_absolute_error: 0.460218, mean_q: -0.538551
#     1755/5000000: episode: 33, duration: 7.828s, episode steps: 163, steps per second: 21, episode reward: -1.000, mean reward: -0.006 [-1.000, 0.000], mean action: 2.491 [0.000, 5.000], mean observation: 0.058 [0.000, 24.000], loss: 0.000660, mean_absolute_error: 0.450223, mean_q: -0.526348
#     1810/5000000: episode: 34, duration: 2.592s, episode steps: 55, steps per second: 21, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 2.709 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000702, mean_absolute_error: 0.441382, mean_q: -0.516001
#     1835/5000000: episode: 35, duration: 1.326s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.440 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000716, mean_absolute_error: 0.442241, mean_q: -0.516654
#     1889/5000000: episode: 36, duration: 2.572s, episode steps: 54, steps per second: 21, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 2.537 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000775, mean_absolute_error: 0.438551, mean_q: -0.511607
#     1958/5000000: episode: 37, duration: 3.449s, episode steps: 69, steps per second: 20, episode reward: -1.000, mean reward: -0.014 [-1.000, 0.000], mean action: 2.493 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000715, mean_absolute_error: 0.437922, mean_q: -0.511065
#     1984/5000000: episode: 38, duration: 1.240s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.308 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000727, mean_absolute_error: 0.435431, mean_q: -0.505853
#     2098/5000000: episode: 39, duration: 5.337s, episode steps: 114, steps per second: 21, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 2.500 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000799, mean_absolute_error: 0.428935, mean_q: -0.498473
#     2161/5000000: episode: 40, duration: 3.021s, episode steps: 63, steps per second: 21, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 2.556 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000761, mean_absolute_error: 0.426130, mean_q: -0.495471
#     2186/5000000: episode: 41, duration: 1.216s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.560 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000757, mean_absolute_error: 0.427571, mean_q: -0.497914
#     2268/5000000: episode: 42, duration: 4.258s, episode steps: 82, steps per second: 19, episode reward: -1.000, mean reward: -0.012 [-1.000, 0.000], mean action: 2.890 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000760, mean_absolute_error: 0.429115, mean_q: -0.500570
#     2294/5000000: episode: 43, duration: 1.262s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.269 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000735, mean_absolute_error: 0.431645, mean_q: -0.503483
#     2376/5000000: episode: 44, duration: 4.050s, episode steps: 82, steps per second: 20, episode reward: -1.000, mean reward: -0.012 [-1.000, 0.000], mean action: 2.415 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000772, mean_absolute_error: 0.433504, mean_q: -0.505576
#     2408/5000000: episode: 45, duration: 1.681s, episode steps: 32, steps per second: 19, episode reward: -1.000, mean reward: -0.031 [-1.000, 0.000], mean action: 3.062 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000733, mean_absolute_error: 0.436498, mean_q: -0.509293
#     2434/5000000: episode: 46, duration: 1.233s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.154 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000693, mean_absolute_error: 0.437607, mean_q: -0.510363
#     2460/5000000: episode: 47, duration: 1.437s, episode steps: 26, steps per second: 18, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.385 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000710, mean_absolute_error: 0.433637, mean_q: -0.505566
#     2487/5000000: episode: 48, duration: 1.332s, episode steps: 27, steps per second: 20, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.519 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000676, mean_absolute_error: 0.436220, mean_q: -0.508942
#     2588/5000000: episode: 49, duration: 5.119s, episode steps: 101, steps per second: 20, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 2.416 [0.000, 5.000], mean observation: 0.066 [0.000, 24.000], loss: 0.000742, mean_absolute_error: 0.438075, mean_q: -0.511411
#     2645/5000000: episode: 50, duration: 2.757s, episode steps: 57, steps per second: 21, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 2.298 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000778, mean_absolute_error: 0.439233, mean_q: -0.512939
#     2753/5000000: episode: 51, duration: 5.063s, episode steps: 108, steps per second: 21, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 2.574 [0.000, 5.000], mean observation: 0.066 [0.000, 24.000], loss: 0.000726, mean_absolute_error: 0.440230, mean_q: -0.513773
#     2778/5000000: episode: 52, duration: 1.171s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 3.240 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000753, mean_absolute_error: 0.440784, mean_q: -0.514410
#     2804/5000000: episode: 53, duration: 1.223s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.615 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000768, mean_absolute_error: 0.439195, mean_q: -0.512589
#     2839/5000000: episode: 54, duration: 1.851s, episode steps: 35, steps per second: 19, episode reward: -1.000, mean reward: -0.029 [-1.000, 0.000], mean action: 2.143 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000706, mean_absolute_error: 0.441292, mean_q: -0.515218
#     2865/5000000: episode: 55, duration: 1.393s, episode steps: 26, steps per second: 19, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.500 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000736, mean_absolute_error: 0.439749, mean_q: -0.513448
#     2892/5000000: episode: 56, duration: 1.433s, episode steps: 27, steps per second: 19, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.963 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000775, mean_absolute_error: 0.439391, mean_q: -0.512419
#     2917/5000000: episode: 57, duration: 1.202s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.360 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000806, mean_absolute_error: 0.440285, mean_q: -0.513945
#     3114/5000000: episode: 58, duration: 9.556s, episode steps: 197, steps per second: 21, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 2.426 [0.000, 5.000], mean observation: 0.063 [0.000, 24.000], loss: 0.000748, mean_absolute_error: 0.442586, mean_q: -0.516471
#     3145/5000000: episode: 59, duration: 1.495s, episode steps: 31, steps per second: 21, episode reward: -1.000, mean reward: -0.032 [-1.000, 0.000], mean action: 2.484 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000821, mean_absolute_error: 0.447495, mean_q: -0.521802
#     3171/5000000: episode: 60, duration: 1.282s, episode steps: 26, steps per second: 20, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.346 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000813, mean_absolute_error: 0.448672, mean_q: -0.523429
#     3200/5000000: episode: 61, duration: 1.394s, episode steps: 29, steps per second: 21, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.172 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.000787, mean_absolute_error: 0.448954, mean_q: -0.523448
#     3225/5000000: episode: 62, duration: 1.266s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.440 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000779, mean_absolute_error: 0.446745, mean_q: -0.520686
#     3250/5000000: episode: 63, duration: 1.207s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.960 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000795, mean_absolute_error: 0.449035, mean_q: -0.523966
#     3275/5000000: episode: 64, duration: 1.245s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.440 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000708, mean_absolute_error: 0.446692, mean_q: -0.521040
#     3407/5000000: episode: 65, duration: 6.428s, episode steps: 132, steps per second: 21, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 2.591 [0.000, 5.000], mean observation: 0.067 [0.000, 24.000], loss: 0.000784, mean_absolute_error: 0.450025, mean_q: -0.524115
#     3434/5000000: episode: 66, duration: 1.255s, episode steps: 27, steps per second: 22, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.778 [0.000, 5.000], mean observation: 0.064 [0.000, 24.000], loss: 0.000885, mean_absolute_error: 0.455813, mean_q: -0.530805
#     3460/5000000: episode: 67, duration: 1.259s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.308 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.000891, mean_absolute_error: 0.456832, mean_q: -0.531504
#     3485/5000000: episode: 68, duration: 1.238s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.400 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000943, mean_absolute_error: 0.457743, mean_q: -0.532506
#     3510/5000000: episode: 69, duration: 1.274s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.880 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000796, mean_absolute_error: 0.456873, mean_q: -0.531462
#     3539/5000000: episode: 70, duration: 1.468s, episode steps: 29, steps per second: 20, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.793 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000875, mean_absolute_error: 0.459945, mean_q: -0.534962
#     3601/5000000: episode: 71, duration: 2.815s, episode steps: 62, steps per second: 22, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 2.565 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000872, mean_absolute_error: 0.454624, mean_q: -0.528119
#     3633/5000000: episode: 72, duration: 1.664s, episode steps: 32, steps per second: 19, episode reward: -1.000, mean reward: -0.031 [-1.000, 0.000], mean action: 2.500 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000780, mean_absolute_error: 0.453599, mean_q: -0.527414
#     3677/5000000: episode: 73, duration: 2.210s, episode steps: 44, steps per second: 20, episode reward: -1.000, mean reward: -0.023 [-1.000, 0.000], mean action: 2.341 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000864, mean_absolute_error: 0.449895, mean_q: -0.523246
#     3705/5000000: episode: 74, duration: 1.353s, episode steps: 28, steps per second: 21, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 3.036 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.001004, mean_absolute_error: 0.449455, mean_q: -0.521974
#     3739/5000000: episode: 75, duration: 1.558s, episode steps: 34, steps per second: 22, episode reward: -1.000, mean reward: -0.029 [-1.000, 0.000], mean action: 2.647 [0.000, 5.000], mean observation: 0.067 [0.000, 24.000], loss: 0.000905, mean_absolute_error: 0.448265, mean_q: -0.520368
#     3923/5000000: episode: 76, duration: 9.151s, episode steps: 184, steps per second: 20, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 2.571 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000945, mean_absolute_error: 0.451834, mean_q: -0.524474
#     3954/5000000: episode: 77, duration: 1.468s, episode steps: 31, steps per second: 21, episode reward: -1.000, mean reward: -0.032 [-1.000, 0.000], mean action: 2.516 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000970, mean_absolute_error: 0.450496, mean_q: -0.523033
#     3994/5000000: episode: 78, duration: 1.911s, episode steps: 40, steps per second: 21, episode reward: -1.000, mean reward: -0.025 [-1.000, 0.000], mean action: 2.625 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000970, mean_absolute_error: 0.449921, mean_q: -0.522081
#     4031/5000000: episode: 79, duration: 1.815s, episode steps: 37, steps per second: 20, episode reward: -1.000, mean reward: -0.027 [-1.000, 0.000], mean action: 2.297 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000960, mean_absolute_error: 0.446922, mean_q: -0.519143
#     4252/5000000: episode: 80, duration: 10.249s, episode steps: 221, steps per second: 22, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 2.475 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.000924, mean_absolute_error: 0.444757, mean_q: -0.516530
#     4546/5000000: episode: 81, duration: 14.252s, episode steps: 294, steps per second: 21, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 2.517 [0.000, 5.000], mean observation: 0.061 [0.000, 24.000], loss: 0.000954, mean_absolute_error: 0.444713, mean_q: -0.516746
#     4744/5000000: episode: 82, duration: 9.278s, episode steps: 198, steps per second: 21, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 2.328 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.000937, mean_absolute_error: 0.449962, mean_q: -0.523226
#     4798/5000000: episode: 83, duration: 2.516s, episode steps: 54, steps per second: 21, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 2.389 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000920, mean_absolute_error: 0.456147, mean_q: -0.530734
#     4829/5000000: episode: 84, duration: 1.530s, episode steps: 31, steps per second: 20, episode reward: -1.000, mean reward: -0.032 [-1.000, 0.000], mean action: 2.452 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000921, mean_absolute_error: 0.453659, mean_q: -0.527644
#     4855/5000000: episode: 85, duration: 1.258s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.500 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000910, mean_absolute_error: 0.456736, mean_q: -0.530281
#     4881/5000000: episode: 86, duration: 1.349s, episode steps: 26, steps per second: 19, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.731 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000903, mean_absolute_error: 0.457689, mean_q: -0.532551
#     4906/5000000: episode: 87, duration: 1.170s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 3.000 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000945, mean_absolute_error: 0.456025, mean_q: -0.530606
#     4938/5000000: episode: 88, duration: 1.587s, episode steps: 32, steps per second: 20, episode reward: -1.000, mean reward: -0.031 [-1.000, 0.000], mean action: 2.875 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000907, mean_absolute_error: 0.455043, mean_q: -0.529358
#     4992/5000000: episode: 89, duration: 2.633s, episode steps: 54, steps per second: 21, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 3.074 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000920, mean_absolute_error: 0.454852, mean_q: -0.529004
#     5025/5000000: episode: 90, duration: 2.586s, episode steps: 33, steps per second: 13, episode reward: -1.000, mean reward: -0.030 [-1.000, 0.000], mean action: 2.515 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000934, mean_absolute_error: 0.451426, mean_q: -0.524531
#     5221/5000000: episode: 91, duration: 9.613s, episode steps: 196, steps per second: 20, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 2.658 [0.000, 5.000], mean observation: 0.063 [0.000, 24.000], loss: 0.000955, mean_absolute_error: 0.448521, mean_q: -0.520540
#     5246/5000000: episode: 92, duration: 1.253s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 3.160 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.001120, mean_absolute_error: 0.444306, mean_q: -0.514439
#     5360/5000000: episode: 93, duration: 5.593s, episode steps: 114, steps per second: 20, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 2.754 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000990, mean_absolute_error: 0.445201, mean_q: -0.516127
#     5416/5000000: episode: 94, duration: 2.842s, episode steps: 56, steps per second: 20, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 2.357 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.001001, mean_absolute_error: 0.441621, mean_q: -0.512625
#     5441/5000000: episode: 95, duration: 1.196s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.360 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.001189, mean_absolute_error: 0.440810, mean_q: -0.510780
#     5466/5000000: episode: 96, duration: 1.160s, episode steps: 25, steps per second: 22, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.360 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.001129, mean_absolute_error: 0.440547, mean_q: -0.511016
#     5491/5000000: episode: 97, duration: 1.247s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.600 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.001130, mean_absolute_error: 0.439554, mean_q: -0.510224
#     5516/5000000: episode: 98, duration: 1.270s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.120 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.001112, mean_absolute_error: 0.441169, mean_q: -0.511999
#     5541/5000000: episode: 99, duration: 1.285s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.840 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.001029, mean_absolute_error: 0.438523, mean_q: -0.508694
#     5566/5000000: episode: 100, duration: 1.270s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 3.160 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.000987, mean_absolute_error: 0.441700, mean_q: -0.512369
#     5643/5000000: episode: 101, duration: 3.822s, episode steps: 77, steps per second: 20, episode reward: -1.000, mean reward: -0.013 [-1.000, 0.000], mean action: 2.429 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.001017, mean_absolute_error: 0.437296, mean_q: -0.507635
#     5696/5000000: episode: 102, duration: 2.443s, episode steps: 53, steps per second: 22, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 2.528 [0.000, 5.000], mean observation: 0.067 [0.000, 24.000], loss: 0.000978, mean_absolute_error: 0.437841, mean_q: -0.508556
#     5721/5000000: episode: 103, duration: 1.341s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.720 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000976, mean_absolute_error: 0.438695, mean_q: -0.509261
#     5790/5000000: episode: 104, duration: 3.358s, episode steps: 69, steps per second: 21, episode reward: -1.000, mean reward: -0.014 [-1.000, 0.000], mean action: 2.580 [0.000, 5.000], mean observation: 0.073 [0.000, 24.000], loss: 0.001052, mean_absolute_error: 0.436452, mean_q: -0.507250
#     5816/5000000: episode: 105, duration: 1.273s, episode steps: 26, steps per second: 20, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.731 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000929, mean_absolute_error: 0.435860, mean_q: -0.507218
#     5844/5000000: episode: 106, duration: 1.519s, episode steps: 28, steps per second: 18, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 2.500 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000992, mean_absolute_error: 0.433673, mean_q: -0.503798
#     5897/5000000: episode: 107, duration: 2.532s, episode steps: 53, steps per second: 21, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 2.585 [0.000, 5.000], mean observation: 0.073 [0.000, 24.000], loss: 0.000986, mean_absolute_error: 0.434597, mean_q: -0.504549
#     5924/5000000: episode: 108, duration: 1.269s, episode steps: 27, steps per second: 21, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 3.148 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000991, mean_absolute_error: 0.431467, mean_q: -0.501267
#     5949/5000000: episode: 109, duration: 1.196s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.800 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.000980, mean_absolute_error: 0.433525, mean_q: -0.503749
#     5974/5000000: episode: 110, duration: 1.224s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.440 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.001016, mean_absolute_error: 0.436581, mean_q: -0.507310
#     6021/5000000: episode: 111, duration: 2.371s, episode steps: 47, steps per second: 20, episode reward: -1.000, mean reward: -0.021 [-1.000, 0.000], mean action: 2.447 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000928, mean_absolute_error: 0.437129, mean_q: -0.508387
#     6117/5000000: episode: 112, duration: 4.391s, episode steps: 96, steps per second: 22, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 2.521 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000923, mean_absolute_error: 0.434925, mean_q: -0.506216
#     6169/5000000: episode: 113, duration: 2.506s, episode steps: 52, steps per second: 21, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 2.327 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000945, mean_absolute_error: 0.434879, mean_q: -0.505518
#     6222/5000000: episode: 114, duration: 2.629s, episode steps: 53, steps per second: 20, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 2.509 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000912, mean_absolute_error: 0.435989, mean_q: -0.507158
#     6247/5000000: episode: 115, duration: 1.178s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.360 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000834, mean_absolute_error: 0.434703, mean_q: -0.506496
#     6371/5000000: episode: 116, duration: 5.701s, episode steps: 124, steps per second: 22, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 2.331 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000850, mean_absolute_error: 0.435202, mean_q: -0.507041
#     6435/5000000: episode: 117, duration: 3.125s, episode steps: 64, steps per second: 20, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 2.000 [0.000, 5.000], mean observation: 0.066 [0.000, 24.000], loss: 0.000880, mean_absolute_error: 0.435194, mean_q: -0.507706
#     6461/5000000: episode: 118, duration: 1.305s, episode steps: 26, steps per second: 20, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.808 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000947, mean_absolute_error: 0.437327, mean_q: -0.509450
#     6490/5000000: episode: 119, duration: 1.471s, episode steps: 29, steps per second: 20, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.759 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000993, mean_absolute_error: 0.434963, mean_q: -0.506764
#     6601/5000000: episode: 120, duration: 5.401s, episode steps: 111, steps per second: 21, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 2.207 [0.000, 5.000], mean observation: 0.064 [0.000, 24.000], loss: 0.000914, mean_absolute_error: 0.437006, mean_q: -0.508704
#     6745/5000000: episode: 121, duration: 7.128s, episode steps: 144, steps per second: 20, episode reward: -1.000, mean reward: -0.007 [-1.000, 0.000], mean action: 2.639 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.000934, mean_absolute_error: 0.438839, mean_q: -0.511660
#     6770/5000000: episode: 122, duration: 1.200s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.880 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000919, mean_absolute_error: 0.444824, mean_q: -0.517937
#     6795/5000000: episode: 123, duration: 1.262s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 1.960 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000910, mean_absolute_error: 0.441258, mean_q: -0.514205
#     6832/5000000: episode: 124, duration: 1.868s, episode steps: 37, steps per second: 20, episode reward: -1.000, mean reward: -0.027 [-1.000, 0.000], mean action: 2.351 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000956, mean_absolute_error: 0.440369, mean_q: -0.513476
#     6895/5000000: episode: 125, duration: 3.242s, episode steps: 63, steps per second: 19, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 2.460 [0.000, 5.000], mean observation: 0.067 [0.000, 24.000], loss: 0.000974, mean_absolute_error: 0.438909, mean_q: -0.511772
#     6920/5000000: episode: 126, duration: 1.223s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 3.120 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.001014, mean_absolute_error: 0.439451, mean_q: -0.511671
#     6945/5000000: episode: 127, duration: 1.338s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 1.960 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.001036, mean_absolute_error: 0.439144, mean_q: -0.511669
#     7067/5000000: episode: 128, duration: 5.903s, episode steps: 122, steps per second: 21, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 2.574 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.001007, mean_absolute_error: 0.437489, mean_q: -0.509485
#     7125/5000000: episode: 129, duration: 2.942s, episode steps: 58, steps per second: 20, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 2.569 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000883, mean_absolute_error: 0.437552, mean_q: -0.509368
#     7150/5000000: episode: 130, duration: 1.218s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.560 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.000927, mean_absolute_error: 0.437451, mean_q: -0.509050
#     7175/5000000: episode: 131, duration: 1.289s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.760 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000905, mean_absolute_error: 0.435479, mean_q: -0.506969
#     7456/5000000: episode: 132, duration: 13.990s, episode steps: 281, steps per second: 20, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 2.463 [0.000, 5.000], mean observation: 0.066 [0.000, 24.000], loss: 0.000985, mean_absolute_error: 0.438113, mean_q: -0.509765
#     7572/5000000: episode: 133, duration: 5.616s, episode steps: 116, steps per second: 21, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 2.517 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.001010, mean_absolute_error: 0.443053, mean_q: -0.516497
#     7597/5000000: episode: 134, duration: 1.299s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.400 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000984, mean_absolute_error: 0.441410, mean_q: -0.514123
#     7694/5000000: episode: 135, duration: 4.463s, episode steps: 97, steps per second: 22, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 2.546 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000971, mean_absolute_error: 0.442646, mean_q: -0.514579
#     7833/5000000: episode: 136, duration: 6.621s, episode steps: 139, steps per second: 21, episode reward: -1.000, mean reward: -0.007 [-1.000, 0.000], mean action: 2.748 [0.000, 5.000], mean observation: 0.061 [0.000, 24.000], loss: 0.001017, mean_absolute_error: 0.441736, mean_q: -0.512212
#     7859/5000000: episode: 137, duration: 1.357s, episode steps: 26, steps per second: 19, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.077 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.001008, mean_absolute_error: 0.444793, mean_q: -0.515794
#     7898/5000000: episode: 138, duration: 1.942s, episode steps: 39, steps per second: 20, episode reward: -1.000, mean reward: -0.026 [-1.000, 0.000], mean action: 2.154 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.001017, mean_absolute_error: 0.443164, mean_q: -0.513970
#     7925/5000000: episode: 139, duration: 1.272s, episode steps: 27, steps per second: 21, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.778 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000967, mean_absolute_error: 0.444800, mean_q: -0.516346
#     7954/5000000: episode: 140, duration: 1.362s, episode steps: 29, steps per second: 21, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 3.138 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.000971, mean_absolute_error: 0.442708, mean_q: -0.513920
#     7989/5000000: episode: 141, duration: 1.632s, episode steps: 35, steps per second: 21, episode reward: -1.000, mean reward: -0.029 [-1.000, 0.000], mean action: 2.600 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.001012, mean_absolute_error: 0.443438, mean_q: -0.513748
#     8018/5000000: episode: 142, duration: 6.241s, episode steps: 29, steps per second: 5, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.448 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000982, mean_absolute_error: 0.441954, mean_q: -0.512684
#     8058/5000000: episode: 143, duration: 2.049s, episode steps: 40, steps per second: 20, episode reward: -1.000, mean reward: -0.025 [-1.000, 0.000], mean action: 2.425 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.001065, mean_absolute_error: 0.441342, mean_q: -0.510354
#     8177/5000000: episode: 144, duration: 5.865s, episode steps: 119, steps per second: 20, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 2.605 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.000973, mean_absolute_error: 0.441767, mean_q: -0.511637
#     8206/5000000: episode: 145, duration: 1.538s, episode steps: 29, steps per second: 19, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.966 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000927, mean_absolute_error: 0.448398, mean_q: -0.520859
#     8233/5000000: episode: 146, duration: 1.242s, episode steps: 27, steps per second: 22, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.778 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000981, mean_absolute_error: 0.445639, mean_q: -0.517556
#     8401/5000000: episode: 147, duration: 8.115s, episode steps: 168, steps per second: 21, episode reward: -1.000, mean reward: -0.006 [-1.000, 0.000], mean action: 2.208 [0.000, 5.000], mean observation: 0.067 [0.000, 24.000], loss: 0.000947, mean_absolute_error: 0.445676, mean_q: -0.517804
#     8427/5000000: episode: 148, duration: 1.244s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.654 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.000986, mean_absolute_error: 0.448559, mean_q: -0.520369
#     8529/5000000: episode: 149, duration: 5.109s, episode steps: 102, steps per second: 20, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 2.618 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000970, mean_absolute_error: 0.448947, mean_q: -0.520982
#     8566/5000000: episode: 150, duration: 1.771s, episode steps: 37, steps per second: 21, episode reward: -1.000, mean reward: -0.027 [-1.000, 0.000], mean action: 2.297 [0.000, 5.000], mean observation: 0.062 [0.000, 24.000], loss: 0.000981, mean_absolute_error: 0.448260, mean_q: -0.520358
#     8594/5000000: episode: 151, duration: 1.472s, episode steps: 28, steps per second: 19, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 2.107 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.000993, mean_absolute_error: 0.447404, mean_q: -0.517411
#     8776/5000000: episode: 152, duration: 8.440s, episode steps: 182, steps per second: 22, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 2.286 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000938, mean_absolute_error: 0.452381, mean_q: -0.525100
#     8819/5000000: episode: 153, duration: 2.063s, episode steps: 43, steps per second: 21, episode reward: -1.000, mean reward: -0.023 [-1.000, 0.000], mean action: 2.372 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000989, mean_absolute_error: 0.458900, mean_q: -0.531880
#     8880/5000000: episode: 154, duration: 2.866s, episode steps: 61, steps per second: 21, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 2.311 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000980, mean_absolute_error: 0.456338, mean_q: -0.529041
#     8920/5000000: episode: 155, duration: 2.064s, episode steps: 40, steps per second: 19, episode reward: -1.000, mean reward: -0.025 [-1.000, 0.000], mean action: 2.475 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.001032, mean_absolute_error: 0.455840, mean_q: -0.528422
#     8954/5000000: episode: 156, duration: 1.581s, episode steps: 34, steps per second: 22, episode reward: -1.000, mean reward: -0.029 [-1.000, 0.000], mean action: 2.176 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000951, mean_absolute_error: 0.456939, mean_q: -0.530709
#     9044/5000000: episode: 157, duration: 4.121s, episode steps: 90, steps per second: 22, episode reward: -1.000, mean reward: -0.011 [-1.000, 0.000], mean action: 2.433 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000981, mean_absolute_error: 0.454349, mean_q: -0.527521
#     9077/5000000: episode: 158, duration: 1.631s, episode steps: 33, steps per second: 20, episode reward: -1.000, mean reward: -0.030 [-1.000, 0.000], mean action: 2.545 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000990, mean_absolute_error: 0.457085, mean_q: -0.529317
#     9131/5000000: episode: 159, duration: 2.681s, episode steps: 54, steps per second: 20, episode reward: -1.000, mean reward: -0.019 [-1.000, 0.000], mean action: 2.907 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.001029, mean_absolute_error: 0.455663, mean_q: -0.528656
#     9276/5000000: episode: 160, duration: 6.378s, episode steps: 145, steps per second: 23, episode reward: -1.000, mean reward: -0.007 [-1.000, 0.000], mean action: 2.345 [0.000, 5.000], mean observation: 0.063 [0.000, 24.000], loss: 0.000980, mean_absolute_error: 0.454846, mean_q: -0.527197
#     9302/5000000: episode: 161, duration: 1.243s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.846 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.000964, mean_absolute_error: 0.456571, mean_q: -0.529580
#     9327/5000000: episode: 162, duration: 1.184s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.400 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000962, mean_absolute_error: 0.455130, mean_q: -0.527885
#     9413/5000000: episode: 163, duration: 4.057s, episode steps: 86, steps per second: 21, episode reward: -1.000, mean reward: -0.012 [-1.000, 0.000], mean action: 2.384 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.000959, mean_absolute_error: 0.454519, mean_q: -0.527108
#     9439/5000000: episode: 164, duration: 1.238s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.423 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.000917, mean_absolute_error: 0.458116, mean_q: -0.532407
# ...
#   662101/5000000: episode: 11017, duration: 1.259s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.240 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.022638, mean_absolute_error: 0.715151, mean_q: 0.518700
#   662166/5000000: episode: 11018, duration: 3.246s, episode steps: 65, steps per second: 20, episode reward: -1.000, mean reward: -0.015 [-1.000, 0.000], mean action: 2.631 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.021897, mean_absolute_error: 0.717061, mean_q: 0.527378
#   662191/5000000: episode: 11019, duration: 1.257s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.760 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.020487, mean_absolute_error: 0.707550, mean_q: 0.522207
#   662216/5000000: episode: 11020, duration: 1.223s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.120 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.021438, mean_absolute_error: 0.722441, mean_q: 0.528371
#   662308/5000000: episode: 11021, duration: 4.481s, episode steps: 92, steps per second: 21, episode reward: -1.000, mean reward: -0.011 [-1.000, 0.000], mean action: 2.783 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.022716, mean_absolute_error: 0.713373, mean_q: 0.516243
#   662335/5000000: episode: 11022, duration: 1.432s, episode steps: 27, steps per second: 19, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 3.000 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.021445, mean_absolute_error: 0.702702, mean_q: 0.516869
#   662465/5000000: episode: 11023, duration: 6.482s, episode steps: 130, steps per second: 20, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 2.754 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.023431, mean_absolute_error: 0.698598, mean_q: 0.508966
#   662494/5000000: episode: 11024, duration: 1.484s, episode steps: 29, steps per second: 20, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.310 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.022878, mean_absolute_error: 0.698004, mean_q: 0.499543
#   662551/5000000: episode: 11025, duration: 3.001s, episode steps: 57, steps per second: 19, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 2.491 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.022117, mean_absolute_error: 0.700569, mean_q: 0.510819
#   662579/5000000: episode: 11026, duration: 1.343s, episode steps: 28, steps per second: 21, episode reward: -1.000, mean reward: -0.036 [-1.000, 0.000], mean action: 2.321 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.021739, mean_absolute_error: 0.709593, mean_q: 0.503329
#   662840/5000000: episode: 11027, duration: 11.943s, episode steps: 261, steps per second: 22, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 2.464 [0.000, 5.000], mean observation: 0.060 [0.000, 24.000], loss: 0.021771, mean_absolute_error: 0.697419, mean_q: 0.494710
#   662867/5000000: episode: 11028, duration: 1.306s, episode steps: 27, steps per second: 21, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.519 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.020654, mean_absolute_error: 0.705879, mean_q: 0.486895
#   662892/5000000: episode: 11029, duration: 1.328s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.280 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.023370, mean_absolute_error: 0.695153, mean_q: 0.491123
#   662919/5000000: episode: 11030, duration: 1.289s, episode steps: 27, steps per second: 21, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.333 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.022415, mean_absolute_error: 0.693322, mean_q: 0.486856
#   662978/5000000: episode: 11031, duration: 3.026s, episode steps: 59, steps per second: 20, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 2.322 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.021659, mean_absolute_error: 0.696883, mean_q: 0.490594
#   663003/5000000: episode: 11032, duration: 1.267s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.560 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.019982, mean_absolute_error: 0.707445, mean_q: 0.481928
#   663061/5000000: episode: 11033, duration: 2.713s, episode steps: 58, steps per second: 21, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 2.310 [0.000, 5.000], mean observation: 0.066 [0.000, 24.000], loss: 0.022033, mean_absolute_error: 0.692563, mean_q: 0.486168
#   663086/5000000: episode: 11034, duration: 1.253s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.920 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.018947, mean_absolute_error: 0.692325, mean_q: 0.481245
#   663112/5000000: episode: 11035, duration: 1.234s, episode steps: 26, steps per second: 21, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.885 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.020285, mean_absolute_error: 0.691299, mean_q: 0.480973
#   663211/5000000: episode: 11036, duration: 4.808s, episode steps: 99, steps per second: 21, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 2.747 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.021226, mean_absolute_error: 0.690666, mean_q: 0.475063
#   663274/5000000: episode: 11037, duration: 3.102s, episode steps: 63, steps per second: 20, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 2.587 [0.000, 5.000], mean observation: 0.067 [0.000, 24.000], loss: 0.023544, mean_absolute_error: 0.688345, mean_q: 0.472583
#   663306/5000000: episode: 11038, duration: 1.643s, episode steps: 32, steps per second: 19, episode reward: -1.000, mean reward: -0.031 [-1.000, 0.000], mean action: 2.594 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.019273, mean_absolute_error: 0.685079, mean_q: 0.476690
#   663332/5000000: episode: 11039, duration: 1.277s, episode steps: 26, steps per second: 20, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.538 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.023534, mean_absolute_error: 0.686606, mean_q: 0.467351
#   663361/5000000: episode: 11040, duration: 1.385s, episode steps: 29, steps per second: 21, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.793 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.023136, mean_absolute_error: 0.686377, mean_q: 0.468485
#   663394/5000000: episode: 11041, duration: 1.564s, episode steps: 33, steps per second: 21, episode reward: -1.000, mean reward: -0.030 [-1.000, 0.000], mean action: 2.455 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.020012, mean_absolute_error: 0.683334, mean_q: 0.466369
#   663419/5000000: episode: 11042, duration: 1.301s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.360 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.024817, mean_absolute_error: 0.688789, mean_q: 0.468898
#   663445/5000000: episode: 11043, duration: 1.294s, episode steps: 26, steps per second: 20, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.962 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.021623, mean_absolute_error: 0.679825, mean_q: 0.473706
#   663471/5000000: episode: 11044, duration: 1.280s, episode steps: 26, steps per second: 20, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.577 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.021539, mean_absolute_error: 0.686829, mean_q: 0.463605
#   663509/5000000: episode: 11045, duration: 1.884s, episode steps: 38, steps per second: 20, episode reward: -1.000, mean reward: -0.026 [-1.000, 0.000], mean action: 2.263 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.021560, mean_absolute_error: 0.687132, mean_q: 0.463521
#   663629/5000000: episode: 11046, duration: 5.900s, episode steps: 120, steps per second: 20, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 2.625 [0.000, 5.000], mean observation: 0.073 [0.000, 24.000], loss: 0.020387, mean_absolute_error: 0.689095, mean_q: 0.468053
#   663689/5000000: episode: 11047, duration: 2.808s, episode steps: 60, steps per second: 21, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 2.200 [0.000, 5.000], mean observation: 0.073 [0.000, 24.000], loss: 0.021236, mean_absolute_error: 0.677963, mean_q: 0.459088
#   663715/5000000: episode: 11048, duration: 1.300s, episode steps: 26, steps per second: 20, episode reward: -1.000, mean reward: -0.038 [-1.000, 0.000], mean action: 2.462 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.018831, mean_absolute_error: 0.674434, mean_q: 0.457524
#   663777/5000000: episode: 11049, duration: 3.006s, episode steps: 62, steps per second: 21, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 2.419 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.019223, mean_absolute_error: 0.676658, mean_q: 0.463889
#   663802/5000000: episode: 11050, duration: 1.269s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.200 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.019063, mean_absolute_error: 0.680421, mean_q: 0.455469
#   663847/5000000: episode: 11051, duration: 2.081s, episode steps: 45, steps per second: 22, episode reward: -1.000, mean reward: -0.022 [-1.000, 0.000], mean action: 2.044 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.020576, mean_absolute_error: 0.678536, mean_q: 0.455516
#   663944/5000000: episode: 11052, duration: 4.769s, episode steps: 97, steps per second: 20, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 2.412 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.020082, mean_absolute_error: 0.669750, mean_q: 0.455331
#   663975/5000000: episode: 11053, duration: 1.564s, episode steps: 31, steps per second: 20, episode reward: -1.000, mean reward: -0.032 [-1.000, 0.000], mean action: 2.581 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.022474, mean_absolute_error: 0.668428, mean_q: 0.451193
#   664089/5000000: episode: 11054, duration: 5.562s, episode steps: 114, steps per second: 20, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 2.553 [0.000, 5.000], mean observation: 0.066 [0.000, 24.000], loss: 0.020968, mean_absolute_error: 0.669187, mean_q: 0.448186
#   664114/5000000: episode: 11055, duration: 1.261s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.760 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.022771, mean_absolute_error: 0.663457, mean_q: 0.449965
#   664139/5000000: episode: 11056, duration: 1.191s, episode steps: 25, steps per second: 21, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.360 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.019823, mean_absolute_error: 0.663864, mean_q: 0.443371
#   664166/5000000: episode: 11057, duration: 1.318s, episode steps: 27, steps per second: 20, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.444 [0.000, 5.000], mean observation: 0.071 [0.000, 24.000], loss: 0.020996, mean_absolute_error: 0.671565, mean_q: 0.452907
#   664193/5000000: episode: 11058, duration: 1.310s, episode steps: 27, steps per second: 21, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 2.296 [0.000, 5.000], mean observation: 0.064 [0.000, 24.000], loss: 0.020023, mean_absolute_error: 0.662049, mean_q: 0.437622
#   664257/5000000: episode: 11059, duration: 3.064s, episode steps: 64, steps per second: 21, episode reward: -1.000, mean reward: -0.016 [-1.000, 0.000], mean action: 2.438 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.021908, mean_absolute_error: 0.672808, mean_q: 0.435310
#   664317/5000000: episode: 11060, duration: 2.943s, episode steps: 60, steps per second: 20, episode reward: -1.000, mean reward: -0.017 [-1.000, 0.000], mean action: 2.483 [0.000, 5.000], mean observation: 0.068 [0.000, 24.000], loss: 0.020303, mean_absolute_error: 0.662282, mean_q: 0.435184
#   664358/5000000: episode: 11061, duration: 2.035s, episode steps: 41, steps per second: 20, episode reward: -1.000, mean reward: -0.024 [-1.000, 0.000], mean action: 2.415 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.019811, mean_absolute_error: 0.665668, mean_q: 0.433532
#   664383/5000000: episode: 11062, duration: 1.228s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 2.720 [0.000, 5.000], mean observation: 0.072 [0.000, 24.000], loss: 0.022997, mean_absolute_error: 0.667071, mean_q: 0.427659
#   664574/5000000: episode: 11063, duration: 9.117s, episode steps: 191, steps per second: 21, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 2.424 [0.000, 5.000], mean observation: 0.065 [0.000, 24.000], loss: 0.019861, mean_absolute_error: 0.662130, mean_q: 0.429048
#   664629/5000000: episode: 11064, duration: 2.735s, episode steps: 55, steps per second: 20, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 2.745 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.019966, mean_absolute_error: 0.661144, mean_q: 0.422695
#   664697/5000000: episode: 11065, duration: 3.081s, episode steps: 68, steps per second: 22, episode reward: -1.000, mean reward: -0.015 [-1.000, 0.000], mean action: 2.324 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.020238, mean_absolute_error: 0.659704, mean_q: 0.421616
#   664801/5000000: episode: 11066, duration: 4.980s, episode steps: 104, steps per second: 21, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 2.500 [0.000, 5.000], mean observation: 0.064 [0.000, 24.000], loss: 0.019499, mean_absolute_error: 0.655001, mean_q: 0.415295
#   664830/5000000: episode: 11067, duration: 1.393s, episode steps: 29, steps per second: 21, episode reward: -1.000, mean reward: -0.034 [-1.000, 0.000], mean action: 2.621 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.018853, mean_absolute_error: 0.651775, mean_q: 0.417766
#   664885/5000000: episode: 11068, duration: 2.680s, episode steps: 55, steps per second: 21, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 2.745 [0.000, 5.000], mean observation: 0.070 [0.000, 24.000], loss: 0.018730, mean_absolute_error: 0.654141, mean_q: 0.417283
#   665183/5000000: episode: 11069, duration: 14.919s, episode steps: 298, steps per second: 20, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 2.433 [0.000, 5.000], mean observation: 0.061 [0.000, 24.000], loss: 0.019235, mean_absolute_error: 0.653084, mean_q: 0.403026
#   665228/5000000: episode: 11070, duration: 2.212s, episode steps: 45, steps per second: 20, episode reward: -1.000, mean reward: -0.022 [-1.000, 0.000], mean action: 2.022 [0.000, 5.000], mean observation: 0.069 [0.000, 24.000], loss: 0.019962, mean_absolute_error: 0.649268, mean_q: 0.388141
# done, took 33291.008 seconds

# %%
dqn.save_weights(model_path, overwrite=True)
