# %%
import numpy as np
import os
import tensorflow as tf
import warnings

from keras.models import Model
from keras.layers import Dense, Flatten, Convolution2D, Input, Concatenate, Activation
from keras.optimizers import Adam
from pommerman.configs import ffa_v0_env
from pommerman.envs.v0 import Pomme
from pommerman.agents import SimpleAgent, BaseAgent
from pommerman.constants import BOARD_SIZE
from rl.agents import DDPGAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory
from rl.core import Env, Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint, Callback
from rl.random import OrnsteinUhlenbeckProcess
# Out:
# /gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /gpfs/hpchome/anton95/.conda/envs/pommerman/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
number_of_training_steps = 500000
log_interval = 1000
file_log_path = './dqn/rl_logs/ddgp_cnn128_3_3_dense_64_1/log.txt'
tensorboard_path = './dqn/logs/ddgp_cnn128_3_3_dense_64_1/'
model_path = './dqn/model/ddgp_cnn128_3_3_dense_64_1/model{step}.h4'

# %%
if not os.path.isdir(os.path.dirname(file_log_path)):
    os.makedirs(os.path.dirname(file_log_path))
if not os.path.isdir(os.path.dirname(model_path)):
    os.makedirs(os.path.dirname(model_path))

# %%
class TensorforceAgent(BaseAgent):
    def act(self, obs, action_space):
        pass


class TensorboardLogger(Callback):
    """Logging in tensorboard without tensorflow ops."""
    def __init__(self, log_dir):
        # Some algorithms compute multiple episodes at once since they are multi-threaded.
        # We therefore use a dictionary that is indexed by the episode to separate episodes
        # from each other.
        self.observations = {}
        self.rewards = {}
        self.actions = {}
        self.metrics = {}
        self.step = 0
        """Creates a summary writer logging to log_dir."""
        self.writer = tf.summary.FileWriter(log_dir)

    def log_scalar(self, tag, value, step):
        """Log a scalar variable.
        Parameter
        ----------
        tag : basestring
            Name of the scalar
        value
        step : int
            training iteration
        """
        summary = tf.Summary(value=[tf.Summary.Value(tag=tag, simple_value=value)])
        self.writer.add_summary(summary, step)

    def on_train_begin(self, logs):
        self.metrics_names = self.model.metrics_names

    def on_episode_begin(self, episode, logs):
        self.observations[episode] = []
        self.rewards[episode] = []
        self.actions[episode] = []
        self.metrics[episode] = []

    def on_episode_end(self, episode, logs):
        episode_steps = len(self.observations[episode])
        variables = {
            'step': self.step,
            'nb_steps': self.params['nb_steps'],
            'episode_steps': episode_steps,
            'episode_reward': np.sum(self.rewards[episode]),
            'reward_mean': np.mean(self.rewards[episode]),
            'reward_min': np.min(self.rewards[episode]),
            'reward_max': np.max(self.rewards[episode]),
            'action_mean': np.mean(np.argmax(self.actions[episode], axis=1)),
            'action_min': np.min(np.argmax(self.actions[episode], axis=1)),
            'action_max': np.max(np.argmax(self.actions[episode], axis=1)),
            'obs_mean': np.mean(self.observations[episode]),
            'obs_min': np.min(self.observations[episode]),
            'obs_max': np.max(self.observations[episode]),
        }

        # Format all metrics.
        metrics = np.array(self.metrics[episode])
        with warnings.catch_warnings():
            warnings.filterwarnings('error')
            for idx, name in enumerate(self.metrics_names):
                try:
                    value = np.nanmean(metrics[:, idx])
                except Warning:
                    value = -1
                variables[name] = value
        for key, value in variables.items():
            self.log_scalar(key, value, episode + 1)

        # Free up resources.
        del self.observations[episode]
        del self.rewards[episode]
        del self.actions[episode]
        del self.metrics[episode]

    def on_step_end(self, step, logs):
        episode = logs['episode']
        self.observations[episode].append(logs['observation'])
        self.rewards[episode].append(logs['reward'])
        self.actions[episode].append(logs['action'])
        self.metrics[episode].append(logs['metrics'])
        self.step += 1

# %%
# Instantiate the environment
config = ffa_v0_env()
env = Pomme(**config["env_kwargs"])
np.random.seed(0)
env.seed(0)

env.set_init_game_state(None)
nb_actions = env.action_space.n


def create_actor(actions, input_shape=(13, 13, 17,)):
    inp = Input(input_shape)
    x = Convolution2D(128, 3, activation='relu')(inp)
    x = Convolution2D(128, 3, activation='relu')(x)
    x = Flatten()(x)
    x = Dense(64, activation='relu')(x)
    out = Dense(actions)(x)
    out = Activation('softmax')(out)
    model = Model(inputs=inp, outputs=out)
    return model


def create_critic(actions, input_shape=(13, 13, 17,)):
    action_input = Input(shape=(actions,), name='action_input')
    observation_input = Input(shape=input_shape, name='observation_input')
    x = Convolution2D(128, 3, activation='relu')(observation_input)
    x = Convolution2D(128, 3, activation='relu')(x)
    x = Flatten()(x)    
    x = Concatenate()([action_input, x])
    x = Dense(32)(x)
    x = Activation('relu')(x)
    x = Dense(32)(x)
    x = Activation('relu')(x)
    x = Dense(1)(x)
    return action_input, Model(inputs=[action_input, observation_input], outputs=x)


actor = create_actor(nb_actions)
action_input, critic = create_critic(nb_actions)
print(actor.summary())
print(critic.summary())
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 13, 13, 17)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 128)       19712
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 128)         147584
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10368)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                663616
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# _________________________________________________________________
# activation_1 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 831,302
# Trainable params: 831,302
# Non-trainable params: 0
# _________________________________________________________________
# None
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# observation_input (InputLayer)  (None, 13, 13, 17)   0
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 11, 11, 128)  19712       observation_input[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 9, 9, 128)    147584      conv2d_3[0][0]
# __________________________________________________________________________________________________
# action_input (InputLayer)       (None, 6)            0
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 10368)        0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10374)        0           action_input[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           332000      concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           1056        activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            33          activation_3[0][0]
# ==================================================================================================
# Total params: 500,385
# Trainable params: 500,385
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
class EnvWrapper(Env):
    """The abstract environment class that is used by all agents. This class has the exact
        same API that OpenAI Gym uses so that integrating with it is trivial. In contrast to the
        OpenAI Gym implementation, this class only defines the abstract methods without any actual
        implementation.
        To implement your own environment, you need to define the following methods:
        - `step`
        - `reset`
        - `render`
        - `close`
        Refer to the [Gym documentation](https://gym.openai.com/docs/#environments).
        """
    reward_range = (-1, 1)
    action_space = None
    observation_space = None

    def __init__(self, gym, board_size):
        self.gym = gym
        self.action_space = gym.action_space
        self.observation_space = gym.observation_space
        self.reward_range = gym.reward_range
        self.board_size = board_size

    def step(self, action):
        """Run one timestep of the environment's dynamics.
        Accepts an action and returns a tuple (observation, reward, done, info).
        # Arguments
            action (object): An action provided by the environment.
        # Returns
            observation (object): Agent's observation of the current environment.
            reward (float) : Amount of reward returned after previous action.
            done (boolean): Whether the episode has ended, in which case further step() calls will return undefined results.
            info (dict): Contains auxiliary diagnostic information (helpful for debugging, and sometimes learning).
        """
        action = np.argmax(action)
        obs = self.gym.get_observations()
        all_actions = self.gym.act(obs)
        all_actions.insert(self.gym.training_agent, action)
        state, reward, terminal, info = self.gym.step(all_actions)
        agent_state = self.featurize(state[self.gym.training_agent])
        agent_reward = reward[self.gym.training_agent]
        return agent_state, agent_reward, terminal, info

    def reset(self):
        """
        Resets the state of the environment and returns an initial observation.
        # Returns
            observation (object): The initial observation of the space. Initial reward is assumed to be 0.
        """
        # Add 3 random agents
        train_agent_pos = np.random.randint(0, 4)
        agents = []
        for agent_id in range(4):
            if agent_id == train_agent_pos:
                agents.append(TensorforceAgent(config["agent"](agent_id, config["game_type"])))
            else:
                agents.append(SimpleAgent(config["agent"](agent_id, config["game_type"])))
        self.gym.set_agents(agents)
        self.gym.set_training_agent(agents[train_agent_pos].agent_id)
        
        obs = self.gym.reset()
        agent_obs = self.featurize(obs[self.gym.training_agent])
        return agent_obs

    def render(self, mode='human', close=False):
        """Renders the environment.
        The set of supported modes varies per environment. (And some
        environments do not support rendering at all.)
        # Arguments
            mode (str): The mode to render with.
            close (bool): Close all open renderings.
        """
        self.gym.render(mode=mode, close=close)

    def close(self):
        """Override in your subclass to perform any necessary cleanup.
        Environments will automatically close() themselves when
        garbage collected or when the program exits.
        """
        self.gym.close()

    def seed(self, seed=None):
        """Sets the seed for this env's random number generator(s).
        # Returns
            Returns the list of seeds used in this env's random number generators
        """
        raise self.gym.seed(seed)

    def configure(self, *args, **kwargs):
        """Provides runtime configuration to the environment.
        This configuration should consist of data that tells your
        environment how to run (such as an address of a remote server,
        or path to your ImageNet data). It should not affect the
        semantics of the environment.
        """
        raise NotImplementedError()

    def featurize(self, obs):
        shape = (self.board_size, self.board_size, 1)

        def get_matrix(dict, key):
            res = dict[key]
            return res.reshape(shape).astype(np.float32)

        def get_map(board, item):
            map = np.zeros(shape)
            map[board == item] = 1
            return map

        board = get_matrix(obs, 'board')

        # TODO: probably not needed Passage = 0
        rigid_map = get_map(board, 1)  # Rigid = 1
        wood_map = get_map(board, 2)  # Wood = 2
        bomb_map = get_map(board, 3)  # Bomb = 3
        flames_map = get_map(board, 4)  # Flames = 4
        fog_map = get_map(board, 5)  # TODO: not used for first two stages Fog = 5
        extra_bomb_map = get_map(board, 6)  # ExtraBomb = 6
        incr_range_map = get_map(board, 7)  # IncrRange = 7
        kick_map = get_map(board, 8)  # Kick = 8
        skull_map = get_map(board, 9)  # Skull = 9

        position = obs["position"]
        my_position = np.zeros(shape)
        my_position[position[0], position[1], 0] = 1

        team_mates = get_map(board, obs["teammate"].value)  # TODO during documentation it should be an array

        enemies = np.zeros(shape)
        for enemy in obs["enemies"]:
            enemies[board == enemy.value] = 1

        bomb_blast_strength = get_matrix(obs, 'bomb_blast_strength')
        bomb_life = get_matrix(obs, 'bomb_life')

        ammo = np.full(shape, obs["ammo"])
        blast_strength = np.full(shape, obs["blast_strength"])
        can_kick = np.full(shape, int(obs["can_kick"]))

        obs = np.concatenate([my_position, enemies, team_mates, rigid_map,
                              wood_map, bomb_map, flames_map,
                              fog_map, extra_bomb_map, incr_range_map,
                              kick_map, skull_map, bomb_blast_strength,
                              bomb_life, ammo, blast_strength, can_kick], axis=2)
        return obs

    def __del__(self):
        self.close()

    def __str__(self):
        return '<{} instance>'.format(type(self).__name__)


class CustomProcessor(Processor):
    def process_state_batch(self, batch):
        """Processes an entire batch of states and returns it.
        # Arguments
            batch (list): List of states
        # Returns
            Processed list of states
        """
        batch = np.squeeze(batch, axis=1)
        return batch

    def process_info(self, info):
        """Processes the info as obtained from the environment for use in an agent and
        returns it.
        """
        info['result'] = info['result'].value
        return info

# %%
env_wrapper = EnvWrapper(env, BOARD_SIZE)
processor = CustomProcessor()


memory = SequentialMemory(limit=100000, window_length=1)
random_process = OrnsteinUhlenbeckProcess(size=nb_actions, theta=.15, mu=0., sigma=.3)
agent = DDPGAgent(nb_actions=nb_actions, actor=actor, critic=critic, critic_action_input=action_input,
                  memory=memory, nb_steps_warmup_critic=512, nb_steps_warmup_actor=512,
                  random_process=random_process, gamma=.99, target_model_update=1e-3,
                  batch_size=512, processor=processor)
agent.compile(Adam(lr=0.0001, clipnorm=1.), metrics=['mae'])


file_logger = FileLogger(file_log_path, interval=log_interval)
checkpoint = ModelIntervalCheckpoint(model_path, interval=log_interval)
tensorboard = TensorboardLogger(tensorboard_path)
callbacks=[file_logger, checkpoint, tensorboard]
if os.path.isfile(model_path):
    agent.load_weights(model_path)

# %%
history = agent.fit(env_wrapper, nb_steps=number_of_training_steps, visualize=False, verbose=2,
        nb_max_episode_steps=env._max_steps, callbacks=callbacks)
# Out:
# Training for 500000 steps ...
#     154/500000: episode: 1, duration: 3.560s, episode steps: 154, steps per second: 43, episode reward: -1.000, mean reward: -0.006 [-1.000, 0.000], mean action: 0.202 [-0.255, 0.758], mean observation: 0.278 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#    1124/500000: episode: 2, duration: 58.083s, episode steps: 970, steps per second: 17, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.214 [-0.885, 1.232], mean observation: 0.263 [0.000, 24.000], loss: 0.000180, mean_absolute_error: 0.006944, mean_q: 0.025429
#    3624/500000: episode: 3, duration: 207.377s, episode steps: 2500, steps per second: 12, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.165 [-1.327, 1.809], mean observation: 0.265 [0.000, 24.000], loss: 0.000074, mean_absolute_error: 0.003767, mean_q: 0.022566
#    4083/500000: episode: 4, duration: 37.490s, episode steps: 459, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.244 [-1.040, 1.758], mean observation: 0.275 [0.000, 24.000], loss: 0.000022, mean_absolute_error: 0.002973, mean_q: 0.028299
#    4359/500000: episode: 5, duration: 22.658s, episode steps: 276, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.091 [-0.796, 0.983], mean observation: 0.279 [0.000, 24.000], loss: 0.000102, mean_absolute_error: 0.003998, mean_q: 0.028942
#    4645/500000: episode: 6, duration: 22.498s, episode steps: 286, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.087 [-0.553, 1.366], mean observation: 0.280 [0.000, 24.000], loss: 0.000157, mean_absolute_error: 0.005788, mean_q: 0.029675
#    4960/500000: episode: 7, duration: 25.456s, episode steps: 315, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.097 [-0.890, 1.575], mean observation: 0.280 [0.000, 24.000], loss: 0.000164, mean_absolute_error: 0.006145, mean_q: 0.029905
#    6175/500000: episode: 8, duration: 97.258s, episode steps: 1215, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.087 [-1.124, 1.532], mean observation: 0.264 [0.000, 24.000], loss: 0.000087, mean_absolute_error: 0.004622, mean_q: 0.031882
#    6525/500000: episode: 9, duration: 28.176s, episode steps: 350, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.351 [-0.540, 1.566], mean observation: 0.279 [0.000, 24.000], loss: 0.000033, mean_absolute_error: 0.003383, mean_q: 0.031323
#    6986/500000: episode: 10, duration: 36.102s, episode steps: 461, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.253 [-0.816, 1.751], mean observation: 0.275 [0.000, 24.000], loss: 0.000040, mean_absolute_error: 0.004090, mean_q: 0.030651
#    7118/500000: episode: 11, duration: 12.341s, episode steps: 132, steps per second: 11, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 0.122 [-0.517, 0.986], mean observation: 0.271 [0.000, 24.000], loss: 0.000048, mean_absolute_error: 0.004268, mean_q: 0.029261
#    7521/500000: episode: 12, duration: 32.414s, episode steps: 403, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.390 [-0.740, 1.742], mean observation: 0.276 [0.000, 24.000], loss: 0.000040, mean_absolute_error: 0.004198, mean_q: 0.027041
#    8153/500000: episode: 13, duration: 50.735s, episode steps: 632, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: -0.012 [-1.687, 1.461], mean observation: 0.272 [0.000, 24.000], loss: 0.000073, mean_absolute_error: 0.004623, mean_q: 0.025365
#    8737/500000: episode: 14, duration: 44.322s, episode steps: 584, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.056 [-1.093, 1.838], mean observation: 0.272 [0.000, 24.000], loss: 0.000084, mean_absolute_error: 0.005143, mean_q: 0.024054
#   11237/500000: episode: 15, duration: 211.067s, episode steps: 2500, steps per second: 12, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.294 [-1.390, 2.030], mean observation: 0.266 [0.000, 24.000], loss: 0.000043, mean_absolute_error: 0.003831, mean_q: 0.028060
#   11639/500000: episode: 16, duration: 32.183s, episode steps: 402, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.306 [-0.317, 1.276], mean observation: 0.275 [0.000, 24.000], loss: 0.000027, mean_absolute_error: 0.003483, mean_q: 0.031486
#   12053/500000: episode: 17, duration: 35.093s, episode steps: 414, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.164 [-0.660, 1.067], mean observation: 0.276 [0.000, 24.000], loss: 0.000070, mean_absolute_error: 0.004649, mean_q: 0.029096
#   12516/500000: episode: 18, duration: 37.832s, episode steps: 463, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.087 [-0.861, 1.534], mean observation: 0.274 [0.000, 24.000], loss: 0.000060, mean_absolute_error: 0.004699, mean_q: 0.027106
#   13032/500000: episode: 19, duration: 40.176s, episode steps: 516, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.344 [-0.605, 1.880], mean observation: 0.270 [0.000, 24.000], loss: 0.000054, mean_absolute_error: 0.004568, mean_q: 0.025286
#   13508/500000: episode: 20, duration: 39.548s, episode steps: 476, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.266 [-0.567, 1.657], mean observation: 0.275 [0.000, 24.000], loss: 0.000043, mean_absolute_error: 0.004025, mean_q: 0.023632
#   13639/500000: episode: 21, duration: 10.604s, episode steps: 131, steps per second: 12, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 0.168 [-0.294, 0.980], mean observation: 0.277 [0.000, 24.000], loss: 0.000088, mean_absolute_error: 0.005097, mean_q: 0.022869
#   14610/500000: episode: 22, duration: 74.499s, episode steps: 971, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.211 [-1.278, 2.139], mean observation: 0.268 [0.000, 24.000], loss: 0.000060, mean_absolute_error: 0.004465, mean_q: 0.020317
#   17110/500000: episode: 23, duration: 189.669s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: -0.005 [-1.743, 1.593], mean observation: 0.266 [0.000, 24.000], loss: 0.000030, mean_absolute_error: 0.003514, mean_q: 0.017925
#   17503/500000: episode: 24, duration: 30.752s, episode steps: 393, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.332 [-0.981, 1.383], mean observation: 0.274 [0.000, 24.000], loss: 0.000023, mean_absolute_error: 0.003160, mean_q: 0.016319
#   20003/500000: episode: 25, duration: 185.919s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.032 [-1.345, 1.969], mean observation: 0.268 [0.000, 24.000], loss: 0.000024, mean_absolute_error: 0.003178, mean_q: 0.009736
#   20572/500000: episode: 26, duration: 45.218s, episode steps: 569, steps per second: 13, episode reward: 1.000, mean reward: 0.002 [0.000, 1.000], mean action: 0.180 [-0.854, 1.214], mean observation: 0.273 [0.000, 24.000], loss: 0.000019, mean_absolute_error: 0.003059, mean_q: 0.005116
#   21665/500000: episode: 27, duration: 85.449s, episode steps: 1093, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.258 [-0.744, 1.962], mean observation: 0.264 [0.000, 24.000], loss: 0.000036, mean_absolute_error: 0.003523, mean_q: 0.004170
#   22666/500000: episode: 28, duration: 76.283s, episode steps: 1001, steps per second: 13, episode reward: 1.000, mean reward: 0.001 [0.000, 1.000], mean action: 0.454 [-0.702, 1.780], mean observation: 0.266 [0.000, 24.000], loss: 0.000033, mean_absolute_error: 0.003511, mean_q: 0.000336
#   23320/500000: episode: 29, duration: 52.607s, episode steps: 654, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.195 [-0.758, 1.596], mean observation: 0.272 [0.000, 24.000], loss: 0.000047, mean_absolute_error: 0.003730, mean_q: -0.000189
#   24243/500000: episode: 30, duration: 68.336s, episode steps: 923, steps per second: 14, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.432 [-1.152, 2.108], mean observation: 0.265 [0.000, 24.000], loss: 0.000056, mean_absolute_error: 0.004104, mean_q: -0.001009
#   24650/500000: episode: 31, duration: 31.858s, episode steps: 407, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.250 [-0.520, 1.231], mean observation: 0.275 [0.000, 24.000], loss: 0.000052, mean_absolute_error: 0.004107, mean_q: -0.002057
#   25005/500000: episode: 32, duration: 28.883s, episode steps: 355, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.148 [-0.638, 1.200], mean observation: 0.277 [0.000, 24.000], loss: 0.000044, mean_absolute_error: 0.003961, mean_q: -0.003495
#   25313/500000: episode: 33, duration: 24.375s, episode steps: 308, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.027 [-1.016, 1.485], mean observation: 0.279 [0.000, 24.000], loss: 0.000057, mean_absolute_error: 0.004692, mean_q: -0.004134
#   26028/500000: episode: 34, duration: 54.150s, episode steps: 715, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.433 [-0.543, 1.985], mean observation: 0.269 [0.000, 24.000], loss: 0.000048, mean_absolute_error: 0.004229, mean_q: -0.005141
#   26387/500000: episode: 35, duration: 27.891s, episode steps: 359, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.281 [-0.593, 1.515], mean observation: 0.276 [0.000, 24.000], loss: 0.000050, mean_absolute_error: 0.004328, mean_q: -0.006037
#   26714/500000: episode: 36, duration: 26.581s, episode steps: 327, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.063 [-0.769, 1.584], mean observation: 0.281 [0.000, 24.000], loss: 0.000058, mean_absolute_error: 0.004240, mean_q: -0.006873
#   27479/500000: episode: 37, duration: 58.488s, episode steps: 765, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.162 [-1.157, 1.711], mean observation: 0.269 [0.000, 24.000], loss: 0.000051, mean_absolute_error: 0.004382, mean_q: -0.006198
#   27905/500000: episode: 38, duration: 33.359s, episode steps: 426, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.058 [-0.945, 1.450], mean observation: 0.275 [0.000, 24.000], loss: 0.000038, mean_absolute_error: 0.004090, mean_q: -0.007433
#   29823/500000: episode: 39, duration: 151.763s, episode steps: 1918, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.140 [-1.180, 2.056], mean observation: 0.264 [0.000, 24.000], loss: 0.000040, mean_absolute_error: 0.004064, mean_q: -0.008380
#   32323/500000: episode: 40, duration: 181.077s, episode steps: 2500, steps per second: 14, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.070 [-1.764, 1.964], mean observation: 0.264 [0.000, 24.000], loss: 0.000039, mean_absolute_error: 0.003995, mean_q: -0.010130
#   32662/500000: episode: 41, duration: 27.455s, episode steps: 339, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.111 [-0.683, 1.046], mean observation: 0.279 [0.000, 24.000], loss: 0.000034, mean_absolute_error: 0.003893, mean_q: -0.010602
#   32928/500000: episode: 42, duration: 21.682s, episode steps: 266, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: -0.042 [-0.975, 1.214], mean observation: 0.280 [0.000, 24.000], loss: 0.000058, mean_absolute_error: 0.004081, mean_q: -0.011395
#   33312/500000: episode: 43, duration: 30.273s, episode steps: 384, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.320 [-0.921, 1.933], mean observation: 0.277 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.004828, mean_q: -0.012119
#   33721/500000: episode: 44, duration: 32.774s, episode steps: 409, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.102 [-1.176, 1.595], mean observation: 0.277 [0.000, 24.000], loss: 0.000065, mean_absolute_error: 0.004855, mean_q: -0.012742
#   34703/500000: episode: 45, duration: 75.626s, episode steps: 982, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.127 [-1.027, 1.991], mean observation: 0.269 [0.000, 24.000], loss: 0.000055, mean_absolute_error: 0.004437, mean_q: -0.013641
#   35409/500000: episode: 46, duration: 52.483s, episode steps: 706, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.102 [-0.882, 1.105], mean observation: 0.269 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.004824, mean_q: -0.016085
#   37909/500000: episode: 47, duration: 208.134s, episode steps: 2500, steps per second: 12, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.201 [-1.901, 1.651], mean observation: 0.264 [0.000, 24.000], loss: 0.000048, mean_absolute_error: 0.004297, mean_q: -0.020302
#   40409/500000: episode: 48, duration: 227.045s, episode steps: 2500, steps per second: 11, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.119 [-1.236, 1.472], mean observation: 0.267 [0.000, 24.000], loss: 0.000035, mean_absolute_error: 0.003857, mean_q: -0.023628
#   40963/500000: episode: 49, duration: 43.403s, episode steps: 554, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.075 [-0.765, 1.050], mean observation: 0.273 [0.000, 24.000], loss: 0.000038, mean_absolute_error: 0.003968, mean_q: -0.024049
#   41305/500000: episode: 50, duration: 28.329s, episode steps: 342, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.327 [-0.295, 1.320], mean observation: 0.281 [0.000, 24.000], loss: 0.000058, mean_absolute_error: 0.004589, mean_q: -0.025530
#   41513/500000: episode: 51, duration: 17.021s, episode steps: 208, steps per second: 12, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.174 [-0.633, 1.415], mean observation: 0.279 [0.000, 24.000], loss: 0.000051, mean_absolute_error: 0.004534, mean_q: -0.026271
#   42094/500000: episode: 52, duration: 47.604s, episode steps: 581, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.461 [-0.314, 1.393], mean observation: 0.272 [0.000, 24.000], loss: 0.000058, mean_absolute_error: 0.004679, mean_q: -0.027616
#   44594/500000: episode: 53, duration: 190.561s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.187 [-1.281, 1.975], mean observation: 0.261 [0.000, 24.000], loss: 0.000045, mean_absolute_error: 0.004302, mean_q: -0.034395
#   44982/500000: episode: 54, duration: 31.288s, episode steps: 388, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.078 [-0.798, 1.512], mean observation: 0.279 [0.000, 24.000], loss: 0.000039, mean_absolute_error: 0.004160, mean_q: -0.042628
#   45239/500000: episode: 55, duration: 21.111s, episode steps: 257, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.104 [-0.669, 1.092], mean observation: 0.283 [0.000, 24.000], loss: 0.000048, mean_absolute_error: 0.004489, mean_q: -0.042033
#   47739/500000: episode: 56, duration: 179.680s, episode steps: 2500, steps per second: 14, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.318 [-1.321, 2.911], mean observation: 0.265 [0.000, 24.000], loss: 0.000040, mean_absolute_error: 0.004122, mean_q: -0.044366
#   48326/500000: episode: 57, duration: 45.578s, episode steps: 587, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.234 [-0.503, 1.714], mean observation: 0.272 [0.000, 24.000], loss: 0.000039, mean_absolute_error: 0.004144, mean_q: -0.045136
#   48666/500000: episode: 58, duration: 27.750s, episode steps: 340, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.019 [-0.784, 1.192], mean observation: 0.275 [0.000, 24.000], loss: 0.000048, mean_absolute_error: 0.004241, mean_q: -0.045635
#   49208/500000: episode: 59, duration: 43.708s, episode steps: 542, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.267 [-0.642, 1.828], mean observation: 0.273 [0.000, 24.000], loss: 0.000058, mean_absolute_error: 0.004751, mean_q: -0.046185
#   49511/500000: episode: 60, duration: 24.375s, episode steps: 303, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.205 [-0.826, 1.648], mean observation: 0.278 [0.000, 24.000], loss: 0.000064, mean_absolute_error: 0.004894, mean_q: -0.047289
#   52011/500000: episode: 61, duration: 190.061s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.202 [-1.175, 1.751], mean observation: 0.267 [0.000, 24.000], loss: 0.000047, mean_absolute_error: 0.004468, mean_q: -0.047118
#   54511/500000: episode: 62, duration: 191.106s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.092 [-1.605, 1.645], mean observation: 0.267 [0.000, 24.000], loss: 0.000041, mean_absolute_error: 0.004242, mean_q: -0.047809
#   55602/500000: episode: 63, duration: 81.397s, episode steps: 1091, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.234 [-1.012, 2.091], mean observation: 0.266 [0.000, 24.000], loss: 0.000045, mean_absolute_error: 0.004309, mean_q: -0.049158
#   56062/500000: episode: 64, duration: 35.205s, episode steps: 460, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.190 [-0.638, 1.732], mean observation: 0.273 [0.000, 24.000], loss: 0.000046, mean_absolute_error: 0.004312, mean_q: -0.050020
#   56836/500000: episode: 65, duration: 60.676s, episode steps: 774, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.264 [-0.885, 1.532], mean observation: 0.293 [0.000, 24.000], loss: 0.000051, mean_absolute_error: 0.004479, mean_q: -0.051189
#   57093/500000: episode: 66, duration: 21.068s, episode steps: 257, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.185 [-0.719, 1.539], mean observation: 0.282 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.004994, mean_q: -0.052711
#   57478/500000: episode: 67, duration: 31.698s, episode steps: 385, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.198 [-0.495, 1.158], mean observation: 0.275 [0.000, 24.000], loss: 0.000059, mean_absolute_error: 0.004736, mean_q: -0.052985
#   59685/500000: episode: 68, duration: 179.518s, episode steps: 2207, steps per second: 12, episode reward: -1.000, mean reward: -0.000 [-1.000, 0.000], mean action: 0.331 [-1.115, 2.003], mean observation: 0.266 [0.000, 24.000], loss: 0.000058, mean_absolute_error: 0.004594, mean_q: -0.052571
#   60372/500000: episode: 69, duration: 50.432s, episode steps: 687, steps per second: 14, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: -0.028 [-0.996, 1.148], mean observation: 0.265 [0.000, 24.000], loss: 0.000052, mean_absolute_error: 0.004510, mean_q: -0.052120
#   60828/500000: episode: 70, duration: 34.672s, episode steps: 456, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.308 [-0.703, 1.262], mean observation: 0.275 [0.000, 24.000], loss: 0.000057, mean_absolute_error: 0.004618, mean_q: -0.051928
#   64458/500000: episode: 72, duration: 89.800s, episode steps: 1228, steps per second: 14, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.331 [-1.233, 2.016], mean observation: 0.263 [0.000, 24.000], loss: 0.000059, mean_absolute_error: 0.004590, mean_q: -0.052513
#   65389/500000: episode: 73, duration: 72.997s, episode steps: 931, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.100 [-1.153, 1.597], mean observation: 0.266 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.004728, mean_q: -0.053011
#   65502/500000: episode: 74, duration: 9.064s, episode steps: 113, steps per second: 12, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 0.254 [-0.112, 0.980], mean observation: 0.270 [0.000, 24.000], loss: 0.000102, mean_absolute_error: 0.005441, mean_q: -0.054543
#   66236/500000: episode: 75, duration: 72.651s, episode steps: 734, steps per second: 10, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.236 [-0.934, 1.457], mean observation: 0.269 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.004950, mean_q: -0.054044
#   68709/500000: episode: 76, duration: 192.400s, episode steps: 2473, steps per second: 13, episode reward: -1.000, mean reward: -0.000 [-1.000, 0.000], mean action: 0.346 [-1.156, 2.094], mean observation: 0.262 [0.000, 24.000], loss: 0.000062, mean_absolute_error: 0.004732, mean_q: -0.054689
#   69024/500000: episode: 77, duration: 25.686s, episode steps: 315, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.240 [-0.569, 1.653], mean observation: 0.277 [0.000, 24.000], loss: 0.000067, mean_absolute_error: 0.004731, mean_q: -0.055056
#   69781/500000: episode: 78, duration: 59.827s, episode steps: 757, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.178 [-1.259, 1.295], mean observation: 0.271 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.004866, mean_q: -0.055736
#   70803/500000: episode: 79, duration: 79.219s, episode steps: 1022, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.232 [-0.926, 1.737], mean observation: 0.267 [0.000, 24.000], loss: 0.000068, mean_absolute_error: 0.004979, mean_q: -0.056671
#   71060/500000: episode: 80, duration: 21.613s, episode steps: 257, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.088 [-0.661, 0.998], mean observation: 0.271 [0.000, 24.000], loss: 0.000079, mean_absolute_error: 0.005195, mean_q: -0.058200
#   71798/500000: episode: 81, duration: 57.088s, episode steps: 738, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: -0.106 [-1.225, 1.330], mean observation: 0.272 [0.000, 24.000], loss: 0.000079, mean_absolute_error: 0.005185, mean_q: -0.057605
#   72269/500000: episode: 82, duration: 37.069s, episode steps: 471, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.149 [-0.705, 1.237], mean observation: 0.275 [0.000, 24.000], loss: 0.000075, mean_absolute_error: 0.005242, mean_q: -0.058864
#   72846/500000: episode: 83, duration: 44.770s, episode steps: 577, steps per second: 13, episode reward: 1.000, mean reward: 0.002 [0.000, 1.000], mean action: 0.054 [-1.100, 1.666], mean observation: 0.273 [0.000, 24.000], loss: 0.000085, mean_absolute_error: 0.005260, mean_q: -0.059482
#   73316/500000: episode: 84, duration: 38.008s, episode steps: 470, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.134 [-0.865, 1.065], mean observation: 0.275 [0.000, 24.000], loss: 0.000090, mean_absolute_error: 0.005340, mean_q: -0.058781
#   73970/500000: episode: 85, duration: 56.036s, episode steps: 654, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: -0.125 [-1.023, 1.417], mean observation: 0.269 [0.000, 24.000], loss: 0.000085, mean_absolute_error: 0.005274, mean_q: -0.059871
#   74306/500000: episode: 86, duration: 27.532s, episode steps: 336, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.109 [-0.529, 1.230], mean observation: 0.282 [0.000, 24.000], loss: 0.000086, mean_absolute_error: 0.005335, mean_q: -0.060257
#   74768/500000: episode: 87, duration: 38.077s, episode steps: 462, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.149 [-0.941, 1.492], mean observation: 0.276 [0.000, 24.000], loss: 0.000082, mean_absolute_error: 0.005408, mean_q: -0.060638
#   75249/500000: episode: 88, duration: 39.036s, episode steps: 481, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.252 [-0.530, 1.446], mean observation: 0.269 [0.000, 24.000], loss: 0.000080, mean_absolute_error: 0.005226, mean_q: -0.060878
#   75616/500000: episode: 89, duration: 28.715s, episode steps: 367, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.227 [-1.143, 1.319], mean observation: 0.277 [0.000, 24.000], loss: 0.000098, mean_absolute_error: 0.005480, mean_q: -0.061589
#   78116/500000: episode: 90, duration: 203.771s, episode steps: 2500, steps per second: 12, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.111 [-1.921, 1.844], mean observation: 0.266 [0.000, 24.000], loss: 0.000074, mean_absolute_error: 0.005112, mean_q: -0.060819
#   78424/500000: episode: 91, duration: 25.227s, episode steps: 308, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.127 [-0.568, 1.392], mean observation: 0.284 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.005013, mean_q: -0.059922
#   79774/500000: episode: 92, duration: 109.829s, episode steps: 1350, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: -0.065 [-1.569, 1.395], mean observation: 0.267 [0.000, 24.000], loss: 0.000065, mean_absolute_error: 0.004918, mean_q: -0.061564
#   80199/500000: episode: 93, duration: 34.048s, episode steps: 425, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.199 [-0.948, 1.504], mean observation: 0.275 [0.000, 24.000], loss: 0.000078, mean_absolute_error: 0.005106, mean_q: -0.062736
#   80302/500000: episode: 94, duration: 8.477s, episode steps: 103, steps per second: 12, episode reward: -1.000, mean reward: -0.010 [-1.000, 0.000], mean action: 0.168 [-0.739, 1.070], mean observation: 0.273 [0.000, 24.000], loss: 0.000059, mean_absolute_error: 0.004851, mean_q: -0.062218
#   80598/500000: episode: 95, duration: 24.405s, episode steps: 296, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.336 [-0.257, 1.039], mean observation: 0.276 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.005016, mean_q: -0.063725
#   81100/500000: episode: 96, duration: 38.594s, episode steps: 502, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.114 [-1.182, 1.802], mean observation: 0.272 [0.000, 24.000], loss: 0.000071, mean_absolute_error: 0.005122, mean_q: -0.063752
#   81616/500000: episode: 97, duration: 40.601s, episode steps: 516, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.278 [-0.409, 1.802], mean observation: 0.272 [0.000, 24.000], loss: 0.000071, mean_absolute_error: 0.005306, mean_q: -0.064634
#   82298/500000: episode: 98, duration: 55.335s, episode steps: 682, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.183 [-0.710, 1.023], mean observation: 0.270 [0.000, 24.000], loss: 0.000070, mean_absolute_error: 0.005148, mean_q: -0.064857
#   82689/500000: episode: 99, duration: 30.125s, episode steps: 391, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.254 [-0.847, 1.301], mean observation: 0.276 [0.000, 24.000], loss: 0.000071, mean_absolute_error: 0.005064, mean_q: -0.063793
#   83133/500000: episode: 100, duration: 36.566s, episode steps: 444, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.228 [-0.896, 1.398], mean observation: 0.276 [0.000, 24.000], loss: 0.000077, mean_absolute_error: 0.005222, mean_q: -0.064792
#   84916/500000: episode: 101, duration: 137.101s, episode steps: 1783, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.183 [-1.167, 1.409], mean observation: 0.267 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.004956, mean_q: -0.065274
#   85195/500000: episode: 102, duration: 22.398s, episode steps: 279, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.130 [-0.751, 1.269], mean observation: 0.281 [0.000, 24.000], loss: 0.000067, mean_absolute_error: 0.004976, mean_q: -0.065810
#   85467/500000: episode: 103, duration: 22.386s, episode steps: 272, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.084 [-0.636, 1.251], mean observation: 0.274 [0.000, 24.000], loss: 0.000081, mean_absolute_error: 0.005331, mean_q: -0.065323
#   85678/500000: episode: 104, duration: 17.188s, episode steps: 211, steps per second: 12, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.166 [-0.342, 1.084], mean observation: 0.276 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.005080, mean_q: -0.065925
#   86128/500000: episode: 105, duration: 35.132s, episode steps: 450, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.018 [-1.145, 1.416], mean observation: 0.272 [0.000, 24.000], loss: 0.000076, mean_absolute_error: 0.005226, mean_q: -0.066553
#   86894/500000: episode: 106, duration: 60.597s, episode steps: 766, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.247 [-1.255, 2.001], mean observation: 0.272 [0.000, 24.000], loss: 0.000075, mean_absolute_error: 0.005232, mean_q: -0.066829
#   87269/500000: episode: 107, duration: 28.605s, episode steps: 375, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.232 [-0.931, 1.871], mean observation: 0.276 [0.000, 24.000], loss: 0.000060, mean_absolute_error: 0.004884, mean_q: -0.067459
#   87820/500000: episode: 108, duration: 44.306s, episode steps: 551, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.274 [-1.130, 1.619], mean observation: 0.273 [0.000, 24.000], loss: 0.000082, mean_absolute_error: 0.005453, mean_q: -0.067829
#   88490/500000: episode: 109, duration: 49.264s, episode steps: 670, steps per second: 14, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.432 [-0.510, 1.875], mean observation: 0.269 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.005253, mean_q: -0.068883
#   89235/500000: episode: 110, duration: 59.258s, episode steps: 745, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.301 [-0.808, 1.343], mean observation: 0.287 [0.000, 24.000], loss: 0.000080, mean_absolute_error: 0.005278, mean_q: -0.068575
#   89738/500000: episode: 111, duration: 41.480s, episode steps: 503, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.543 [-0.438, 1.429], mean observation: 0.275 [0.000, 24.000], loss: 0.000077, mean_absolute_error: 0.005283, mean_q: -0.070392
#   90243/500000: episode: 112, duration: 40.176s, episode steps: 505, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.213 [-0.985, 1.572], mean observation: 0.273 [0.000, 24.000], loss: 0.000075, mean_absolute_error: 0.005324, mean_q: -0.071205
#   90483/500000: episode: 113, duration: 19.420s, episode steps: 240, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.247 [-0.917, 1.516], mean observation: 0.271 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.005063, mean_q: -0.069933
#   90803/500000: episode: 114, duration: 24.975s, episode steps: 320, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.049 [-0.831, 1.135], mean observation: 0.278 [0.000, 24.000], loss: 0.000080, mean_absolute_error: 0.005278, mean_q: -0.070352
#   91206/500000: episode: 115, duration: 32.498s, episode steps: 403, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.082 [-0.696, 1.385], mean observation: 0.276 [0.000, 24.000], loss: 0.000079, mean_absolute_error: 0.005340, mean_q: -0.071743
#   91587/500000: episode: 116, duration: 31.007s, episode steps: 381, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.332 [-0.404, 1.780], mean observation: 0.279 [0.000, 24.000], loss: 0.000070, mean_absolute_error: 0.005158, mean_q: -0.071814
#   94087/500000: episode: 117, duration: 204.057s, episode steps: 2500, steps per second: 12, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: -0.008 [-1.554, 1.998], mean observation: 0.265 [0.000, 24.000], loss: 0.000062, mean_absolute_error: 0.005070, mean_q: -0.072692
#   94447/500000: episode: 118, duration: 28.161s, episode steps: 360, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.288 [-0.707, 1.871], mean observation: 0.278 [0.000, 24.000], loss: 0.000051, mean_absolute_error: 0.004874, mean_q: -0.074311
#   94921/500000: episode: 119, duration: 37.218s, episode steps: 474, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.032 [-0.911, 1.405], mean observation: 0.274 [0.000, 24.000], loss: 0.000076, mean_absolute_error: 0.005148, mean_q: -0.073990
#   95688/500000: episode: 120, duration: 59.730s, episode steps: 767, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.016 [-1.718, 1.193], mean observation: 0.270 [0.000, 24.000], loss: 0.000070, mean_absolute_error: 0.005344, mean_q: -0.074901
#   96004/500000: episode: 121, duration: 25.905s, episode steps: 316, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.156 [-0.557, 1.037], mean observation: 0.280 [0.000, 24.000], loss: 0.000078, mean_absolute_error: 0.005389, mean_q: -0.074843
#   96886/500000: episode: 122, duration: 67.147s, episode steps: 882, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.166 [-0.706, 1.962], mean observation: 0.269 [0.000, 24.000], loss: 0.000068, mean_absolute_error: 0.005204, mean_q: -0.075975
#   97458/500000: episode: 123, duration: 45.664s, episode steps: 572, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.154 [-0.683, 1.524], mean observation: 0.271 [0.000, 24.000], loss: 0.000070, mean_absolute_error: 0.005364, mean_q: -0.076469
#   97976/500000: episode: 124, duration: 42.325s, episode steps: 518, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.420 [-0.252, 1.550], mean observation: 0.275 [0.000, 24.000], loss: 0.000067, mean_absolute_error: 0.005290, mean_q: -0.076899
#  100476/500000: episode: 125, duration: 203.513s, episode steps: 2500, steps per second: 12, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.145 [-1.126, 2.276], mean observation: 0.269 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.005079, mean_q: -0.076919
#  100893/500000: episode: 126, duration: 32.948s, episode steps: 417, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.270 [-1.065, 1.641], mean observation: 0.274 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.005026, mean_q: -0.073369
#  101395/500000: episode: 127, duration: 40.977s, episode steps: 502, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.003 [-1.091, 1.483], mean observation: 0.275 [0.000, 24.000], loss: 0.000063, mean_absolute_error: 0.005073, mean_q: -0.073987
#  101745/500000: episode: 128, duration: 28.674s, episode steps: 350, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.171 [-0.602, 1.132], mean observation: 0.277 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.005013, mean_q: -0.074055
#  104245/500000: episode: 129, duration: 192.572s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.011 [-1.347, 1.552], mean observation: 0.266 [0.000, 24.000], loss: 0.000064, mean_absolute_error: 0.004994, mean_q: -0.076268
#  104535/500000: episode: 130, duration: 23.664s, episode steps: 290, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.237 [-0.762, 1.563], mean observation: 0.279 [0.000, 24.000], loss: 0.000076, mean_absolute_error: 0.005218, mean_q: -0.076788
#  105145/500000: episode: 131, duration: 47.562s, episode steps: 610, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.047 [-1.055, 1.822], mean observation: 0.272 [0.000, 24.000], loss: 0.000083, mean_absolute_error: 0.005264, mean_q: -0.076335
#  105495/500000: episode: 132, duration: 28.387s, episode steps: 350, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.172 [-0.584, 1.178], mean observation: 0.279 [0.000, 24.000], loss: 0.000078, mean_absolute_error: 0.005224, mean_q: -0.076212
#  106173/500000: episode: 133, duration: 55.311s, episode steps: 678, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.152 [-0.704, 1.386], mean observation: 0.274 [0.000, 24.000], loss: 0.000087, mean_absolute_error: 0.005329, mean_q: -0.078165
#  106810/500000: episode: 134, duration: 49.954s, episode steps: 637, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.168 [-0.806, 1.737], mean observation: 0.272 [0.000, 24.000], loss: 0.000070, mean_absolute_error: 0.005207, mean_q: -0.079185
#  107049/500000: episode: 135, duration: 34.657s, episode steps: 239, steps per second: 7, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.308 [-0.312, 1.392], mean observation: 0.283 [0.000, 24.000], loss: 0.000078, mean_absolute_error: 0.005388, mean_q: -0.080549
#  107585/500000: episode: 136, duration: 40.705s, episode steps: 536, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.149 [-1.005, 1.771], mean observation: 0.271 [0.000, 24.000], loss: 0.000074, mean_absolute_error: 0.005240, mean_q: -0.080962
#  108255/500000: episode: 137, duration: 53.592s, episode steps: 670, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.327 [-0.999, 2.301], mean observation: 0.270 [0.000, 24.000], loss: 0.000068, mean_absolute_error: 0.005125, mean_q: -0.082449
#  108961/500000: episode: 138, duration: 50.327s, episode steps: 706, steps per second: 14, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.072 [-0.963, 1.670], mean observation: 0.266 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.005128, mean_q: -0.081915
#  109359/500000: episode: 139, duration: 32.096s, episode steps: 398, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.180 [-0.907, 1.567], mean observation: 0.277 [0.000, 24.000], loss: 0.000060, mean_absolute_error: 0.004936, mean_q: -0.082448
#  109776/500000: episode: 140, duration: 34.224s, episode steps: 417, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.146 [-0.990, 1.789], mean observation: 0.275 [0.000, 24.000], loss: 0.000068, mean_absolute_error: 0.005194, mean_q: -0.082987
#  110609/500000: episode: 141, duration: 68.278s, episode steps: 833, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.334 [-0.732, 1.847], mean observation: 0.271 [0.000, 24.000], loss: 0.000065, mean_absolute_error: 0.005111, mean_q: -0.084302
#  111098/500000: episode: 142, duration: 40.695s, episode steps: 489, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.270 [-0.604, 2.277], mean observation: 0.274 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.005278, mean_q: -0.084831
#  111481/500000: episode: 143, duration: 30.839s, episode steps: 383, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.214 [-0.630, 1.438], mean observation: 0.277 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.005345, mean_q: -0.085778
#  111837/500000: episode: 144, duration: 29.091s, episode steps: 356, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.229 [-0.973, 1.733], mean observation: 0.278 [0.000, 24.000], loss: 0.000062, mean_absolute_error: 0.005211, mean_q: -0.086440
#  112397/500000: episode: 145, duration: 44.263s, episode steps: 560, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.125 [-0.828, 1.584], mean observation: 0.274 [0.000, 24.000], loss: 0.000068, mean_absolute_error: 0.005152, mean_q: -0.085725
#  112820/500000: episode: 146, duration: 34.380s, episode steps: 423, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.223 [-0.859, 1.829], mean observation: 0.276 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.005311, mean_q: -0.085289
#  115320/500000: episode: 147, duration: 205.185s, episode steps: 2500, steps per second: 12, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.218 [-1.068, 2.822], mean observation: 0.268 [0.000, 24.000], loss: 0.000065, mean_absolute_error: 0.004967, mean_q: -0.083036
#  115578/500000: episode: 148, duration: 21.193s, episode steps: 258, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.242 [-0.682, 1.736], mean observation: 0.280 [0.000, 24.000], loss: 0.000060, mean_absolute_error: 0.004904, mean_q: -0.080927
#  116331/500000: episode: 149, duration: 60.463s, episode steps: 753, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.298 [-0.881, 1.801], mean observation: 0.269 [0.000, 24.000], loss: 0.000057, mean_absolute_error: 0.004942, mean_q: -0.081490
#  117203/500000: episode: 150, duration: 63.720s, episode steps: 872, steps per second: 14, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.072 [-0.965, 1.520], mean observation: 0.268 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.004934, mean_q: -0.083308
#  117632/500000: episode: 151, duration: 34.843s, episode steps: 429, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.195 [-0.880, 1.775], mean observation: 0.276 [0.000, 24.000], loss: 0.000064, mean_absolute_error: 0.004989, mean_q: -0.084113
#  118024/500000: episode: 152, duration: 30.674s, episode steps: 392, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.210 [-0.712, 1.233], mean observation: 0.270 [0.000, 24.000], loss: 0.000063, mean_absolute_error: 0.004761, mean_q: -0.084151
#  118356/500000: episode: 153, duration: 26.826s, episode steps: 332, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.090 [-0.617, 1.228], mean observation: 0.279 [0.000, 24.000], loss: 0.000064, mean_absolute_error: 0.004869, mean_q: -0.084716
#  118775/500000: episode: 154, duration: 33.234s, episode steps: 419, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.026 [-1.226, 1.100], mean observation: 0.274 [0.000, 24.000], loss: 0.000070, mean_absolute_error: 0.005135, mean_q: -0.085423
#  119113/500000: episode: 155, duration: 27.860s, episode steps: 338, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.048 [-1.081, 1.208], mean observation: 0.277 [0.000, 24.000], loss: 0.000055, mean_absolute_error: 0.004846, mean_q: -0.085805
#  119895/500000: episode: 156, duration: 65.667s, episode steps: 782, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.276 [-1.658, 1.747], mean observation: 0.268 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.005009, mean_q: -0.086777
#  120388/500000: episode: 157, duration: 40.476s, episode steps: 493, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.164 [-0.881, 2.278], mean observation: 0.277 [0.000, 24.000], loss: 0.000079, mean_absolute_error: 0.005130, mean_q: -0.088210
#  121200/500000: episode: 158, duration: 64.519s, episode steps: 812, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.070 [-0.923, 1.355], mean observation: 0.269 [0.000, 24.000], loss: 0.000077, mean_absolute_error: 0.005239, mean_q: -0.088988
#  122435/500000: episode: 159, duration: 97.168s, episode steps: 1235, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.236 [-1.067, 2.052], mean observation: 0.265 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.005047, mean_q: -0.091632
#  122916/500000: episode: 160, duration: 39.575s, episode steps: 481, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.112 [-0.849, 1.454], mean observation: 0.277 [0.000, 24.000], loss: 0.000071, mean_absolute_error: 0.005158, mean_q: -0.096814
#  123317/500000: episode: 161, duration: 33.068s, episode steps: 401, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.153 [-0.939, 1.331], mean observation: 0.275 [0.000, 24.000], loss: 0.000061, mean_absolute_error: 0.005057, mean_q: -0.096416
#  123684/500000: episode: 162, duration: 29.091s, episode steps: 367, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.171 [-0.838, 1.410], mean observation: 0.272 [0.000, 24.000], loss: 0.000074, mean_absolute_error: 0.005174, mean_q: -0.097108
#  124445/500000: episode: 163, duration: 59.169s, episode steps: 761, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.338 [-1.210, 2.028], mean observation: 0.267 [0.000, 24.000], loss: 0.000068, mean_absolute_error: 0.004932, mean_q: -0.096002
#  124775/500000: episode: 164, duration: 27.019s, episode steps: 330, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.228 [-0.591, 1.229], mean observation: 0.279 [0.000, 24.000], loss: 0.000065, mean_absolute_error: 0.004854, mean_q: -0.095429
# ...
#  399387/500000: episode: 544, duration: 29.716s, episode steps: 353, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.334 [-0.846, 1.867], mean observation: 0.282 [0.000, 24.000], loss: 0.000081, mean_absolute_error: 0.004952, mean_q: -0.172367
#  400012/500000: episode: 545, duration: 50.829s, episode steps: 625, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.224 [-0.651, 2.510], mean observation: 0.271 [0.000, 24.000], loss: 0.000062, mean_absolute_error: 0.004792, mean_q: -0.171809
#  400297/500000: episode: 546, duration: 23.786s, episode steps: 285, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.167 [-0.677, 1.515], mean observation: 0.280 [0.000, 24.000], loss: 0.000065, mean_absolute_error: 0.004820, mean_q: -0.173079
#  400793/500000: episode: 547, duration: 39.486s, episode steps: 496, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: -0.023 [-1.439, 1.864], mean observation: 0.272 [0.000, 24.000], loss: 0.000068, mean_absolute_error: 0.004961, mean_q: -0.172620
#  400943/500000: episode: 548, duration: 12.570s, episode steps: 150, steps per second: 12, episode reward: -1.000, mean reward: -0.007 [-1.000, 0.000], mean action: 0.102 [-0.603, 1.025], mean observation: 0.278 [0.000, 24.000], loss: 0.000101, mean_absolute_error: 0.005451, mean_q: -0.173662
#  401580/500000: episode: 549, duration: 51.938s, episode steps: 637, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.323 [-0.798, 1.253], mean observation: 0.266 [0.000, 24.000], loss: 0.000071, mean_absolute_error: 0.004933, mean_q: -0.172995
#  402013/500000: episode: 550, duration: 38.570s, episode steps: 433, steps per second: 11, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.254 [-0.570, 1.901], mean observation: 0.276 [0.000, 24.000], loss: 0.000064, mean_absolute_error: 0.004805, mean_q: -0.173428
#  402871/500000: episode: 551, duration: 66.884s, episode steps: 858, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: -0.057 [-1.100, 1.612], mean observation: 0.271 [0.000, 24.000], loss: 0.000067, mean_absolute_error: 0.004888, mean_q: -0.173246
#  402978/500000: episode: 552, duration: 9.053s, episode steps: 107, steps per second: 12, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 0.142 [-0.344, 0.991], mean observation: 0.275 [0.000, 24.000], loss: 0.000056, mean_absolute_error: 0.004807, mean_q: -0.173470
#  403381/500000: episode: 553, duration: 33.779s, episode steps: 403, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.285 [-0.471, 1.653], mean observation: 0.275 [0.000, 24.000], loss: 0.000064, mean_absolute_error: 0.004905, mean_q: -0.173937
#  404491/500000: episode: 554, duration: 88.331s, episode steps: 1110, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.153 [-1.173, 1.735], mean observation: 0.264 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.004838, mean_q: -0.172667
#  404694/500000: episode: 555, duration: 16.796s, episode steps: 203, steps per second: 12, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.173 [-0.412, 1.299], mean observation: 0.268 [0.000, 24.000], loss: 0.000060, mean_absolute_error: 0.004656, mean_q: -0.172883
#  406173/500000: episode: 556, duration: 112.291s, episode steps: 1479, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.132 [-1.351, 1.551], mean observation: 0.264 [0.000, 24.000], loss: 0.000063, mean_absolute_error: 0.004697, mean_q: -0.171480
#  406490/500000: episode: 557, duration: 26.036s, episode steps: 317, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: -0.023 [-0.917, 1.786], mean observation: 0.277 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.004754, mean_q: -0.170184
#  407229/500000: episode: 558, duration: 57.185s, episode steps: 739, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.125 [-1.105, 1.621], mean observation: 0.267 [0.000, 24.000], loss: 0.000071, mean_absolute_error: 0.004809, mean_q: -0.171467
#  407824/500000: episode: 559, duration: 47.208s, episode steps: 595, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.252 [-0.911, 1.289], mean observation: 0.273 [0.000, 24.000], loss: 0.000063, mean_absolute_error: 0.004851, mean_q: -0.172110
#  408698/500000: episode: 560, duration: 63.528s, episode steps: 874, steps per second: 14, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.229 [-0.732, 1.356], mean observation: 0.269 [0.000, 24.000], loss: 0.000071, mean_absolute_error: 0.004950, mean_q: -0.173527
#  410313/500000: episode: 561, duration: 135.006s, episode steps: 1615, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.183 [-1.447, 1.692], mean observation: 0.268 [0.000, 24.000], loss: 0.000066, mean_absolute_error: 0.004797, mean_q: -0.172800
#  410719/500000: episode: 562, duration: 32.480s, episode steps: 406, steps per second: 13, episode reward: 1.000, mean reward: 0.002 [0.000, 1.000], mean action: -0.057 [-1.360, 1.406], mean observation: 0.276 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.004909, mean_q: -0.172307
#  411022/500000: episode: 563, duration: 25.444s, episode steps: 303, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.441 [-0.262, 1.742], mean observation: 0.279 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.004943, mean_q: -0.172617
#  411414/500000: episode: 564, duration: 32.736s, episode steps: 392, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.226 [-0.581, 1.705], mean observation: 0.278 [0.000, 24.000], loss: 0.000090, mean_absolute_error: 0.005094, mean_q: -0.172488
#  411487/500000: episode: 565, duration: 6.146s, episode steps: 73, steps per second: 12, episode reward: -1.000, mean reward: -0.014 [-1.000, 0.000], mean action: 0.169 [-0.240, 0.988], mean observation: 0.268 [0.000, 24.000], loss: 0.000086, mean_absolute_error: 0.005276, mean_q: -0.172194
#  413987/500000: episode: 566, duration: 205.320s, episode steps: 2500, steps per second: 12, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.178 [-1.350, 1.970], mean observation: 0.270 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.004819, mean_q: -0.172241
#  416487/500000: episode: 567, duration: 190.373s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: -0.063 [-1.524, 1.943], mean observation: 0.260 [0.000, 24.000], loss: 0.000071, mean_absolute_error: 0.004780, mean_q: -0.172610
#  417246/500000: episode: 568, duration: 70.347s, episode steps: 759, steps per second: 11, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.300 [-0.801, 1.570], mean observation: 0.271 [0.000, 24.000], loss: 0.000070, mean_absolute_error: 0.004725, mean_q: -0.173661
#  418066/500000: episode: 569, duration: 68.096s, episode steps: 820, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: -0.004 [-1.189, 1.439], mean observation: 0.271 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.004897, mean_q: -0.173771
#  418775/500000: episode: 570, duration: 55.568s, episode steps: 709, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.043 [-0.903, 1.199], mean observation: 0.272 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.004803, mean_q: -0.173180
#  419140/500000: episode: 571, duration: 29.896s, episode steps: 365, steps per second: 12, episode reward: 1.000, mean reward: 0.003 [0.000, 1.000], mean action: 0.346 [-0.383, 1.826], mean observation: 0.279 [0.000, 24.000], loss: 0.000079, mean_absolute_error: 0.004958, mean_q: -0.174381
#  419632/500000: episode: 572, duration: 39.504s, episode steps: 492, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.213 [-0.826, 1.674], mean observation: 0.272 [0.000, 24.000], loss: 0.000093, mean_absolute_error: 0.005159, mean_q: -0.172941
#  419973/500000: episode: 573, duration: 26.988s, episode steps: 341, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.127 [-0.743, 1.376], mean observation: 0.274 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.004770, mean_q: -0.172962
#  422473/500000: episode: 574, duration: 185.472s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: -0.021 [-1.695, 1.747], mean observation: 0.263 [0.000, 24.000], loss: 0.000074, mean_absolute_error: 0.004821, mean_q: -0.175227
#  423298/500000: episode: 575, duration: 64.863s, episode steps: 825, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.173 [-1.054, 1.560], mean observation: 0.266 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.004810, mean_q: -0.177968
#  423900/500000: episode: 576, duration: 48.568s, episode steps: 602, steps per second: 12, episode reward: 1.000, mean reward: 0.002 [0.000, 1.000], mean action: 0.222 [-0.486, 1.090], mean observation: 0.273 [0.000, 24.000], loss: 0.000077, mean_absolute_error: 0.004879, mean_q: -0.176966
#  426370/500000: episode: 577, duration: 188.973s, episode steps: 2470, steps per second: 13, episode reward: -1.000, mean reward: -0.000 [-1.000, 0.000], mean action: 0.188 [-1.664, 1.829], mean observation: 0.262 [0.000, 24.000], loss: 0.000081, mean_absolute_error: 0.004897, mean_q: -0.180231
#  426461/500000: episode: 578, duration: 7.648s, episode steps: 91, steps per second: 12, episode reward: -1.000, mean reward: -0.011 [-1.000, 0.000], mean action: 0.226 [-0.238, 1.099], mean observation: 0.274 [0.000, 24.000], loss: 0.000084, mean_absolute_error: 0.004998, mean_q: -0.184972
#  426701/500000: episode: 579, duration: 20.329s, episode steps: 240, steps per second: 12, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.193 [-0.631, 1.366], mean observation: 0.285 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.004648, mean_q: -0.184477
#  427280/500000: episode: 580, duration: 48.889s, episode steps: 579, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.202 [-0.708, 1.490], mean observation: 0.275 [0.000, 24.000], loss: 0.000086, mean_absolute_error: 0.005031, mean_q: -0.184951
#  427479/500000: episode: 581, duration: 16.466s, episode steps: 199, steps per second: 12, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.116 [-0.636, 0.993], mean observation: 0.275 [0.000, 24.000], loss: 0.000098, mean_absolute_error: 0.005139, mean_q: -0.185048
#  429979/500000: episode: 582, duration: 194.371s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: -0.058 [-1.486, 1.478], mean observation: 0.268 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.004839, mean_q: -0.183817
#  430288/500000: episode: 583, duration: 25.982s, episode steps: 309, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.202 [-0.444, 1.298], mean observation: 0.269 [0.000, 24.000], loss: 0.000081, mean_absolute_error: 0.004781, mean_q: -0.181234
#  430653/500000: episode: 584, duration: 30.224s, episode steps: 365, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.164 [-0.786, 1.163], mean observation: 0.279 [0.000, 24.000], loss: 0.000064, mean_absolute_error: 0.004752, mean_q: -0.181247
#  431158/500000: episode: 585, duration: 40.251s, episode steps: 505, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: -0.018 [-1.088, 1.018], mean observation: 0.275 [0.000, 24.000], loss: 0.000072, mean_absolute_error: 0.004974, mean_q: -0.182392
#  432428/500000: episode: 586, duration: 96.962s, episode steps: 1270, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: -0.039 [-1.409, 1.328], mean observation: 0.263 [0.000, 24.000], loss: 0.000074, mean_absolute_error: 0.005024, mean_q: -0.183836
#  433121/500000: episode: 587, duration: 58.718s, episode steps: 693, steps per second: 12, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.062 [-1.247, 1.572], mean observation: 0.272 [0.000, 24.000], loss: 0.000076, mean_absolute_error: 0.005038, mean_q: -0.187139
#  433702/500000: episode: 588, duration: 47.581s, episode steps: 581, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.114 [-1.123, 1.609], mean observation: 0.270 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.005043, mean_q: -0.187223
#  434163/500000: episode: 589, duration: 38.220s, episode steps: 461, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: -0.037 [-1.232, 1.285], mean observation: 0.276 [0.000, 24.000], loss: 0.000077, mean_absolute_error: 0.005115, mean_q: -0.189265
#  434253/500000: episode: 590, duration: 7.201s, episode steps: 90, steps per second: 12, episode reward: -1.000, mean reward: -0.011 [-1.000, 0.000], mean action: 0.148 [-0.216, 1.014], mean observation: 0.270 [0.000, 24.000], loss: 0.000094, mean_absolute_error: 0.005382, mean_q: -0.188958
#  434968/500000: episode: 591, duration: 56.578s, episode steps: 715, steps per second: 13, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.405 [-0.789, 2.232], mean observation: 0.270 [0.000, 24.000], loss: 0.000075, mean_absolute_error: 0.005065, mean_q: -0.188988
#  435417/500000: episode: 592, duration: 36.544s, episode steps: 449, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.255 [-0.412, 1.312], mean observation: 0.275 [0.000, 24.000], loss: 0.000082, mean_absolute_error: 0.005225, mean_q: -0.189548
#  437917/500000: episode: 593, duration: 190.307s, episode steps: 2500, steps per second: 13, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.248 [-0.999, 1.875], mean observation: 0.264 [0.000, 24.000], loss: 0.000073, mean_absolute_error: 0.005085, mean_q: -0.190448
#  438247/500000: episode: 594, duration: 27.229s, episode steps: 330, steps per second: 12, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.247 [-0.496, 1.781], mean observation: 0.279 [0.000, 24.000], loss: 0.000075, mean_absolute_error: 0.005224, mean_q: -0.189558
#  438454/500000: episode: 595, duration: 17.438s, episode steps: 207, steps per second: 12, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.027 [-0.545, 0.998], mean observation: 0.280 [0.000, 24.000], loss: 0.000063, mean_absolute_error: 0.004916, mean_q: -0.188142
#  438956/500000: episode: 596, duration: 39.948s, episode steps: 502, steps per second: 13, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.315 [-0.508, 1.646], mean observation: 0.270 [0.000, 24.000], loss: 0.000076, mean_absolute_error: 0.005085, mean_q: -0.188628
#  439375/500000: episode: 597, duration: 34.272s, episode steps: 419, steps per second: 12, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.187 [-0.759, 1.053], mean observation: 0.276 [0.000, 24.000], loss: 0.000069, mean_absolute_error: 0.005065, mean_q: -0.188430

# %%
agent.save_weights(model_path, overwrite=True)
