# %%
import numpy as np
import os
import tensorflow as tf
import warnings

from keras.models import Model
from keras.layers import Dense, Flatten, Convolution2D, Input, Concatenate, Activation
from keras.optimizers import Adam
from pommerman.configs import ffa_v0_env
from pommerman.envs.v0 import Pomme
from pommerman.agents import SimpleAgent, BaseAgent
from pommerman.constants import BOARD_SIZE
from rl.agents import DDPGAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory
from rl.core import Env, Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint, Callback
from rl.random import OrnsteinUhlenbeckProcess

# %%
number_of_training_steps = 500000
log_interval = 1000
file_log_path = './dqn/rl_logs/ddgp_dense_8_2/log.txt'
tensorboard_path = './dqn/logs/ddgp_dense_8_2/'
model_path = './dqn/model/ddgp_dense_8_2/model{step}.h4'

# %%
if not os.path.isdir(os.path.dirname(file_log_path)):
    os.makedirs(os.path.dirname(file_log_path))
if not os.path.isdir(os.path.dirname(model_path)):
    os.makedirs(os.path.dirname(model_path))

# %%
class TensorforceAgent(BaseAgent):
    def act(self, obs, action_space):
        pass


class TensorboardLogger(Callback):
    """Logging in tensorboard without tensorflow ops."""
    def __init__(self, log_dir):
        # Some algorithms compute multiple episodes at once since they are multi-threaded.
        # We therefore use a dictionary that is indexed by the episode to separate episodes
        # from each other.
        self.observations = {}
        self.rewards = {}
        self.actions = {}
        self.metrics = {}
        self.step = 0
        """Creates a summary writer logging to log_dir."""
        self.writer = tf.summary.FileWriter(log_dir)

    def log_scalar(self, tag, value, step):
        """Log a scalar variable.
        Parameter
        ----------
        tag : basestring
            Name of the scalar
        value
        step : int
            training iteration
        """
        summary = tf.Summary(value=[tf.Summary.Value(tag=tag, simple_value=value)])
        self.writer.add_summary(summary, step)

    def on_train_begin(self, logs):
        self.metrics_names = self.model.metrics_names

    def on_episode_begin(self, episode, logs):
        self.observations[episode] = []
        self.rewards[episode] = []
        self.actions[episode] = []
        self.metrics[episode] = []

    def on_episode_end(self, episode, logs):
        episode_steps = len(self.observations[episode])
        variables = {
            'step': self.step,
            'nb_steps': self.params['nb_steps'],
            'episode_steps': episode_steps,
            'episode_reward': np.sum(self.rewards[episode]),
            'reward_mean': np.mean(self.rewards[episode]),
            'reward_min': np.min(self.rewards[episode]),
            'reward_max': np.max(self.rewards[episode]),
            'action_mean': np.mean(np.argmax(self.actions[episode], axis=1)),
            'action_min': np.min(np.argmax(self.actions[episode], axis=1)),
            'action_max': np.max(np.argmax(self.actions[episode], axis=1)),
            'obs_mean': np.mean(self.observations[episode]),
            'obs_min': np.min(self.observations[episode]),
            'obs_max': np.max(self.observations[episode]),
        }

        # Format all metrics.
        metrics = np.array(self.metrics[episode])
        with warnings.catch_warnings():
            warnings.filterwarnings('error')
            for idx, name in enumerate(self.metrics_names):
                try:
                    value = np.nanmean(metrics[:, idx])
                except Warning:
                    value = -1
                variables[name] = value
        for key, value in variables.items():
            self.log_scalar(key, value, episode + 1)

        # Free up resources.
        del self.observations[episode]
        del self.rewards[episode]
        del self.actions[episode]
        del self.metrics[episode]

    def on_step_end(self, step, logs):
        episode = logs['episode']
        self.observations[episode].append(logs['observation'])
        self.rewards[episode].append(logs['reward'])
        self.actions[episode].append(logs['action'])
        self.metrics[episode].append(logs['metrics'])
        self.step += 1

# %%
# Instantiate the environment
config = ffa_v0_env()
env = Pomme(**config["env_kwargs"])
np.random.seed(0)
env.seed(0)

env.set_init_game_state(None)
nb_actions = env.action_space.n


def create_actor(actions, input_shape=(2369,)):
    inp = Input(input_shape)
    x = Dense(8)(inp)
    x = Activation('relu')(x)
    x = Dense(8)(x)
    x = Activation('relu')(x)    
    out = Dense(actions)(x)
    out = Activation('softmax')(out)
    model = Model(inputs=inp, outputs=out)
    return model


def create_critic(actions, input_shape=(2369,)):
    action_input = Input(shape=(actions,), name='action_input')
    observation_input = Input(shape=input_shape, name='observation_input')
    x = Concatenate()([action_input, observation_input])
    x = Dense(8)(x)
    x = Activation('relu')(x)
    x = Dense(8)(x)
    x = Activation('relu')(x)    
    x = Dense(1)(x)
    return action_input, Model(inputs=[action_input, observation_input], outputs=x)


actor = create_actor(nb_actions)
action_input, critic = create_critic(nb_actions)
print(actor.summary())
print(critic.summary())
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 2369)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 8)                 18960
# _________________________________________________________________
# activation_6 (Activation)    (None, 8)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 72
# _________________________________________________________________
# activation_7 (Activation)    (None, 8)                 0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 54
# _________________________________________________________________
# activation_8 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 19,086
# Trainable params: 19,086
# Non-trainable params: 0
# _________________________________________________________________
# None
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# action_input (InputLayer)       (None, 6)            0
# __________________________________________________________________________________________________
# observation_input (InputLayer)  (None, 2369)         0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2375)         0           action_input[0][0]
#                                                                  observation_input[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 8)            19008       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8)            0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 8)            72          activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8)            0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            9           activation_10[0][0]
# ==================================================================================================
# Total params: 19,089
# Trainable params: 19,089
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
class EnvWrapper(Env):
    """The abstract environment class that is used by all agents. This class has the exact
        same API that OpenAI Gym uses so that integrating with it is trivial. In contrast to the
        OpenAI Gym implementation, this class only defines the abstract methods without any actual
        implementation.
        To implement your own environment, you need to define the following methods:
        - `step`
        - `reset`
        - `render`
        - `close`
        Refer to the [Gym documentation](https://gym.openai.com/docs/#environments).
        """
    reward_range = (-1, 1)
    action_space = None
    observation_space = None

    def __init__(self, gym, board_size):
        self.gym = gym
        self.action_space = gym.action_space
        self.observation_space = gym.observation_space
        self.reward_range = gym.reward_range
        self.board_size = board_size

    def step(self, action):
        """Run one timestep of the environment's dynamics.
        Accepts an action and returns a tuple (observation, reward, done, info).
        # Arguments
            action (object): An action provided by the environment.
        # Returns
            observation (object): Agent's observation of the current environment.
            reward (float) : Amount of reward returned after previous action.
            done (boolean): Whether the episode has ended, in which case further step() calls will return undefined results.
            info (dict): Contains auxiliary diagnostic information (helpful for debugging, and sometimes learning).
        """
        action = np.argmax(action)
        obs = self.gym.get_observations()
        all_actions = self.gym.act(obs)
        all_actions.insert(self.gym.training_agent, action)
        state, reward, terminal, info = self.gym.step(all_actions)
        agent_state = self.featurize(state[self.gym.training_agent])
        agent_reward = reward[self.gym.training_agent]
        return agent_state, agent_reward, terminal, info

    def reset(self):
        """
        Resets the state of the environment and returns an initial observation.
        # Returns
            observation (object): The initial observation of the space. Initial reward is assumed to be 0.
        """
        # Add 3 random agents
        train_agent_pos = np.random.randint(0, 4)
        agents = []
        for agent_id in range(4):
            if agent_id == train_agent_pos:
                agents.append(TensorforceAgent(config["agent"](agent_id, config["game_type"])))
            else:
                agents.append(SimpleAgent(config["agent"](agent_id, config["game_type"])))
        self.gym.set_agents(agents)
        self.gym.set_training_agent(agents[train_agent_pos].agent_id)
        
        obs = self.gym.reset()
        agent_obs = self.featurize(obs[self.gym.training_agent])
        return agent_obs

    def render(self, mode='human', close=False):
        """Renders the environment.
        The set of supported modes varies per environment. (And some
        environments do not support rendering at all.)
        # Arguments
            mode (str): The mode to render with.
            close (bool): Close all open renderings.
        """
        self.gym.render(mode=mode, close=close)

    def close(self):
        """Override in your subclass to perform any necessary cleanup.
        Environments will automatically close() themselves when
        garbage collected or when the program exits.
        """
        self.gym.close()

    def seed(self, seed=None):
        """Sets the seed for this env's random number generator(s).
        # Returns
            Returns the list of seeds used in this env's random number generators
        """
        raise self.gym.seed(seed)

    def configure(self, *args, **kwargs):
        """Provides runtime configuration to the environment.
        This configuration should consist of data that tells your
        environment how to run (such as an address of a remote server,
        or path to your ImageNet data). It should not affect the
        semantics of the environment.
        """
        raise NotImplementedError()

    def featurize(self, obs):
        shape = (self.board_size, self.board_size, 1)

        def get_matrix(dict, key):
            res = dict[key]
            return res.reshape(shape).astype(np.float32)

        def get_map(board, item):
            map = np.zeros(shape)
            map[board == item] = 1
            return map

        board = get_matrix(obs, 'board')

        # TODO: probably not needed Passage = 0
        rigid_map = get_map(board, 1)               # Rigid = 1
        wood_map = get_map(board, 2)                # Wood = 2
        bomb_map = get_map(board, 3)                # Bomb = 3
        flames_map = get_map(board, 4)              # Flames = 4
        fog_map = get_map(board, 5)                 # TODO: not used for first two stages Fog = 5
        extra_bomb_map = get_map(board, 6)          # ExtraBomb = 6
        incr_range_map = get_map(board, 7)          # IncrRange = 7
        kick_map = get_map(board, 8)                # Kick = 8
        skull_map = get_map(board, 9)               # Skull = 9

        position = obs["position"]
        my_position = np.zeros(shape)
        my_position[position[0], position[1], 0] = 1

        team_mates = get_map(board, obs["teammate"].value) # TODO during documentation it should be an array

        enemies = np.zeros(shape)
        for enemy in obs["enemies"]:
            enemies[board == enemy.value] = 1

        bomb_blast_strength = get_matrix(obs, 'bomb_blast_strength')
        bomb_life = get_matrix(obs, 'bomb_life')

        ammo = obs["ammo"]
        blast_strength = obs["blast_strength"]
        can_kick = int(obs["can_kick"])

        obs = np.concatenate([my_position, enemies, team_mates, rigid_map,
                              wood_map, bomb_map, flames_map,
                              fog_map, extra_bomb_map, incr_range_map,
                              kick_map, skull_map, bomb_blast_strength,
                              bomb_life], axis=2).flatten()
        obs = np.append(obs, [ammo, blast_strength, can_kick])
        return obs

    def __del__(self):
        self.close()

    def __str__(self):
        return '<{} instance>'.format(type(self).__name__)


class CustomProcessor(Processor):
    def process_state_batch(self, batch):
        """Processes an entire batch of states and returns it.
        # Arguments
            batch (list): List of states
        # Returns
            Processed list of states
        """
        batch = np.squeeze(batch, axis=1)
        return batch

    def process_info(self, info):
        """Processes the info as obtained from the environment for use in an agent and
        returns it.
        """
        info['result'] = info['result'].value
        return info

# %%
env_wrapper = EnvWrapper(env, BOARD_SIZE)
processor = CustomProcessor()


memory = SequentialMemory(limit=100000, window_length=1)
random_process = OrnsteinUhlenbeckProcess(size=nb_actions, theta=.15, mu=0., sigma=.3)
agent = DDPGAgent(nb_actions=nb_actions, actor=actor, critic=critic, critic_action_input=action_input,
                  memory=memory, nb_steps_warmup_critic=512, nb_steps_warmup_actor=512,
                  random_process=random_process, gamma=.99, target_model_update=1e-3,
                  batch_size=512, processor=processor)
agent.compile(Adam(lr=0.0001, clipnorm=1.), metrics=['mae'])


file_logger = FileLogger(file_log_path, interval=log_interval)
checkpoint = ModelIntervalCheckpoint(model_path, interval=log_interval)
tensorboard = TensorboardLogger(tensorboard_path)
callbacks=[file_logger, checkpoint, tensorboard]
if os.path.isfile(model_path):
    agent.load_weights(model_path)

# %%
history = agent.fit(env_wrapper, nb_steps=number_of_training_steps, visualize=False, verbose=2,
        nb_max_episode_steps=env._max_steps, callbacks=callbacks)
# Out:
# Training for 500000 steps ...
#      44/500000: episode: 1, duration: 0.887s, episode steps: 44, steps per second: 50, episode reward: -1.000, mean reward: -0.023 [-1.000, 0.000], mean action: 0.195 [-0.265, 0.465], mean observation: 0.070 [0.000, 24.000], loss: --, mean_absolute_error: --, mean_q: --
#     720/500000: episode: 2, duration: 15.889s, episode steps: 676, steps per second: 43, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: -0.011 [-1.055, 1.412], mean observation: 0.047 [0.000, 24.000], loss: 0.004099, mean_absolute_error: 0.039448, mean_q: 0.070418
#    1115/500000: episode: 3, duration: 21.261s, episode steps: 395, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.197 [-0.775, 1.029], mean observation: 0.049 [0.000, 24.000], loss: 0.002258, mean_absolute_error: 0.029248, mean_q: 0.009115
#    1140/500000: episode: 4, duration: 1.393s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.199 [-0.309, 1.089], mean observation: 0.072 [0.000, 24.000], loss: 0.001932, mean_absolute_error: 0.026160, mean_q: -0.018331
#    1165/500000: episode: 5, duration: 1.337s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.093 [-0.206, 0.637], mean observation: 0.071 [0.000, 24.000], loss: 0.002081, mean_absolute_error: 0.026876, mean_q: -0.013734
#    1190/500000: episode: 6, duration: 1.396s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.119 [-0.169, 0.662], mean observation: 0.072 [0.000, 24.000], loss: 0.002498, mean_absolute_error: 0.028426, mean_q: -0.017500
#    1215/500000: episode: 7, duration: 1.414s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0
, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.166 [-0.198, 1.052], mean observation: 0.071 [0.000, 24.000], loss: 0.001894, mean_absolute_error: 0.031873, mean_q: -0.013006
#    3960/500000: episode: 80, duration: 1.344s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.152 [-0.260, 1.173], mean observation: 0.065 [0.000, 24.000], loss: 0.001662, mean_absolute_error: 0.030888, mean_q: -0.012578
#    3985/500000: episode: 81, duration: 1.361s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.129 [-0.252, 1.140], mean observation: 0.071 [0.000, 24.000], loss: 0.001734, mean_absolute_error: 0.031108, mean_q: -0.008731
#    4010/500000: episode: 82, duration: 1.368s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.136 [-0.167, 0.964], mean observation: 0.071 [0.000, 24.000], loss: 0.001791, mean_absolute_error: 0.031825, mean_q: -0.006507
#    4035/500000: episode: 83, duration: 1.388s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.094 [-0.315, 1.087], mean observation: 0.072 [0.000, 24.000], loss: 0.001832, mean_absolute_error: 0.032254, mean_q: -0.008336
#    4060/500000: episode: 84, duration: 1.394s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.121 [-0.157, 1.088], mean observation: 0.071 [0.000, 24.000], loss: 0.001695, mean_absolute_error: 0.031128, mean_q: -0.007892
#    4085/500000: episode: 85, duration: 1.308s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.209 [-0.282, 1.268], mean observation: 0.072 [0.000, 24.000], loss: 0.001855, mean_absolute_error: 0.032066, mean_q: -0.012603
#    4110/500000: episode: 86, duration: 1.410s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.222 [-0.132, 1.171], mean observation: 0.072 [0.000, 24.000], loss: 0.001924, mean_absolute_error: 0.032719, mean_q: -0.011030
#    4135/500000: episode: 87, duration: 1.396s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.174 [-0.171, 1.090], mean observation: 0.072 [0.000, 24.000], loss: 0.001874, mean_absolute_error: 0.032141, mean_q: -0.012818
#    4160/500000: episode: 88, duration: 1.338s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.154 [-0.151, 1.120], mean observation: 0.070 [0.000, 24.000], loss: 0.001912, mean_absolute_error: 0.032521, mean_q: -0.011332
#    4185/500000: episode: 89, duration: 1.346s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.131 [-0.372, 1.016], mean observation: 0.072 [0.000, 24.000], loss: 0.001705, mean_absolute_error: 0.031613, mean_q: -0.009297
#    4210/500000: episode: 90, duration: 1.380s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.226 [-0.099, 1.150], mean observation: 0.072 [0.000, 24.000], loss: 0.001903, mean_absolute_error: 0.031903, mean_q: -0.013797
#    4235/500000: episode: 91, duration: 1.384s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.185 [-0.205, 1.041], mean observation: 0.071 [0.000, 24.000], loss: 0.001675, mean_absolute_error: 0.031067, mean_q: -0.015865
#    4260/500000: episode: 92, duration: 1.352s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.208 [-0.235, 1.105], mean observation: 0.072 [0.000, 24.000], loss: 0.001729, mean_absolute_error: 0.030698, mean_q: -0.008210
#    4285/500000: episode: 93, duration: 1.357s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.189 [-0.251, 1.210], mean observation: 0.072 [0.000, 24.000], loss: 0.001667, mean_absolute_error: 0.030348, mean_q: -0.012283
#    4310/500000: episode: 94, duration: 1.338s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.123 [-0.378, 1.039], mean observation: 0.072 [0.000, 24.000], loss: 0.001813, mean_absolute_error: 0.031471, mean_q: -0.013567
#    4335/500000: episode: 95, duration: 1.319s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0
, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.198 [-0.113, 1.071], mean observation: 0.072 [0.000, 24.000], loss: 0.001840, mean_absolute_error: 0.031565, mean_q: -0.027824
#    5188/500000: episode: 128, duration: 1.397s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.186 [-0.225, 1.237], mean observation: 0.071 [0.000, 24.000], loss: 0.001896, mean_absolute_error: 0.031421, mean_q: -0.026669
#    5213/500000: episode: 129, duration: 1.351s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.156 [-0.188, 1.227], mean observation: 0.071 [0.000, 24.000], loss: 0.002009, mean_absolute_error: 0.032093, mean_q: -0.036498
#    5238/500000: episode: 130, duration: 1.292s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.170 [-0.202, 1.044], mean observation: 0.072 [0.000, 24.000], loss: 0.002071, mean_absolute_error: 0.032907, mean_q: -0.029300
#    5263/500000: episode: 131, duration: 1.375s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.154 [-0.237, 1.258], mean observation: 0.065 [0.000, 24.000], loss: 0.001864, mean_absolute_error: 0.031303, mean_q: -0.024448
#    5288/500000: episode: 132, duration: 1.353s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.200 [-0.202, 1.116], mean observation: 0.058 [0.000, 24.000], loss: 0.001854, mean_absolute_error: 0.031396, mean_q: -0.025065
#    5313/500000: episode: 133, duration: 1.382s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.177 [-0.176, 1.165], mean observation: 0.072 [0.000, 24.000], loss: 0.001863, mean_absolute_error: 0.031607, mean_q: -0.031676
#    5338/500000: episode: 134, duration: 1.396s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.139 [-0.195, 1.033], mean observation: 0.072 [0.000, 24.000], loss: 0.002093, mean_absolute_error: 0.032638, mean_q: -0.028754
#    5363/500000: episode: 135, duration: 1.376s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.190 [-0.122, 1.210], mean observation: 0.071 [0.000, 24.000], loss: 0.002065, mean_absolute_error: 0.032751, mean_q: -0.035602
#    5388/500000: episode: 136, duration: 1.370s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.135 [-0.260, 1.013], mean observation: 0.071 [0.000, 24.000], loss: 0.001923, mean_absolute_error: 0.031451, mean_q: -0.025739
#    5413/500000: episode: 137, duration: 1.352s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.180 [-0.184, 1.162], mean observation: 0.071 [0.000, 24.000], loss: 0.001922, mean_absolute_error: 0.032080, mean_q: -0.030242
#    5438/500000: episode: 138, duration: 1.366s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.222 [-0.095, 1.101], mean observation: 0.072 [0.000, 24.000], loss: 0.002213, mean_absolute_error: 0.033764, mean_q: -0.035373
#    5463/500000: episode: 139, duration: 1.347s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.168 [-0.252, 1.026], mean observation: 0.058 [0.000, 24.000], loss: 0.001835, mean_absolute_error: 0.031753, mean_q: -0.034030
#    5488/500000: episode: 140, duration: 1.325s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.104 [-0.197, 1.071], mean observation: 0.072 [0.000, 24.000], loss: 0.001934, mean_absolute_error: 0.032235, mean_q: -0.045830
#    5513/500000: episode: 141, duration: 1.347s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.192 [-0.218, 1.137], mean observation: 0.072 [0.000, 24.000], loss: 0.002086, mean_absolute_error: 0.032628, mean_q: -0.035734
#    5538/500000: episode: 142, duration: 1.398s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.101 [-0.298, 1.032], mean observation: 0.065 [0.000, 24.000], loss: 0.001884, mean_absolute_error: 0.032296, mean_q: -0.041056
#    5563/500000: episode: 143, duration: 1.389s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.180 [-0.223, 1.069], mean observation: 0.072 [0.000, 24.000], loss: 0.001878, mean_absolute_error: 0.031588, mean_q: -0.035745
#    5588/500000: episode: 144, duration: 1.397s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.070 [-0.365, 1.201], mean observation: 0.072 [0.000, 24.000], loss: 0.001959, mean_absolute_error: 0.032093, mean_q: -0.043019
#    5613/500000: episode: 145, duration: 1.315s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.200 [-0.076, 1.047], mean observation: 0.072 [0.000, 24.000], loss: 0.001865, mean_absolute_error: 0.031807, mean_q: -0.042109
#    5638/500000: episode: 146, duration: 1.468s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.178 [-0.353, 1.106], mean observation: 0.072 [0.000, 24.000], loss: 0.001930, mean_absolute_error: 0.032335, mean_q: -0.043011
#    5663/500000: episode: 147, duration: 1.498s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.227 [-0.286, 1.163], mean observation: 0.072 [0.000, 24.000], loss: 0.001881, mean_absolute_error: 0.032525, mean_q: -0.041068
#    5688/500000: episode: 148, duration: 1.451s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.182 [-0.155, 1.167], mean observation: 0.072 [0.000, 24.000], loss: 0.001930, mean_absolute_error: 0.031767, mean_q: -0.040887
#    5713/500000: episode: 149, duration: 1.289s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.197 [-0.165, 1.113], mean observation: 0.071 [0.000, 24.000], loss: 0.001990, mean_absolute_error: 0.032048, mean_q: -0.045562
#    5738/500000: episode: 150, duration: 1.260s, episode steps: 25, steps per second: 20, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.176 [-0.236, 1.281], mean observation: 0.072 [0.000, 24.000], loss: 0.001774, mean_absolute_error: 0.031896, mean_q: -0.046034
#    5763/500000: episode: 151, duration: 1.355s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.168 [-0.287, 1.069], mean observation: 0.071 [0.000, 24.000], loss: 0.001802, mean_absolute_error: 0.030965, mean_q: -0.041434
#    5788/500000: episode: 152, duration: 1.418s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.197 [-0.188, 0.975], mean observation: 0.072 [0.000, 24.000], loss: 0.001885, mean_absolute_error: 0.031884, mean_q: -0.051638
#    5813/500000: episode: 153, duration: 1.345s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.156 [-0.367, 1.075], mean observation: 0.072 [0.000, 24.000], loss: 0.001923, mean_absolute_error: 0.032795, mean_q: -0.050205
#    5838/500000: episode: 154, duration: 1.315s, episode steps: 25, steps per second: 19, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.162 [-0.196, 1.106], mean observation: 0.071 [0.000, 24.000], loss: 0.001898, mean_absolute_error: 0.032595, mean_q: -0.051583
#    5863/500000: episode: 155, duration: 1.357s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.112 [-0.377, 0.997], mean observation: 0.072 [0.000, 24.000], loss: 0.001934, mean_absolute_error: 0.032733, mean_q: -0.059215
#    5888/500000: episode: 156, duration: 1.380s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.201 [-0.262, 1.038], mean observation: 0.065 [0.000, 24.000], loss: 0.001912, mean_absolute_error: 0.032532, mean_q: -0.051316
#    5913/500000: episode: 157, duration: 1.469s, episode steps: 25, steps per second: 17, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.175 [-0.276, 1.127], mean observation: 0.071 [0.000, 24.000], loss: 0.002029, mean_absolute_error: 0.033309, mean_q: -0.055087
#    5938/500000: episode: 158, duration: 1.354s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.189 [-0.113, 1.074], mean observation: 0.072 [0.000, 24.000], loss: 0.001721, mean_absolute_error: 0.031667, mean_q: -0.055798
#    5963/500000: episode: 159, duration: 1.400s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.212 [-0.092, 1.189], mean observation: 0.072 [0.000, 24.000], loss: 0.001720, mean_absolute_error: 0.031362, mean_q: -0.062078
#    5988/500000: episode: 160, duration: 1.412s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.131 [-0.253, 1.075], mean observation: 0.072 [0.000, 24.000], loss: 0.001887, mean_absolute_error: 0.032376, mean_q: -0.057043
#    6013/500000: episode: 161, duration: 1.426s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.218 [-0.099, 1.137], mean observation: 0.070 [0.000, 24.000], loss: 0.001882, mean_absolute_error: 0.032483, mean_q: -0.059846
#    6055/500000: episode: 162, duration: 2.524s, episode steps: 42, steps per second: 17, episode reward: -1.000, mean reward: -0.024 [-1.000, 0.000], mean action: 0.170 [-0.166, 1.023], mean observation: 0.071 [0.000, 24.000], loss: 0.001792, mean_absolute_error: 0.031663, mean_q: -0.061153
#    6080/500000: episode: 163, duration: 1.383s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.178 [-0.250, 1.174], mean observation: 0.065 [0.000, 24.000], loss: 0.002049, mean_absolute_error: 0.032875, mean_q: -0.063901
#    6105/500000: episode: 164, duration: 1.419s, episode steps: 25, steps per second: 18, episode reward: -1.000, mean reward: -0.040 [-1.000, 0.000], mean action: 0.207 [-0.101, 1.101], mean observation: 0.072 [0.000, 24.000], loss: 0.001817, mean_absolute_error: 0.032341, mean_q: -0.064966
# ...
#   13631/500000: episode: 229, duration: 20.693s, episode steps: 385, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.354 [-1.077, 1.856], mean observation: 0.054 [0.000, 24.000], loss: 0.001135, mean_absolute_error: 0.024023, mean_q: -0.161316
#   13990/500000: episode: 230, duration: 20.132s, episode steps: 359, steps per second: 18, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.019 [-1.139, 1.450], mean observation: 0.055 [0.000, 24.000], loss: 0.001205, mean_absolute_error: 0.024432, mean_q: -0.160927
#   14506/500000: episode: 231, duration: 28.935s, episode steps: 516, steps per second: 18, episode reward: 1.000, mean reward: 0.002 [0.000, 1.000], mean action: 0.122 [-1.121, 1.283], mean observation: 0.047 [0.000, 24.000], loss: 0.001279, mean_absolute_error: 0.025025, mean_q: -0.167293
#   14938/500000: episode: 232, duration: 23.067s, episode steps: 432, steps per second: 19, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.255 [-0.899, 1.739], mean observation: 0.052 [0.000, 24.000], loss: 0.001368, mean_absolute_error: 0.025530, mean_q: -0.170953
#   15100/500000: episode: 233, duration: 8.724s, episode steps: 162, steps per second: 19, episode reward: -1.000, mean reward: -0.006 [-1.000, 0.000], mean action: -0.032 [-0.878, 1.273], mean observation: 0.063 [0.000, 24.000], loss: 0.001330, mean_absolute_error: 0.025395, mean_q: -0.171189
#   15615/500000: episode: 234, duration: 27.531s, episode steps: 515, steps per second: 19, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.171 [-1.117, 1.964], mean observation: 0.049 [0.000, 24.000], loss: 0.001326, mean_absolute_error: 0.025888, mean_q: -0.176642
#   15876/500000: episode: 235, duration: 14.367s, episode steps: 261, steps per second: 18, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.259 [-0.526, 1.638], mean observation: 0.060 [0.000, 24.000], loss: 0.001350, mean_absolute_error: 0.026251, mean_q: -0.176042
#   16275/500000: episode: 236, duration: 20.860s, episode steps: 399, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.191 [-0.516, 1.725], mean observation: 0.051 [0.000, 24.000], loss: 0.001412, mean_absolute_error: 0.026753, mean_q: -0.172724
#   16471/500000: episode: 237, duration: 10.733s, episode steps: 196, steps per second: 18, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.315 [-0.212, 1.342], mean observation: 0.061 [0.000, 24.000], loss: 0.001465, mean_absolute_error: 0.026872, mean_q: -0.175295
#   16657/500000: episode: 238, duration: 9.919s, episode steps: 186, steps per second: 19, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.152 [-0.593, 1.335], mean observation: 0.058 [0.000, 24.000], loss: 0.001494, mean_absolute_error: 0.026864, mean_q: -0.177388
#   17132/500000: episode: 239, duration: 26.092s, episode steps: 475, steps per second: 18, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.105 [-1.444, 1.581], mean observation: 0.050 [0.000, 24.000], loss: 0.001399, mean_absolute_error: 0.026624, mean_q: -0.178427
#   17253/500000: episode: 240, duration: 6.486s, episode steps: 121, steps per second: 19, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 0.220 [-0.487, 1.150], mean observation: 0.061 [0.000, 24.000], loss: 0.001368, mean_absolute_error: 0.026455, mean_q: -0.177161
#   17542/500000: episode: 241, duration: 14.876s, episode steps: 289, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.206 [-0.513, 1.155], mean observation: 0.047 [0.000, 24.000], loss: 0.001346, mean_absolute_error: 0.026379, mean_q: -0.179704
#   17912/500000: episode: 242, duration: 19.597s, episode steps: 370, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.122 [-1.048, 1.456], mean observation: 0.053 [0.000, 24.000], loss: 0.001308, mean_absolute_error: 0.026075, mean_q: -0.183971
#   18037/500000: episode: 243, duration: 6.729s, episode steps: 125, steps per second: 19, episode reward: -1.000, mean reward: -0.008 [-1.000, 0.000], mean action: 0.100 [-0.648, 1.600], mean observation: 0.064 [0.000, 24.000], loss: 0.001311, mean_absolute_error: 0.026097, mean_q: -0.186373
#   18207/500000: episode: 244, duration: 9.269s, episode steps: 170, steps per second: 18, episode reward: -1.000, mean reward: -0.006 [-1.000, 0.000], mean action: 0.143 [-0.498, 1.260], mean observation: 0.059 [0.000, 24.000], loss: 0.001332, mean_absolute_error: 0.026097, mean_q: -0.189883
#   18529/500000: episode: 245, duration: 17.479s, episode steps: 322, steps per second: 18, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.054 [-0.875, 1.232], mean observation: 0.051 [0.000, 24.000], loss: 0.001374, mean_absolute_error: 0.026408, mean_q: -0.189119
#   18556/500000: episode: 246, duration: 1.557s, episode steps: 27, steps per second: 17, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 0.143 [-0.418, 0.961], mean observation: 0.071 [0.000, 24.000], loss: 0.001318, mean_absolute_error: 0.026306, mean_q: -0.187474
#   18926/500000: episode: 247, duration: 19.236s, episode steps: 370, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.130 [-0.895, 1.456], mean observation: 0.051 [0.000, 24.000], loss: 0.001397, mean_absolute_error: 0.026402, mean_q: -0.191575
#   19090/500000: episode: 248, duration: 8.912s, episode steps: 164, steps per second: 18, episode reward: -1.000, mean reward: -0.006 [-1.000, 0.000], mean action: 0.201 [-0.303, 1.284], mean observation: 0.061 [0.000, 24.000], loss: 0.001412, mean_absolute_error: 0.026646, mean_q: -0.191699
#   19199/500000: episode: 249, duration: 5.503s, episode steps: 109, steps per second: 20, episode reward: -1.000, mean reward: -0.009 [-1.000, 0.000], mean action: 0.110 [-0.658, 1.265], mean observation: 0.060 [0.000, 24.000], loss: 0.001400, mean_absolute_error: 0.026468, mean_q: -0.193636
#   19254/500000: episode: 250, duration: 3.104s, episode steps: 55, steps per second: 18, episode reward: -1.000, mean reward: -0.018 [-1.000, 0.000], mean action: 0.176 [-0.226, 1.249], mean observation: 0.068 [0.000, 24.000], loss: 0.001427, mean_absolute_error: 0.027130, mean_q: -0.195218
#   19760/500000: episode: 251, duration: 27.436s, episode steps: 506, steps per second: 18, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.070 [-1.025, 1.789], mean observation: 0.047 [0.000, 24.000], loss: 0.001382, mean_absolute_error: 0.026753, mean_q: -0.197799
#   19787/500000: episode: 252, duration: 1.520s, episode steps: 27, steps per second: 18, episode reward: -1.000, mean reward: -0.037 [-1.000, 0.000], mean action: 0.162 [-0.209, 1.118], mean observation: 0.071 [0.000, 24.000], loss: 0.001292, mean_absolute_error: 0.026367, mean_q: -0.198775
#   20491/500000: episode: 253, duration: 38.441s, episode steps: 704, steps per second: 18, episode reward: 1.000, mean reward: 0.001 [0.000, 1.000], mean action: 0.242 [-0.809, 1.883], mean observation: 0.044 [0.000, 24.000], loss: 0.001342, mean_absolute_error: 0.026457, mean_q: -0.198916
#   21065/500000: episode: 254, duration: 30.524s, episode steps: 574, steps per second: 19, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.264 [-0.848, 1.918], mean observation: 0.045 [0.000, 24.000], loss: 0.001322, mean_absolute_error: 0.026383, mean_q: -0.199993
#   22690/500000: episode: 255, duration: 88.782s, episode steps: 1625, steps per second: 18, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.109 [-1.514, 2.189], mean observation: 0.043 [0.000, 24.000], loss: 0.001154, mean_absolute_error: 0.024716, mean_q: -0.199787
#   22903/500000: episode: 256, duration: 11.285s, episode steps: 213, steps per second: 19, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.182 [-0.771, 1.558], mean observation: 0.053 [0.000, 24.000], loss: 0.001047, mean_absolute_error: 0.023156, mean_q: -0.199820
#   23192/500000: episode: 257, duration: 15.511s, episode steps: 289, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: -0.030 [-0.934, 1.103], mean observation: 0.058 [0.000, 24.000], loss: 0.001017, mean_absolute_error: 0.022898, mean_q: -0.200269
#   23381/500000: episode: 258, duration: 10.281s, episode steps: 189, steps per second: 18, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.116 [-0.783, 1.399], mean observation: 0.064 [0.000, 24.000], loss: 0.001045, mean_absolute_error: 0.023490, mean_q: -0.199603
#   23599/500000: episode: 259, duration: 11.799s, episode steps: 218, steps per second: 18, episode reward: -1.000, mean reward: -0.005 [-1.000, 0.000], mean action: 0.097 [-0.469, 1.216], mean observation: 0.054 [0.000, 24.000], loss: 0.001081, mean_absolute_error: 0.023770, mean_q: -0.201883
#   24050/500000: episode: 260, duration: 23.984s, episode steps: 451, steps per second: 19, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.096 [-1.160, 1.677], mean observation: 0.051 [0.000, 24.000], loss: 0.001064, mean_absolute_error: 0.023738, mean_q: -0.202797
#   24391/500000: episode: 261, duration: 18.682s, episode steps: 341, steps per second: 18, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.283 [-0.942, 1.278], mean observation: 0.053 [0.000, 24.000], loss: 0.001088, mean_absolute_error: 0.023746, mean_q: -0.204676
#   24703/500000: episode: 262, duration: 16.769s, episode steps: 312, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.226 [-0.555, 1.618], mean observation: 0.057 [0.000, 24.000], loss: 0.001094, mean_absolute_error: 0.024026, mean_q: -0.203727
#   24986/500000: episode: 263, duration: 15.221s, episode steps: 283, steps per second: 19, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.139 [-1.295, 1.659], mean observation: 0.057 [0.000, 24.000], loss: 0.001136, mean_absolute_error: 0.024378, mean_q: -0.201696
#   25319/500000: episode: 264, duration: 26.620s, episode steps: 333, steps per second: 13, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.252 [-0.533, 1.321], mean observation: 0.052 [0.000, 24.000], loss: 0.001092, mean_absolute_error: 0.023862, mean_q: -0.203431
#   26025/500000: episode: 265, duration: 36.800s, episode steps: 706, steps per second: 19, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.024 [-1.474, 1.769], mean observation: 0.042 [0.000, 24.000], loss: 0.001067, mean_absolute_error: 0.023672, mean_q: -0.199818
#   26667/500000: episode: 266, duration: 33.272s, episode steps: 642, steps per second: 19, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.251 [-1.008, 1.838], mean observation: 0.046 [0.000, 24.000], loss: 0.001012, mean_absolute_error: 0.023164, mean_q: -0.198834
#   27033/500000: episode: 267, duration: 18.383s, episode steps: 366, steps per second: 20, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.062 [-0.983, 1.192], mean observation: 0.052 [0.000, 24.000], loss: 0.001023, mean_absolute_error: 0.023176, mean_q: -0.200615
#   27355/500000: episode: 268, duration: 16.986s, episode steps: 322, steps per second: 19, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.146 [-0.632, 1.279], mean observation: 0.053 [0.000, 24.000], loss: 0.001031, mean_absolute_error: 0.023201, mean_q: -0.199264
#   28716/500000: episode: 269, duration: 67.091s, episode steps: 1361, steps per second: 20, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.079 [-0.857, 1.289], mean observation: 0.043 [0.000, 24.000], loss: 0.000961, mean_absolute_error: 0.022050, mean_q: -0.196067
#   30891/500000: episode: 270, duration: 95.530s, episode steps: 2175, steps per second: 23, episode reward: -1.000, mean reward: -0.000 [-1.000, 0.000], mean action: 0.256 [-1.029, 1.759], mean observation: 0.041 [0.000, 24.000], loss: 0.000833, mean_absolute_error: 0.020425, mean_q: -0.200394
#   31369/500000: episode: 271, duration: 34.756s, episode steps: 478, steps per second: 14, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.204 [-0.940, 1.832], mean observation: 0.051 [0.000, 24.000], loss: 0.000777, mean_absolute_error: 0.019533, mean_q: -0.205971
#   31681/500000: episode: 272, duration: 16.908s, episode steps: 312, steps per second: 18, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.207 [-0.847, 1.653], mean observation: 0.054 [0.000, 24.000], loss: 0.000797, mean_absolute_error: 0.019793, mean_q: -0.204190
#   32168/500000: episode: 273, duration: 27.582s, episode steps: 487, steps per second: 18, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.296 [-0.464, 1.865], mean observation: 0.052 [0.000, 24.000], loss: 0.000817, mean_absolute_error: 0.019940, mean_q: -0.205512
#   32396/500000: episode: 274, duration: 12.606s, episode steps: 228, steps per second: 18, episode reward: -1.000, mean reward: -0.004 [-1.000, 0.000], mean action: 0.156 [-0.496, 1.233], mean observation: 0.063 [0.000, 24.000], loss: 0.000826, mean_absolute_error: 0.020008, mean_q: -0.205510
#   33024/500000: episode: 275, duration: 31.274s, episode steps: 628, steps per second: 20, episode reward: -1.000, mean reward: -0.002 [-1.000, 0.000], mean action: 0.483 [-0.845, 2.735], mean observation: 0.046 [0.000, 24.000], loss: 0.000840, mean_absolute_error: 0.020299, mean_q: -0.203758
#   34669/500000: episode: 276, duration: 78.555s, episode steps: 1645, steps per second: 21, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.118 [-1.298, 1.665], mean observation: 0.035 [0.000, 24.000], loss: 0.000795, mean_absolute_error: 0.019963, mean_q: -0.200274
#   37169/500000: episode: 277, duration: 121.115s, episode steps: 2500, steps per second: 21, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.003 [-2.053, 2.386], mean observation: 0.041 [0.000, 24.000], loss: 0.000669, mean_absolute_error: 0.018003, mean_q: -0.198891
#   37412/500000: episode: 278, duration: 12.180s, episode steps: 243, steps per second: 20, episode reward: 1.000, mean reward: 0.004 [0.000, 1.000], mean action: 0.179 [-0.767, 1.335], mean observation: 0.057 [0.000, 24.000], loss: 0.000650, mean_absolute_error: 0.017309, mean_q: -0.203588
#   38503/500000: episode: 279, duration: 48.096s, episode steps: 1091, steps per second: 23, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.265 [-1.070, 1.668], mean observation: 0.045 [0.000, 24.000], loss: 0.000645, mean_absolute_error: 0.017202, mean_q: -0.210371
#   39357/500000: episode: 280, duration: 44.772s, episode steps: 854, steps per second: 19, episode reward: -1.000, mean reward: -0.001 [-1.000, 0.000], mean action: 0.297 [-1.238, 1.604], mean observation: 0.044 [0.000, 24.000], loss: 0.000604, mean_absolute_error: 0.016585, mean_q: -0.215048
#   39743/500000: episode: 281, duration: 20.985s, episode steps: 386, steps per second: 18, episode reward: -1.000, mean reward: -0.003 [-1.000, 0.000], mean action: 0.195 [-0.695, 1.553], mean observation: 0.052 [0.000, 24.000], loss: 0.000598, mean_absolute_error: 0.016744, mean_q: -0.216834
#   42243/500000: episode: 282, duration: 123.596s, episode steps: 2500, steps per second: 20, episode reward: 0.000, mean reward: 0.000 [0.000, 0.000], mean action: 0.172 [-1.234, 1.732], mean observation: 0.038 [0.000, 24.000], loss: 0.000581, mean_absolute_error: 0.016268, mean_q: -0.217700

# %%
agent.save_weights(model_path, overwrite=True)
